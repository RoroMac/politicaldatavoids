# %%
import pandas as pd

com = pd.read_csv("community/FB_groups_States_crime.csv", sep= ",")
pol = pd.read_csv("political/Topics_FB_Political_Posts_per_partycrime.csv", sep = ",")
news = pd.read_csv("news/FB_groups_News_Media_Outlets_crime.csv", sep=",")

# %%
com.head()
# Out:
#    Unnamed: 0                                   name  \
# 0         436  Hispanos unidos en New York (H.U.N.Y)
# 1         515  Hispanos unidos en New York (H.U.N.Y)
# 2        1208  Hispanos unidos en New York (H.U.N.Y)
# 3        1211  Hispanos unidos en New York (H.U.N.Y)
# 4        1431  Hispanos unidos en New York (H.U.N.Y)
#
#                                Page or Account URL                   List  \
# 0  https://www.facebook.com/groups/793416207356486  Latinos+EstadosGroups
# 1  https://www.facebook.com/groups/793416207356486  Latinos+EstadosGroups
# 2  https://www.facebook.com/groups/793416207356486  Latinos+EstadosGroups
# 3  https://www.facebook.com/groups/793416207356486  Latinos+EstadosGroups
# 4  https://www.facebook.com/groups/793416207356486  Latinos+EstadosGroups
#
#       State     state      Facebook Id                             Group Name  \
# 0  New York  New York  793416207356486  Hispanos unidos en New York (H.U.N.Y)
# 1  New York  New York  793416207356486  Hispanos unidos en New York (H.U.N.Y)
# 2  New York  New York  793416207356486  Hispanos unidos en New York (H.U.N.Y)
# 3  New York  New York  793416207356486  Hispanos unidos en New York (H.U.N.Y)
# 4  New York  New York  793416207356486  Hispanos unidos en New York (H.U.N.Y)
#
#   User Name  Likes at Posting  ... Final Link Image Text  \
# 0       NaN            6241.0  ...        NaN        NaN
# 1       NaN            6241.0  ...        NaN        NaN
# 2       NaN            6291.0  ...        NaN        NaN
# 3       NaN            6292.0  ...        NaN        NaN
# 4       NaN            6293.0  ...        NaN        NaN
#
#                                            Link Text  \
# 0                                   Primera Línea NY
# 1                                   Primera Línea NY
# 2  Ejército: involucrados en caso de Vanessa Guil...
# 3  Ejército: involucrados en caso de Vanessa Guil...
# 4                                                Eva
#
#                                          Description  Sponsor Id  \
# 0  MTA ofrece $10.000 dólares de recompensa por a...         NaN
# 1  MTA ofrece $10.000 dólares de recompensa por a...         NaN
# 2  El secretario del Ejército de EE.UU. #RyanMcCa...         NaN
# 3  El secretario del Ejército de EE.UU. #RyanMcCa...         NaN
# 4  As many of you know about Diego’s story and so...         NaN
#
#    Sponsor Name  Total Interactions  Overperforming Score  \
# 0           NaN                   2                -10.00
# 1           NaN                   0                -40.00
# 2           NaN                   1                -68.00
# 3           NaN                   1                -68.00
# 4           NaN                  37                  1.12
#
#                                         MessageDescr  \
# 0  https://www.facebook.com/102726128134068/posts...
# 1  https://www.facebook.com/102726128134068/posts...
# 2  El miércoles, introducirán en el #Congreso el ...
# 3  El secretario del Ejército de EE.UU. #RyanMcCa...
# 4   As many of you know about Diego’s story and s...
#
#                                          MessageOnly
# 0  https://www.facebook.com/102726128134068/posts...
# 1  https://www.facebook.com/102726128134068/posts...
# 2  El miércoles, introducirán en el #Congreso el ...
# 3  El secretario del Ejército de EE.UU. #RyanMcCa...
# 4   As many of you know about Diego’s story and s...
#
# [5 rows x 39 columns]

# %%
pol.head()
# Out:
#    Unnamed: 0                   Group Name                 User Name  \
# 0         467   Latinos for Joe Biden 2020             LatinosforJoe
# 1         908  Mexican Americans For Biden  MexicanAmericansForBiden
# 2        1035   Latinos for Joe Biden 2020             LatinosforJoe
# 3        1188            Latinos Con Biden           LatinosConBiden
# 4        2090   Latinos for Joe Biden 2020             LatinosforJoe
#
#        Facebook Id  Likes at Posting                  Created          Type  \
# 0  121155365229796            1597.0  2020-08-27 17:01:14 EDT          Link
# 1  100921535039507               NaN  2020-09-09 17:31:43 EDT  Native Video
# 2  121155365229796            1591.0  2020-08-25 17:05:08 EDT          Link
# 3  101127554954870            1254.0  2020-10-13 20:35:48 EDT          Link
# 4  121155365229796            2486.0  2020-10-27 18:23:49 EDT          Link
#
#    Likes  Comments  Shares  ...  Image Text  \
# 0     97        13      14  ...         NaN
# 1     26         6       6  ...         NaN
# 2     36         6       3  ...         NaN
# 3     32         1       5  ...         NaN
# 4      4         3       0  ...         NaN
#
#                                            Link Text  \
# 0  Biden, Harris Condemn Violent Protests, Accuse...
# 1                                The Lincoln Project
# 2  Trump’s Scare Tactics Aren’t Working on Women ...
# 3  Entrevista exclusiva: Joe Biden promete luchar...
# 4                                         Get Access
#
#                                          Description  Sponsor Id  \
# 0  The Trump campaign has attempted to simultaneo...         NaN
# 1  Trump knew it was worse than the flu. \n\nTrum...         NaN
# 2  North of Charlotte, N.C., voters of both parti...         NaN
# 3  Como parte de su plan para Puerto Rico, el can...         NaN
# 4  Connect With UsContact UsSubscribeRSS FeedsApp...         NaN
#
#    Sponsor Name  Total Interactions Overperforming Score  \
# 0           NaN                 136                 1.35
# 1           NaN                  62                -1.35
# 2           NaN                  52                -1.60
# 3           NaN                  41                 1.64
# 4           NaN                   7               -10.57
#
#                                         MessageDescr  \
# 0  Just when you think it can't get worse. https:...
# 1  Trump knew COVID-19 was lethal and he intentio...
# 2  Trump needs women in the suburbs but this arti...
# 3  “Tres años después de María, todavía tenemos q...
# 4  This is an amazing story of someone who is str...
#
#                                          MessageOnly     party
# 0  Just when you think it can't get worse. https:...  Democrat
# 1  Trump knew COVID-19 was lethal and he intentio...  Democrat
# 2  Trump needs women in the suburbs but this arti...  Democrat
# 3  “Tres años después de María, todavía tenemos q...  Democrat
# 4  This is an amazing story of someone who is str...  Democrat
#
# [5 rows x 35 columns]

# %%
news.head()
# Out:
#    Unnamed: 0                 Page Name         User Name      Facebook Id  \
# 0         447       El Diario de Juárez  eldiariodejuarez  128606507194600
# 1         534            CNN en Español             CNNee      89613772643
# 2         997  Univision 34 Los Angeles       Univision34     114529603527
# 3        1630       El Diario de Juárez  eldiariodejuarez  128606507194600
# 4        1666       El Diario de Juárez  eldiariodejuarez  128606507194600
#
#    Likes at Posting                  Created  Type  Likes  Comments  Shares  \
# 0          688500.0  2020-08-21 18:26:38 EDT  Link    500       834     276
# 1        13176291.0  2020-08-24 02:32:01 EDT  Link   2731       251     121
# 2          898635.0  2020-08-22 18:33:58 EDT  Link    268       398     274
# 3          689588.0  2020-08-27 16:33:04 EDT  Link    398        95      43
# 4          689733.0  2020-08-28 16:07:00 EDT  Link    499       117     199
#
#    ...  Sponsor Id  Sponsor Name  Total Interactions  \
# 0  ...         NaN           NaN               4,962
# 1  ...         NaN           NaN               4,321
# 2  ...         NaN           NaN               2,439
# 3  ...         NaN           NaN               1,507
# 4  ...         NaN           NaN               1,481
#
#    Total Interactions (weighted  —  Likes 1x Shares 1x Comments 1x Love 1x Wow 1x Haha 1x Sad 1x Angry 1x Care 1x )  \
# 0                                              4,962
# 1                                              4,321
# 2                                              2,439
# 3                                              1,507
# 4                                              1,481
#
#    Overperforming Score         clean_url       State  \
# 0                 12.47  eldiariodejuarez       Texas
# 1                 11.11             cnnee     Georgia
# 2                 14.52       univision34  California
# 3                  3.79  eldiariodejuarez       Texas
# 4                  3.72  eldiariodejuarez       Texas
#
#                                     Facebook  \
# 0  https://www.facebook.com/eldiariodejuarez
# 1             https://www.facebook.com/CNNee
# 2      https://www.facebook.com/Univision34/
# 3  https://www.facebook.com/eldiariodejuarez
# 4  https://www.facebook.com/eldiariodejuarez
#
#                                         MessageDescr  \
# 0  Al momento del crimen se encontraba en estado ...
# 1  "Soy venganza". Así fue como Robert Pattinson ...
# 2  El hispano cuenta que de repente dos hombres m...
# 3  Fue acusado en 1983 por la violación y asesina...
# 4  🔴 Entran pistoleros y disparan, sin mediar pal...
#
#                                          MessageOnly
# 0  Al momento del crimen se encontraba en estado ...
# 1  "Soy venganza". Así fue como Robert Pattinson ...
# 2  El hispano cuenta que de repente dos hombres m...
# 3  Fue acusado en 1983 por la violación y asesina...
# 4  🔴 Entran pistoleros y disparan, sin mediar pal...
#
# [5 rows x 38 columns]

# %%
pol.rename(columns = {'Group Name': 'name'}, inplace=True)
news.rename(columns = {'Page Name': 'name'}, inplace=True)

# %%
print(pol.name.nunique())
print(pol.name.unique())
# Out:
# 72
# ['Latinos for Joe Biden 2020' 'Mexican Americans For Biden'
#  'Latinos Con Biden' 'Cuban Americans for Joe Biden'
#  'NoCo Latinos for Biden' 'Republican National Hispanic Assembly'
#  'Latinos With Trump' 'Mexicans for Donald Trump'
#  'Latinos For Trump-El Paso'
#  'Republican National Hispanic Assembly - New York Chapter'
#  'Latinos For Trump en Espaol' 'Latinos con Donald J. Trump'
#  'Arizona Latino Republican Association' 'Latinos For Trump 2020'
#  'Los Angeles Hispanic Republican Club' 'Mexican Chicas For Trump'
#  "New Mexico's Hispanic For Trump"
#  'Republican Hispanic Citizens in Action'
#  'This is why Trump is good for Mexico and Mexicans' 'Latinas For Trump'
#  'Latinos for Trump in Lea County' 'Latinos for TRUMP CLUB'
#  'Latinos For Trump - Michigan' 'Latino National Republican Coalition'
#  'Republican National Hispanic Assembly of Miami-Dade County'
#  'Republican National Hispanic Assembly of Charlotte'
#  'Republican National Hispanic Assembly of Osceola County'
#  'Latinos For Trump -Georgia' 'Latinos Against Donald Trump'
#  'African Americans & Latinos for Biden & Harris'
#  'Cuban Americans & friends for Biden'
#  'Pennsylvania Latinos for Joe Biden' 'Latinos contra Trump'
#  'Latinos United Against  Donald Trump'
#  'Latinos Unidos Contra Donald Trump' 'Latinos Unidos contra Trump'
#  'Mexicans/Chicanos/Natives HATE Trump' 'DONALD TRUMP PARA HISPANOS'
#  'Latinos For Trump -California Group'
#  'Puertorican Republican and Latin Conservative Movement'
#  'Republican National Hispanic Assembly - Official Group'
#  'CARA - Cuban American Republican Alliance'
#  'Republican National Hispanic Assembly of Florida' 'Latinos For Trump.'
#  'Latino Republican National Federation'
#  'Latinos who support Donald Trump' 'Latinos for Trump'
#  'LATINOS FOR TRUMP OREGON' 'Texas Latinos/as Republican Group'
#  'Tarrant County Republican National Hispanic Assembly'
#  'Colombianos Y Latinoamericanos que apoyamos a Donald Trump'
#  'Latinos Blacks White Jewish - Trump Train & Trump Team'
#  'Chicanos For Trump' 'Kentucky republican latinos'
#  'LATINOS / HISPANICS WHO TRUST TRUMP!' 'Latinos / Latinas for TRUMP'
#  'Trump Para Los hispanos' 'Latinos por la Familia Trump'
#  'Latinos por Trump' 'Latinos for Trump 2020- Georgia/Florida'
#  'Mexican Americans for Trump' 'Latinos de la Florida con Donald Trump'
#  'TRUMP--LATINOS EXIGEN UNA VICTORIA APLASTANTE 2020'
#  'Latinos for Trump - Jacksonville'
#  'Latino National Republican Coalition - Houston Area'
#  'Latinos for Trump en Espaol'
#  'Latino National Republican Coalition of Maryland'
#  'Latinos For Trump Manatee area Group' 'Latinos 4 Trump'
#  'Hispanic Republicans - Republican National Hispanic Assembly of Cook'
#  'Latinos For Trump - Texas Group' 'Latinos por Donald Trump in Las Vegas']

# %%
print(type(com))
print(type(com['name']))
print(type(com.name))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %%
com.name.fillna(com['Group Name'], inplace = True)
print(len(com))
com.tail()
# Out:
# 1131
#       Unnamed: 0                         name Page or Account URL List State  \
# 1126     1064274        Latino Giving Houston                 NaN  NaN   NaN
# 1127     1064436        Latino Giving Houston                 NaN  NaN   NaN
# 1128     1064491  New York Latinos  (TV Show)                 NaN  NaN   NaN
# 1129     1064840          Latinos en New York                 NaN  NaN   NaN
# 1130     1064841          Latinos en New York                 NaN  NaN   NaN
#
#      state       Facebook Id                   Group Name         User Name  \
# 1126   NaN   461202987236203        Latino Giving Houston      LatinoGiving
# 1127   NaN   461202987236203        Latino Giving Houston      LatinoGiving
# 1128   NaN   211700918847373  New York Latinos  (TV Show)    newyorklatinos
# 1129   NaN  1444226155789217          Latinos en New York  latinosennewyork
# 1130   NaN  1444226155789217          Latinos en New York  latinosennewyork
#
#       Likes at Posting  ...  \
# 1126               NaN  ...
# 1127               NaN  ...
# 1128               NaN  ...
# 1129               NaN  ...
# 1130               NaN  ...
#
#                                              Final Link Image Text  \
# 1126  https://www.facebook.com/login/?next=https%3A%...        NaN
# 1127  https://www.facebook.com/login/?next=https%3A%...        NaN
# 1128                                                NaN        NaN
# 1129                                                NaN        NaN
# 1130                                                NaN        NaN
#
#                                               Link Text  \
# 1126                        Fe y Justicia Worker Center
# 1127  Tuesdays @2 with Brian Middleton, Fort Bend Co...
# 1128                  Simposio de las Fuerzas del Orden
# 1129  Agente latina de policía salvó la vida a su co...
# 1130  Despiden a policía de Georgia que golpeó repet...
#
#                                             Description  Sponsor Id  \
# 1126  Rafael Pantoja is a police officer with the Ho...         NaN
# 1127  Join us for a look into the Crime Victims Resp...         NaN
# 1128  La Asociación de las Fuerzas del Orden Interna...         NaN
# 1129  Claudia Apolinar es madre, trabajaba antes com...         NaN
# 1130  Una revisión del incidente arrojó que el agent...         NaN
#
#       Sponsor Name  Total Interactions  Overperforming Score  \
# 1126           NaN                   2                 -0.88
# 1127           NaN                   0                -20.00
# 1128           NaN                   0               -370.00
# 1129           NaN                   0                -42.00
# 1130           NaN                   0                -42.00
#
#                                            MessageDescr  \
# 1126  2013 Latino Giving Grantee Rafael Pantoja is a...
# 1127  2016 Latino Giving Grantee Join us for a look ...
# 1128  La Asociación de las Fuerzas del Orden Interna...
# 1129  https://www.telemundo.com/noticias/noticias-te...
# 1130  https://www.telemundo.com/noticias/edicion-not...
#
#                                             MessageOnly
# 1126  2013 Latino Giving Grantee Rafael Pantoja is a...
# 1127  2016 Latino Giving Grantee Join us for a look ...
# 1128  La Asociación de las Fuerzas del Orden Interna...
# 1129  https://www.telemundo.com/noticias/noticias-te...
# 1130  https://www.telemundo.com/noticias/edicion-not...
#
# [5 rows x 39 columns]

# %%
print(type(com))
print(type(com.name))
temp = com.name.tolist()
print(type(temp))
print(type(temp[0]))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# <class 'list'>
# <class 'str'>

# %%
cond = []
for x in temp:
    if 'Trump' in x:
        cond.append(x)
    if 'Democr' in x:
        cond.append(x)
    if 'Repub' in x:
        cond.append(x)
    if 'repub' in x:
        cond.append(x)

# %%
print(len(cond))
#v is index
v = []
for x in range(len(com['name'])):
    if com['name'][x] in cond:
        v.append(x)
print 

print(len(v))
for i in v:
    pol = pol.append(com.iloc[i])

com.drop(
    labels = v,
    axis =0,
    inplace=True
)

pol.tail()
print(com.name.unique())
# Out:
# 111
# 111
# ['Hispanos unidos en New York (H.U.N.Y)' 'Hispanos en Columbus Ohio'
#  'Hispanos en Oklahoma' 'HISPANOS EN ST LOUIS MISSOURI'
#  'Hispanos V.I.P. de Virginia' 'Hispanos en West Palm Beach FL'
#  'Hispanos en New York'
#  'Comunidad Latina de New Jersey - Latino Community of NJ'
#  'SAN BERNARDINO SWAPMEET LATINO' 'Latino Outdoors Washington'
#  'Mundo Latino Network Group Nebraska, Iowa y South Dakota'
#  'Utah Latino Empowerment OutReach Network' 'LATIN EVENTS SOUTH CAROLINA'
#  'Columbus Ohio - Comunidad Latina y Trabajo Disponible'
#  'Boston, Massachusetts Fuerza Latina, Trabajos, Promotiones, Apartamentos'
#  'la yarda latina de carlsbad nm' 'RED LATINA NEW YORK'
#  'Hispanic Heritage Matters in Texas'
#  'CASAS DE CONSTRUCCIÓN NUEVA EN OKLAHOMA- ALEJANDRO LAURENS REALTOR'
#  'Ticos en New Jersey' 'Ticos en Miami Dade' 'Ticos En Miami'
#  'Boricuas en San Antonio,TX' 'Boricuas en Dallas Y Fort Worth'
#  'BORICUAS 100 X 35 EN NORTH CAROLINA' 'BORICUAS EN KISSIMMEE Y ORLANDO'
#  'Boricuas en Orlando VIP' 'Boricuas levantandose  en Cleveland, Ohio'
#  'Boricuas Profesionales en Dallas y Ft. Worth -  Texas'
#  'Boricuas en Miami' 'BORICUAS EN CHARLOTTE NORTH CAROLINA'
#  'Boricuas en Killeen Texas' 'BORICUAS EN WISCONSIN' 'PR NORTH CAROLINA'
#  'Servicios Boricuas en Maryland' 'JANGUEO BORICUA Miami'
#  'Soy Boricua en DFW' 'Nicas Autoconvocados en Miami'
#  'Nicas Unidos En Miami' 'Nicas en San Francisco' 'Nicas en Miami'
#  'Argentinos En New Jersey 🇦🇷 Oficial' 'Argentinos en San Diego CA'
#  'Argentinos en Dallas Texas'
#  'Argentinos en San Diego profesionales y comercio' 'Venezolanos en Miami'
#  'Venezolanos viviendo en Miami ' 'Venezolanos en Orlando'
#  'Venezolanos En Orlando' 'Venezolanos en Chicago'
#  'Venezolanos en Dallas - Fort Worth' 'Venezolanos en Kissimmee'
#  'Venezolanos en Houston Tx' 'Venezolanos en new jersey'
#  'venezolanos en Orlando and Kissimmee'
#  'Venezolanos Unidos en D.C. Maryland & Virginia'
#  'Venezolanos en Washington D.C, Virginia and Maryland'
#  'Cuantos venezolanos hay en New York?' 'Venezolanos En Chicago 🇺🇸🇻🇪'
#  'Venezolanos en San Francisco'
#  'VENEZOLANOS EN EL TRI-STATE (OHIO, INDIANA, KENTUCKY)'
#  'VENEZOLANOS EN TULSA-OKLAHOMA'
#  'Venezolanos del Area de la Bahia de San Francisco'
#  'VENEZOLANOS UNIDOS EN OKLAHOMA' 'Venezolanos en Miami '
#  'VENEZOLANOS EN MIAMI,FLORIDA' 'VENEZOLANOS EN PENNSYLVANIA'
#  'Venezolanos viviendo en Frederick, Maryland, USA'
#  'Venezolanos en North Dallas - Addison - Carrolton - Famers Branch Etc'
#  'Venezolanos en Paterson New Jersey y sus alrededores'
#  'Venezolanos en north carolina (ventas)'
#  'Venezolanos viviendo en Miami  Grupo de Mundo24'
#  'Venezolanos en Virginia, Maryland y Washington 🇻🇪🇺🇸'
#  'Peruanos en DC, Maryland & Virginia (DMV)' 'SALVADOREÑOS EN HOUSTON®'
#  'Guatemaltecos en Miami' 'Guatemaltecos en Rhode Island'
#  'Hondureños en Dallas' '🇭🇳Hondureños en Houston🇭🇳'
#  'Hondureños En Houston Texas' 'Hondureños Unidos En New Jersey'
#  'Hondureños en Dallas Fort  Worth' 'HONDUREÑOS EN HOUSTON, TX.'
#  'hondureños viviendo en miami: compra vende regala intercambia'
#  'SALVADOREñOS EN LONG ISLAND Y NEW YORK' 'Mexicanos en Texas 🇲🇽🇺🇸'
#  'Mexicanos unidos de utah' 'Mexicanos en st Louis Missouri'
#  'Mexicanos en washington virginia !!' 'Mexicanos En North Carolina'
#  'MEXICANOS EN TENNESSEE' 'Mexicanos en Chicago' 'Mexicanos en Dallas'
#  'Mexicanos en San Francisco California' 'Cubanos en miami,fl'
#  'CUBANOS EN HOUSTON' 'CUBANOS EN ORLANDO,FLORIDA' 'Cubanos en Chicago'
#  'Cubanos en Somos Miami' 'Cubanos en Dallas' '+ Cubanos en Miami 🇨🇺'
#  'Cubanos En Dallas'
#  'CUBANOS Y LATINOS RESIDENTES EN MIAMI BEACH. FLORIDA. UNETE.'
#  "Cubans and Hispanics who grew up in Miami during the 60's and 70's"
#  'Dominicanos en Miami Y USA' 'Dominicanos en Orlando.'
#  'Dominicanos en las vegas nv' 'Asociación de Ecuatorianos DFW'
#  'Ecuatorianos en Orlando' 'ECUATORIANOS en NEW YORK (NY)'
#  'ECUATORIANOS EN NEW YORK &  NEW JERSEY'
#  'ECUATORIANOS EN LA CIUDAD DE NEW YORK'
#  'Ecuatorianos en Virginia-DC-Maryland' 'ECUATORIANOS EN NEW YORK'
#  'Ecuatorianos en La Florida' 'Mexicanos en California 🇲🇽🇺🇸'
#  'Mexicanos en California USA u otros estados' 'Mexicanos En Connecticut'
#  'MEXICANOS Y CENTRO AMERICANOS EN LAS VEGAS'
#  'Latinos en Florida, Broward & Miami Dade'
#  'Latinos en Compro y Vendo en St Louis Missouri' 'LATINOS EN NEW YORK'
#  'TRABAJOS PARA LATINOS - HOUSTON'
#  'latinos en maryland , washington dc y virginia '
#  'LATINOS FOR TRUMP OREGON' 'Latinos en New Jersey (NJ) y New York (NY)'
#  'Latinos en New Jersey y areas cercanas' '☀️ Latinos en Miami 🌴'
#  'Latinos en Oregon' 'latinos en New York' 'Latinos en Texas'
#  'Latinos Unidos En Massachusetts'
#  'TRABAJO PARA LATINOS  EN ST LOUIS MISSOURI' 'Pennsylvania Latinos'
#  'Peruanos Unidos en DC, Maryland & Virginia'
#  'peruanos  en new  york y new jersey  de todas las sangres'
#  'Peruanos en New Jersey' 'Peruanos en Massachusetts' 'Peruanos en Utah'
#  'Peruanos de Corazon NY NJ' 'PERUANOS EN FLORIDA' 'venezolanos En Austin'
#  'Venezolanos en Colorado' 'Venezolanos en Charlotte NC'
#  'Grupo de Venezolanos Activos en Georgia' 'Venezolanos en Nashville'
#  'Venezolanos en La Florida' 'Ciudadanos Venezolanos en Atlanta.'
#  'Venezolanos en Florida.' 'Venezolanos Solidarios En Kendall'
#  'Venezolanos En Tampa Bay Oficial' 'Venezolanos en NY'
#  'Venezolanos en Boston' 'Pennsylvania Latinos for Joe Biden'
#  'Oakland Latinos United (Unidos)' 'Acción y Alertas Latinos Wisconsin'
#  'Latinos en Charlotte North Carolina'
#  'Chilenos Latinos unidos en NY NJ PA OH by Orlando Abarzua ...'
#  'latinos Unidos❤en houston tx' 'Latinos en todo Massachusetts USA'
#  'Latinos in Tennessee' 'Latinos en Orlando Florida' 'Latinos en Missouri'
#  'LGBTQ LATINOS, BOSTON, RHODE ISLAND, CONNECTICUT, NEW YORK Y NEW JERSEY.'
#  'Latinos San Diego/Tijuana'
#  'Buffalo, New York, West Side Latinos Stand Up !!!!!!'
#  'The Washington DC Latinos!' 'Latinos Unidos En South Carolina'
#  'Profesionales latinos en Kissimmee y Orlando anunciate'
#  'Latinos en Dallas - Fort Worth' 'Las Vegas Hispanos y Latinos'
#  'Latinos En Atlanta Official' 'Marketing  Latinos en Atlanta  ( USA )'
#  'Latinos en SALT LAKE CITY' 'latinos unidos de cincinnati'
#  'TRABAJO EN SAVANNAH PARA LATINOS' 'Latinos en SWFL'
#  'Latinos en Fayetteville NC'
#  'Latinos en los Angeles California compra y venta'
#  'Latinos en Tampa Bay official'
#  'Institute of  Hispanic Culture of Houston' 'Texas Latino Conservatives'
#  'Latino Mix Houston' 'Latino Mix Chicago' 'La Mesa Boricua de Florida'
#  'Latino Mix Dallas' 'Latinos En Michigan TV'
#  'VACOLAO - Virginia Coalition of Latino Organizations'
#  'San Diego Latino Film Festival' 'Venezolanos En Orlando VEO'
#  'Chicago Boricua Resistance' 'Chicago Latino Film Festival'
#  'West Michigan Hispanic Chamber of Commerce' 'Latino News of Tennessee'
#  'Latino Mix Phoenix' 'Latin New York' 'South Carolina Latina Project'
#  'New York Latino Film Festival' 'Nebraska Latino American Commission'
#  'National Hispanic Institute at San Antonio'
#  'El Sol Latino Newspaper Miami' 'Venezolanos En Nebraska'
#  'Diosa Latina New York' 'Cubanos en Houston' 'Latino Giving Houston'
#  'New York Latinos  (TV Show)' 'Latinos en New York']

# %%
print(len(com))
print(com.name.unique())
temp = []
temp = com.name.unique()
print(len(temp))
# Out:
# 1020
# ['Hispanos unidos en New York (H.U.N.Y)' 'Hispanos en Columbus Ohio'
#  'Hispanos en Oklahoma' 'HISPANOS EN ST LOUIS MISSOURI'
#  'Hispanos V.I.P. de Virginia' 'Hispanos en West Palm Beach FL'
#  'Hispanos en New York'
#  'Comunidad Latina de New Jersey - Latino Community of NJ'
#  'SAN BERNARDINO SWAPMEET LATINO' 'Latino Outdoors Washington'
#  'Mundo Latino Network Group Nebraska, Iowa y South Dakota'
#  'Utah Latino Empowerment OutReach Network' 'LATIN EVENTS SOUTH CAROLINA'
#  'Columbus Ohio - Comunidad Latina y Trabajo Disponible'
#  'Boston, Massachusetts Fuerza Latina, Trabajos, Promotiones, Apartamentos'
#  'la yarda latina de carlsbad nm' 'RED LATINA NEW YORK'
#  'Hispanic Heritage Matters in Texas'
#  'CASAS DE CONSTRUCCIÓN NUEVA EN OKLAHOMA- ALEJANDRO LAURENS REALTOR'
#  'Ticos en New Jersey' 'Ticos en Miami Dade' 'Ticos En Miami'
#  'Boricuas en San Antonio,TX' 'Boricuas en Dallas Y Fort Worth'
#  'BORICUAS 100 X 35 EN NORTH CAROLINA' 'BORICUAS EN KISSIMMEE Y ORLANDO'
#  'Boricuas en Orlando VIP' 'Boricuas levantandose  en Cleveland, Ohio'
#  'Boricuas Profesionales en Dallas y Ft. Worth -  Texas'
#  'Boricuas en Miami' 'BORICUAS EN CHARLOTTE NORTH CAROLINA'
#  'Boricuas en Killeen Texas' 'BORICUAS EN WISCONSIN' 'PR NORTH CAROLINA'
#  'Servicios Boricuas en Maryland' 'JANGUEO BORICUA Miami'
#  'Soy Boricua en DFW' 'Nicas Autoconvocados en Miami'
#  'Nicas Unidos En Miami' 'Nicas en San Francisco' 'Nicas en Miami'
#  'Argentinos En New Jersey 🇦🇷 Oficial' 'Argentinos en San Diego CA'
#  'Argentinos en Dallas Texas'
#  'Argentinos en San Diego profesionales y comercio' 'Venezolanos en Miami'
#  'Venezolanos viviendo en Miami ' 'Venezolanos en Orlando'
#  'Venezolanos En Orlando' 'Venezolanos en Chicago'
#  'Venezolanos en Dallas - Fort Worth' 'Venezolanos en Kissimmee'
#  'Venezolanos en Houston Tx' 'Venezolanos en new jersey'
#  'venezolanos en Orlando and Kissimmee'
#  'Venezolanos Unidos en D.C. Maryland & Virginia'
#  'Venezolanos en Washington D.C, Virginia and Maryland'
#  'Cuantos venezolanos hay en New York?' 'Venezolanos En Chicago 🇺🇸🇻🇪'
#  'Venezolanos en San Francisco'
#  'VENEZOLANOS EN EL TRI-STATE (OHIO, INDIANA, KENTUCKY)'
#  'VENEZOLANOS EN TULSA-OKLAHOMA'
#  'Venezolanos del Area de la Bahia de San Francisco'
#  'VENEZOLANOS UNIDOS EN OKLAHOMA' 'Venezolanos en Miami '
#  'VENEZOLANOS EN MIAMI,FLORIDA' 'VENEZOLANOS EN PENNSYLVANIA'
#  'Venezolanos viviendo en Frederick, Maryland, USA'
#  'Venezolanos en North Dallas - Addison - Carrolton - Famers Branch Etc'
#  'Venezolanos en Paterson New Jersey y sus alrededores'
#  'Venezolanos en north carolina (ventas)'
#  'Venezolanos viviendo en Miami  Grupo de Mundo24'
#  'Venezolanos en Virginia, Maryland y Washington 🇻🇪🇺🇸'
#  'Peruanos en DC, Maryland & Virginia (DMV)' 'SALVADOREÑOS EN HOUSTON®'
#  'Guatemaltecos en Miami' 'Guatemaltecos en Rhode Island'
#  'Hondureños en Dallas' '🇭🇳Hondureños en Houston🇭🇳'
#  'Hondureños En Houston Texas' 'Hondureños Unidos En New Jersey'
#  'Hondureños en Dallas Fort  Worth' 'HONDUREÑOS EN HOUSTON, TX.'
#  'hondureños viviendo en miami: compra vende regala intercambia'
#  'SALVADOREñOS EN LONG ISLAND Y NEW YORK' 'Mexicanos en Texas 🇲🇽🇺🇸'
#  'Mexicanos unidos de utah' 'Mexicanos en st Louis Missouri'
#  'Mexicanos en washington virginia !!' 'Mexicanos En North Carolina'
#  'MEXICANOS EN TENNESSEE' 'Mexicanos en Chicago' 'Mexicanos en Dallas'
#  'Mexicanos en San Francisco California' 'Cubanos en miami,fl'
#  'CUBANOS EN HOUSTON' 'CUBANOS EN ORLANDO,FLORIDA' 'Cubanos en Chicago'
#  'Cubanos en Somos Miami' 'Cubanos en Dallas' '+ Cubanos en Miami 🇨🇺'
#  'Cubanos En Dallas'
#  'CUBANOS Y LATINOS RESIDENTES EN MIAMI BEACH. FLORIDA. UNETE.'
#  "Cubans and Hispanics who grew up in Miami during the 60's and 70's"
#  'Dominicanos en Miami Y USA' 'Dominicanos en Orlando.'
#  'Dominicanos en las vegas nv' 'Asociación de Ecuatorianos DFW'
#  'Ecuatorianos en Orlando' 'ECUATORIANOS en NEW YORK (NY)'
#  'ECUATORIANOS EN NEW YORK &  NEW JERSEY'
#  'ECUATORIANOS EN LA CIUDAD DE NEW YORK'
#  'Ecuatorianos en Virginia-DC-Maryland' 'ECUATORIANOS EN NEW YORK'
#  'Ecuatorianos en La Florida' 'Mexicanos en California 🇲🇽🇺🇸'
#  'Mexicanos en California USA u otros estados' 'Mexicanos En Connecticut'
#  'MEXICANOS Y CENTRO AMERICANOS EN LAS VEGAS'
#  'Latinos en Florida, Broward & Miami Dade'
#  'Latinos en Compro y Vendo en St Louis Missouri' 'LATINOS EN NEW YORK'
#  'TRABAJOS PARA LATINOS - HOUSTON'
#  'latinos en maryland , washington dc y virginia '
#  'LATINOS FOR TRUMP OREGON' 'Latinos en New Jersey (NJ) y New York (NY)'
#  'Latinos en New Jersey y areas cercanas' '☀️ Latinos en Miami 🌴'
#  'Latinos en Oregon' 'latinos en New York' 'Latinos en Texas'
#  'Latinos Unidos En Massachusetts'
#  'TRABAJO PARA LATINOS  EN ST LOUIS MISSOURI' 'Pennsylvania Latinos'
#  'Peruanos Unidos en DC, Maryland & Virginia'
#  'peruanos  en new  york y new jersey  de todas las sangres'
#  'Peruanos en New Jersey' 'Peruanos en Massachusetts' 'Peruanos en Utah'
#  'Peruanos de Corazon NY NJ' 'PERUANOS EN FLORIDA' 'venezolanos En Austin'
#  'Venezolanos en Colorado' 'Venezolanos en Charlotte NC'
#  'Grupo de Venezolanos Activos en Georgia' 'Venezolanos en Nashville'
#  'Venezolanos en La Florida' 'Ciudadanos Venezolanos en Atlanta.'
#  'Venezolanos en Florida.' 'Venezolanos Solidarios En Kendall'
#  'Venezolanos En Tampa Bay Oficial' 'Venezolanos en NY'
#  'Venezolanos en Boston' 'Pennsylvania Latinos for Joe Biden'
#  'Oakland Latinos United (Unidos)' 'Acción y Alertas Latinos Wisconsin'
#  'Latinos en Charlotte North Carolina'
#  'Chilenos Latinos unidos en NY NJ PA OH by Orlando Abarzua ...'
#  'latinos Unidos❤en houston tx' 'Latinos en todo Massachusetts USA'
#  'Latinos in Tennessee' 'Latinos en Orlando Florida' 'Latinos en Missouri'
#  'LGBTQ LATINOS, BOSTON, RHODE ISLAND, CONNECTICUT, NEW YORK Y NEW JERSEY.'
#  'Latinos San Diego/Tijuana'
#  'Buffalo, New York, West Side Latinos Stand Up !!!!!!'
#  'The Washington DC Latinos!' 'Latinos Unidos En South Carolina'
#  'Profesionales latinos en Kissimmee y Orlando anunciate'
#  'Latinos en Dallas - Fort Worth' 'Las Vegas Hispanos y Latinos'
#  'Latinos En Atlanta Official' 'Marketing  Latinos en Atlanta  ( USA )'
#  'Latinos en SALT LAKE CITY' 'latinos unidos de cincinnati'
#  'TRABAJO EN SAVANNAH PARA LATINOS' 'Latinos en SWFL'
#  'Latinos en Fayetteville NC'
#  'Latinos en los Angeles California compra y venta'
#  'Latinos en Tampa Bay official'
#  'Institute of  Hispanic Culture of Houston' 'Texas Latino Conservatives'
#  'Latino Mix Houston' 'Latino Mix Chicago' 'La Mesa Boricua de Florida'
#  'Latino Mix Dallas' 'Latinos En Michigan TV'
#  'VACOLAO - Virginia Coalition of Latino Organizations'
#  'San Diego Latino Film Festival' 'Venezolanos En Orlando VEO'
#  'Chicago Boricua Resistance' 'Chicago Latino Film Festival'
#  'West Michigan Hispanic Chamber of Commerce' 'Latino News of Tennessee'
#  'Latino Mix Phoenix' 'Latin New York' 'South Carolina Latina Project'
#  'New York Latino Film Festival' 'Nebraska Latino American Commission'
#  'National Hispanic Institute at San Antonio'
#  'El Sol Latino Newspaper Miami' 'Venezolanos En Nebraska'
#  'Diosa Latina New York' 'Cubanos en Houston' 'Latino Giving Houston'
#  'New York Latinos  (TV Show)' 'Latinos en New York']
# 207

# %%
#column 1 = group, column 2 = 'name' column 3 = 'frequency'

group = []
name = []
frequency = []
#community
for x in range(len(com)):
    
    # new row
    if com['name'].iloc[x] not in name:
        #append new name
        name.append(com['name'].iloc[x])
        #create new row
        group.append('Community')
        #give value of 1
        frequency.append(1)
    else:
        v = name.index(com['name'].iloc[x])
        frequency[v] +=1

#political
for x in range(len(pol)):
    if pol['name'].iloc[x] not in name:
        #append new name
        name.append(pol['name'].iloc[x])
        #create new row
        group.append('Political')
        #give value of 1
        frequency.append(1)
    else:
        v = name.index(pol['name'].iloc[x])
        frequency[v] +=1
        
#news
for x in range(len(news)):
    if news['name'].iloc[x] not in name:
        #append new name
        name.append(news['name'].iloc[x])
        #create new row
        group.append('News')
        #give value of 1
        frequency.append(1)
    else:
        v = name.index(news['name'].iloc[x])
        frequency[v] +=1

dict = {'name': name, 'group': group, 'frequency': frequency}
df = pd.DataFrame(dict)
df
# Out:
#                                       name      group  frequency
# 0    Hispanos unidos en New York (H.U.N.Y)  Community          6
# 1                Hispanos en Columbus Ohio  Community          1
# 2                     Hispanos en Oklahoma  Community          1
# 3            HISPANOS EN ST LOUIS MISSOURI  Community          2
# 4              Hispanos V.I.P. de Virginia  Community          1
# ..                                     ...        ...        ...
# 501                Latin Opinion Baltimore       News          4
# 502                                WORA-TV       News          1
# 503                  Periódico El Oriental       News          1
# 504                            Unica Radio       News          1
# 505                KUNP Univision Portland       News          1
#
# [506 rows x 3 columns]

# %%
import seaborn as sns

sns.catplot(x='group', y = 'frequency', data =df, dodge=True, kind = 'violin', aspect =2)

# %%
sns.catplot(x='frequency', y ='group', data=df, kind ='strip')

# %%
sns.catplot(x='frequency', y ='group', data=df, kind ='violin')

# %%
#Levene Test
import scipy.stats as stats
#establish three groups
group_col = []
group_pol = []
group_new = []
for x in range(len(df)):
    if df['group'][x] == "Community":
        group_col.append(df['frequency'][x])
    if df['group'][x] == "Political":
        group_pol.append(df['frequency'][x])
    if df['group'][x] == "News":
        group_new.append(df['frequency'][x])
        
stats.levene(group_col, group_pol, group_new, center='median')
# Out:
# LeveneResult(statistic=10.931615699479503, pvalue=2.252898054441013e-05)

# %%
stats.levene(group_col, group_pol, group_new, center='mean')
# Out:
# LeveneResult(statistic=17.78221141627812, pvalue=3.452045708702272e-08)

# %%
stats.f_oneway(group_col, group_pol, group_new)
# Out:
# F_onewayResult(statistic=13.198437043954778, pvalue=2.5901983981975515e-06)

# %%
stats.mannwhitneyu(group_col, group_pol)
# Out:
# MannwhitneyuResult(statistic=7206.5, pvalue=0.27284740444040323)

# %%
import numpy

numpy.mean(group_col)
numpy.sum(group_col)
# Out:
# 1031

# %%
numpy.mean(group_pol)
# Out:
# 8.986301369863014

# %%
numpy.mean(group_col)
# Out:
# 4.980676328502415

# %%
print(1031/5)
# Out:
# 206.2

# %%
numpy.sum(group_pol)
# Out:
# 656

# %%
numpy.sum(group_new)
# Out:
# 2690
