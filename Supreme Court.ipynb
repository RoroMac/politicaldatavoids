# %%
import pandas as pd

#readcsv file date
com = pd.read_csv("community/FB_groups_States_supreme_court.csv", sep= ",")
pol = pd.read_csv("political/Topics_FB_Political_Posts_per_partysupreme_court.csv", sep = ",")
news = pd.read_csv("news/FB_groups_News_Media_Outlets_supreme_court.csv", sep=",")

# %%
com.head()
# Out:
#    Unnamed: 0                                 name  \
# 0      929664  Latinos For Trump -California Group
# 1     1046083                                  NaN
#
#                                Page or Account URL                   List  \
# 0  https://www.facebook.com/groups/371686133500927  Latinos+EstadosGroups
# 1                                              NaN                    NaN
#
#         State       state      Facebook Id  \
# 0  California  California  371686133500927
# 1         NaN         NaN  305859026094125
#
#                             Group Name    User Name  Likes at Posting  ...  \
# 0  Latinos For Trump -California Group          NaN            3078.0  ...
# 1           Texas Latino Conservatives  TLCforTexas            4985.0  ...
#
#   Final Link Image Text  Link Text  \
# 0        NaN        NaN        Tad
# 1        NaN        NaN        NaN
#
#                                          Description  Sponsor Id  \
# 0  [https://www.realclearpolitics.com/video/2020/...         NaN
# 1                                                NaN         NaN
#
#    Sponsor Name  Total Interactions  Overperforming Score  \
# 0           NaN                   0                -70.00
# 1           NaN                  92                  1.64
#
#                                         MessageDescr  \
# 0   [https://www.realclearpolitics.com/video/2020...
# 1  HOUSTON – Texas Latino Conservatives issued th...
#
#                                          MessageOnly
# 0   [https://www.realclearpolitics.com/video/2020...
# 1  HOUSTON – Texas Latino Conservatives issued th...
#
# [2 rows x 39 columns]

# %%
pol.head()
# Out:
#    Unnamed: 0                                         Group Name  \
# 0        5787  Republican National Hispanic Assembly of Charl...
# 1        9918  Republican National Hispanic Assembly of Charl...
# 2        9928  Republican National Hispanic Assembly of Charl...
# 3       10593                                 Latinos For Trump.
# 4       15705          CARA - Cuban American Republican Alliance
#
#        User Name       Facebook Id  Likes at Posting                  Created  \
# 0  RNHACharlotte   127248570788974             472.0  2020-09-20 09:36:44 EDT
# 1  RNHACharlotte   127248570788974             474.0  2020-09-29 09:29:56 EDT
# 2  RNHACharlotte   127248570788974             470.0  2020-09-19 11:30:44 EDT
# 3            NaN  1674032616233446            1228.0  2020-10-03 09:05:39 EDT
# 4            NaN  1745713449085734            3931.0  2020-10-12 17:15:15 EDT
#
#    Type  Likes  Comments  Shares  ...  Image Text  \
# 0  Link      2         0       0  ...         NaN
# 1  Link      0         0       0  ...         NaN
# 2  Link      0         0       0  ...         NaN
# 3  Link      6         1       0  ...         NaN
# 4  Link      3         1       0  ...         NaN
#
#                                            Link Text  \
# 0  Pro-Life Leaders Urge Trump to ‘Move Quickly’ ...
# 1  Supreme Court 'Game Changer' – Christian Leade...
# 2  Ted Cruz urges Senate to fill Ruth Bader Ginsb...
# 3  The Michigan Supreme Court finally clipped Gov...
# 4  Voters Strongly Reject Religious Litmus Test f...
#
#                                          Description  Sponsor Id  \
# 0  Pro-life leaders and abortion rights advocates...         NaN
# 1  Christian and conservative leaders are praisin...         NaN
# 2  Sen. Ted Cruz on Friday urged his fellow lawma...         NaN
# 3  Michigan's Democrat governor Gretchen Whitmer ...         NaN
# 4  Some Democratic opponents of U.S. Supreme Cour...         NaN
#
#    Sponsor Name  Total Interactions  Overperforming Score  \
# 0           NaN                   2                  -0.8
# 1           NaN                   0                 -20.0
# 2           NaN                   0                 -20.0
# 3           NaN                   7                  -3.0
# 4           NaN                   4                  -9.0
#
#                                         MessageDescr  \
# 0  #Pro-Life leaders want President #Trump to mov...
# 1  “#Conservative Christians need to understand t...
# 2  Ted Cruz: "A four-four court that is equally d...
# 3   Michigan's Democrat governor Gretchen Whitmer...
# 4  Democratic Socialist opponents of U.S. Supreme...
#
#                                          MessageOnly       party
# 0  #Pro-Life leaders want President #Trump to mov...  Republican
# 1  “#Conservative Christians need to understand t...  Republican
# 2  Ted Cruz: "A four-four court that is equally d...  Republican
# 3   Michigan's Democrat governor Gretchen Whitmer...  Republican
# 4  Democratic Socialist opponents of U.S. Supreme...  Republican
#
# [5 rows x 35 columns]

# %%
news.head()
# Out:
#    Unnamed: 0                  Page Name       User Name  Facebook Id  \
# 0      188295  Democracy Now! en español  democracynowes  58670196103
# 1      211751  Democracy Now! en español  democracynowes  58670196103
# 2      291612  Democracy Now! en español  democracynowes  58670196103
# 3      390861  Democracy Now! en español  democracynowes  58670196103
# 4      437361  Democracy Now! en español  democracynowes  58670196103
#
#    Likes at Posting                  Created  Type  Likes  Comments  Shares  \
# 0           29044.0  2020-09-25 17:30:40 EDT  Link     43         1      18
# 1           29048.0  2020-09-22 16:11:34 EDT  Link      2         0       4
# 2           29037.0  2020-10-07 21:00:42 EDT  Link      5         0       5
# 3           29042.0  2020-10-16 19:00:34 EDT  Link      0         0       2
# 4           29001.0  2020-10-29 16:30:09 EDT  Link      0         0       0
#
#    ...  Sponsor Id  Sponsor Name  Total Interactions  \
# 0  ...         NaN           NaN                  77
# 1  ...         NaN           NaN                  11
# 2  ...         NaN           NaN                  21
# 3  ...         NaN           NaN                  11
# 4  ...         NaN           NaN                   0
#
#    Total Interactions (weighted  —  Likes 1x Shares 1x Comments 1x Love 1x Wow 1x Haha 1x Sad 1x Angry 1x Care 1x )  \
# 0                                                 77
# 1                                                 11
# 2                                                 21
# 3                                                 11
# 4                                                  0
#
#    Overperforming Score       clean_url     State  \
# 0                  1.83  democracynowes  New York
# 1                 -3.82  democracynowes  New York
# 2                 -1.95  democracynowes  New York
# 3                 -3.91  democracynowes  New York
# 4                -82.00  democracynowes  New York
#
#                                   Facebook  \
# 0  https://www.facebook.com/democracynowes
# 1  https://www.facebook.com/democracynowes
# 2  https://www.facebook.com/democracynowes
# 3  https://www.facebook.com/democracynowes
# 4  https://www.facebook.com/democracynowes
#
#                                         MessageDescr  \
# 0  El presidente Donald Trump visitó la Corte Sup...
# 1  En Washington, D.C., los republicanos se prepa...
# 2  Los jueces Clarence Thomas y Samuel Alito se h...
# 3  El jueves concluyeron las audiencias de confir...
# 4  La Corte Suprema de Estados Unidos ha dictamin...
#
#                                          MessageOnly
# 0  El presidente Donald Trump visitó la Corte Sup...
# 1  En Washington, D.C., los republicanos se prepa...
# 2  Los jueces Clarence Thomas y Samuel Alito se h...
# 3  El jueves concluyeron las audiencias de confir...
# 4  La Corte Suprema de Estados Unidos ha dictamin...
#
# [5 rows x 38 columns]

# %%
pol.rename(columns = {'Group Name': 'name'}, inplace=True)
news.rename(columns = {'Page Name': 'name'}, inplace=True)

# %%
print(pol.name.nunique())
print(pol.name.unique())
# Out:
# 5
# ['Republican National Hispanic Assembly of Charlotte' 'Latinos For Trump.'
#  'CARA - Cuban American Republican Alliance'
#  'Republican National Hispanic Assembly - Official Group'
#  'Latinos For Trump -California Group']

# %%
print(type(com))
print(type(com['name']))
print(type(com.name))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %%
com.name.fillna(com['Group Name'], inplace = True)
print(len(com))
com.tail()
# Out:
# 2
#    Unnamed: 0                                 name  \
# 0      929664  Latinos For Trump -California Group
# 1     1046083           Texas Latino Conservatives
#
#                                Page or Account URL                   List  \
# 0  https://www.facebook.com/groups/371686133500927  Latinos+EstadosGroups
# 1                                              NaN                    NaN
#
#         State       state      Facebook Id  \
# 0  California  California  371686133500927
# 1         NaN         NaN  305859026094125
#
#                             Group Name    User Name  Likes at Posting  ...  \
# 0  Latinos For Trump -California Group          NaN            3078.0  ...
# 1           Texas Latino Conservatives  TLCforTexas            4985.0  ...
#
#   Final Link Image Text  Link Text  \
# 0        NaN        NaN        Tad
# 1        NaN        NaN        NaN
#
#                                          Description  Sponsor Id  \
# 0  [https://www.realclearpolitics.com/video/2020/...         NaN
# 1                                                NaN         NaN
#
#    Sponsor Name  Total Interactions  Overperforming Score  \
# 0           NaN                   0                -70.00
# 1           NaN                  92                  1.64
#
#                                         MessageDescr  \
# 0   [https://www.realclearpolitics.com/video/2020...
# 1  HOUSTON – Texas Latino Conservatives issued th...
#
#                                          MessageOnly
# 0   [https://www.realclearpolitics.com/video/2020...
# 1  HOUSTON – Texas Latino Conservatives issued th...
#
# [2 rows x 39 columns]

# %%
print(type(com))
print(type(com.name))
temp = com.name.tolist()
print(type(temp))
print(type(temp[0]))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# <class 'list'>
# <class 'str'>

# %%
cond = []
for x in temp:
    if 'Trump' in x:
        cond.append(x)
    if 'Democr' in x:
        cond.append(x)
    if 'Repub' in x:
        cond.append(x)
    if 'repub' in x:
        cond.append(x)

# %%
print(len(cond))
#v is index
v = []
for x in range(len(com['name'])):
    if com['name'][x] in cond:
        v.append(x)
print 

print(len(v))
for i in v:
    pol = pol.append(com.iloc[i])

com.drop(
    labels = v,
    axis =0,
    inplace=True
)

pol.tail()
print(com.name.unique())
# Out:
# 1
# 1
# ['Texas Latino Conservatives']

# %%
print(len(com))
print(com.name.unique())
temp = []
temp = com.name.unique()
print(len(temp))
# Out:
# 1
# ['Texas Latino Conservatives']
# 1

# %%
#column 1 = group, column 2 = 'name' column 3 = 'frequency'

group = []
name = []
frequency = []
#community
for x in range(len(com)):
    
    # new row
    if com['name'].iloc[x] not in name:
        #append new name
        name.append(com['name'].iloc[x])
        #create new row
        group.append('Community')
        #give value of 1
        frequency.append(1)
    else:
        v = name.index(com['name'].iloc[x])
        frequency[v] +=1

#political
for x in range(len(pol)):
    if pol['name'].iloc[x] not in name:
        #append new name
        name.append(pol['name'].iloc[x])
        #create new row
        group.append('Political')
        #give value of 1
        frequency.append(1)
    else:
        v = name.index(pol['name'].iloc[x])
        frequency[v] +=1
        
#news
for x in range(len(news)):
    if news['name'].iloc[x] not in name:
        #append new name
        name.append(news['name'].iloc[x])
        #create new row
        group.append('News')
        #give value of 1
        frequency.append(1)
    else:
        v = name.index(news['name'].iloc[x])
        frequency[v] +=1

dict = {'name': name, 'group': group, 'frequency': frequency}
df = pd.DataFrame(dict)
df
# Out:
#                                                 name      group  frequency
# 0                         Texas Latino Conservatives  Community          1
# 1  Republican National Hispanic Assembly of Charl...  Political          3
# 2                                 Latinos For Trump.  Political          2
# 3          CARA - Cuban American Republican Alliance  Political          1
# 4  Republican National Hispanic Assembly - Offici...  Political          1
# 5                Latinos For Trump -California Group  Political          2
# 6                          Democracy Now! en español       News          5

# %%
import seaborn as sns

sns.catplot(x='group', y = 'frequency', data =df, dodge=True, kind = 'violin', aspect =2)

# %%
sns.stripplot(x='frequency', y ='group', data=df, jitter=1)
# Out:
# <AxesSubplot:xlabel='frequency', ylabel='group'>

# %%
sns.catplot(x='frequency', y ='group', data=df, kind ='violin')

# %%
#Levene Test
import scipy.stats as stats
#establish three groups
group_col = []
group_pol = []
group_new = []
for x in range(len(df)):
    if df['group'][x] == "Community":
        group_col.append(df['frequency'][x])
    if df['group'][x] == "Political":
        group_pol.append(df['frequency'][x])
    if df['group'][x] == "News":
        group_new.append(df['frequency'][x])
        
stats.levene(group_col, group_pol, group_new, center='mean')
# Out:
# LeveneResult(statistic=1.556231003039514, pvalue=0.3162860691065819)

# %%
stats.f_oneway(group_col, group_pol, group_new)
# Out:
# F_onewayResult(statistic=7.183673469387753, pvalue=0.04742716049382719)
