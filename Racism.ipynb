# %%
import pandas as pd

#readcsv file date
com = pd.read_csv("community/FB_groups_States_racism.csv", sep= ",")
pol = pd.read_csv("political/Topics_FB_Political_Posts_per_partyracism.csv", sep = ",")
news = pd.read_csv("news/FB_groups_News_Media_Outlets_racism.csv", sep=",")

# %%
com.head()
# Out:
#    Unnamed: 0                                   name  \
# 0          74  Hispanos unidos en New York (H.U.N.Y)
# 1         769  Hispanos unidos en New York (H.U.N.Y)
# 2        1587  Hispanos unidos en New York (H.U.N.Y)
# 3        2371  Hispanos unidos en New York (H.U.N.Y)
# 4        9582              Hispanos en Columbus Ohio
#
#                                 Page or Account URL                   List  \
# 0   https://www.facebook.com/groups/793416207356486  Latinos+EstadosGroups
# 1   https://www.facebook.com/groups/793416207356486  Latinos+EstadosGroups
# 2   https://www.facebook.com/groups/793416207356486  Latinos+EstadosGroups
# 3   https://www.facebook.com/groups/793416207356486  Latinos+EstadosGroups
# 4  https://www.facebook.com/groups/1450333408570918  Latinos+EstadosGroups
#
#       State     state       Facebook Id  \
# 0  New York  New York   793416207356486
# 1  New York  New York   793416207356486
# 2  New York  New York   793416207356486
# 3  New York  New York   793416207356486
# 4      Ohio      Ohio  1450333408570918
#
#                               Group Name User Name  Likes at Posting  ...  \
# 0  Hispanos unidos en New York (H.U.N.Y)       NaN            6201.0  ...
# 1  Hispanos unidos en New York (H.U.N.Y)       NaN            6256.0  ...
# 2  Hispanos unidos en New York (H.U.N.Y)       NaN            6289.0  ...
# 3  Hispanos unidos en New York (H.U.N.Y)       NaN            6325.0  ...
# 4              Hispanos en Columbus Ohio       NaN            9867.0  ...
#
#   Final Link Image Text                                          Link Text  \
# 0        NaN        NaN  Disturbios por racismo y brutalidad policial; ...
# 1        NaN        NaN  Comandante de Fort Hood es destituido, tras in...
# 2        NaN        NaN  Posible fin del TPS; $12 millones por la muert...
# 3        NaN        NaN  Prometen transición pacífica; Piden calma en L...
# 4        NaN        NaN                                         Lempire Tv
#
#                                          Description  Sponsor Id  \
# 0  Un nuevo caso de brutalidad policial, en #Keno...         NaN
# 1  #VanessaGuillen #ElderFernandes #FortHood Remu...         NaN
# 2  #FortHood #VanessaGuillen #YoSoyVanessaGuillén...         NaN
# 3  **Líderes demócratas y republicanos en el #Con...         NaN
# 4  La invitación está hecha a toda la comunidad H...         NaN
#
#    Sponsor Name  Total Interactions  Overperforming Score  \
# 0           NaN                   1                 -68.0
# 1           NaN                   1                 -68.0
# 2           NaN                   0                -136.0
# 3           NaN                   0                -136.0
# 4           NaN                   0                 -34.0
#
#                                         MessageDescr  \
# 0   Un nuevo caso de brutalidad policial, en #Ken...
# 1  Remueven de su cargo al Comandante de #FortHoo...
# 2  **Varios representantes demócratas y republica...
# 3  **Líderes demócratas y republicanos en el #Con...
# 4  Atención con esta información. Saludos La invi...
#
#                                          MessageOnly
# 0   Un nuevo caso de brutalidad policial, en #Ken...
# 1  Remueven de su cargo al Comandante de #FortHoo...
# 2  **Varios representantes demócratas y republica...
# 3  **Líderes demócratas y republicanos en el #Con...
# 4  Atención con esta información. Saludos La invi...
#
# [5 rows x 39 columns]

# %%
pol.head()
# Out:
#    Unnamed: 0            Group Name       User Name       Facebook Id  \
# 0          81  Latinos Contra Trump  latinosvstrump  1161597243956409
# 1         117  Latinos Contra Trump  latinosvstrump  1161597243956409
# 2         209  Latinos Contra Trump  latinosvstrump  1161597243956409
# 3         222  Latinos Contra Trump  latinosvstrump  1161597243956409
# 4         294  Latinos Contra Trump  latinosvstrump  1161597243956409
#
#    Likes at Posting                  Created  Type  Likes  Comments  Shares  \
# 0          229462.0  2020-10-31 10:03:17 EDT  Link     79       216     103
# 1          229773.0  2020-08-27 19:29:55 EDT  Link     44       280      19
# 2          229523.0  2020-10-14 19:13:44 EDT  Link     66        38      65
# 3          229523.0  2020-10-14 15:27:29 EDT  Link     61        48      38
# 4          229471.0  2020-10-26 17:53:48 EDT  Link     38        45      23
#
#    ...  Image Text                                          Link Text  \
# 0  ...         NaN  Trump se Burla Alegremente del Nombre de Kamal...
# 1  ...         NaN  Gracias Querido Presidente Trump: Este es el T...
# 2  ...         NaN  Para Este Senador Cuando el Racismo Era Ley, E...
# 3  ...         NaN  Ya no Basta Con Estar Institucionalizando el R...
# 4  ...         NaN  ¿Sabes Cuál es el Problema de los Afroamerican...
#
#                                          Description  Sponsor Id  \
# 0  Desde difamar a los médicos que salvan vidas h...         NaN
# 1  El concepto de Trump de hacer a “América Grand...         NaN
# 2  Los espectadores no podían creer lo que oían a...         NaN
# 3  Su terrible decisión sobre la palabra n se sum...         NaN
# 4  El yerno del presidente sacó a relucir algo de...         NaN
#
#    Sponsor Name  Total Interactions Overperforming Score  \
# 0           NaN                 618                 1.39
# 1           NaN                 473                 1.53
# 2           NaN                 299                -1.35
# 3           NaN                 274                -1.48
# 4           NaN                 207                -2.24
#
#                                         MessageDescr  \
# 0  Racismo, enfoque divisivo e indecencia siguen ...
# 1  Este va directo para el que todavía tenga duda...
# 2  A eso es lo que realmente quieren llegar: a vo...
# 3  Nominada de Trump al Supremo Bajo Fuego por De...
# 4  Fíjate bien. No es por siglos de EXPLOTACIÓN y...
#
#                                          MessageOnly     party
# 0  Racismo, enfoque divisivo e indecencia siguen ...  Democrat
# 1  Este va directo para el que todavía tenga duda...  Democrat
# 2  A eso es lo que realmente quieren llegar: a vo...  Democrat
# 3  Nominada de Trump al Supremo Bajo Fuego por De...  Democrat
# 4  Fíjate bien. No es por siglos de EXPLOTACIÓN y...  Democrat
#
# [5 rows x 35 columns]

# %%
news.head()
# Out:
#    Unnamed: 0       Page Name    User Name  Facebook Id  Likes at Posting  \
# 0         730  CNN en Español        CNNee  89613772643        13174565.0
# 1         777  CNN en Español        CNNee  89613772643        13174728.0
# 2        1566  CNN en Español        CNNee  89613772643        13176291.0
# 3        1900    Primera Hora  primerahora  99825897726         1813544.0
# 4        2072  CNN en Español        CNNee  89613772643        13184192.0
#
#                    Created   Type  Likes  Comments  Shares  ...  Sponsor Id  \
# 0  2020-08-19 22:35:10 EDT   Link   1585       441      67  ...         NaN
# 1  2020-08-21 00:51:11 EDT   Link   1394       521      74  ...         NaN
# 2  2020-08-24 15:55:05 EDT  Photo    811       575      39  ...         NaN
# 3  2020-08-28 17:00:48 EDT   Link    734        84     186  ...         NaN
# 4  2020-08-31 11:10:11 EDT   Link    846        74      93  ...         NaN
#
#    Sponsor Name  Total Interactions  \
# 0           NaN               3,327
# 1           NaN               3,126
# 2           NaN               1,563
# 3           NaN               1,298
# 4           NaN               1,203
#
#    Total Interactions (weighted  —  Likes 1x Shares 1x Comments 1x Love 1x Wow 1x Haha 1x Sad 1x Angry 1x Care 1x )  \
# 0                                              3,327
# 1                                              3,126
# 2                                              1,563
# 3                                              1,298
# 4                                              1,203
#
#    Overperforming Score    clean_url        State  \
# 0                  8.55        cnnee      Georgia
# 1                  8.04        cnnee      Georgia
# 2                  2.98        cnnee      Georgia
# 3                  2.95  primerahora  Puerto Rico
# 4                  3.09        cnnee      Georgia
#
#                                Facebook  \
# 0        https://www.facebook.com/CNNee
# 1        https://www.facebook.com/CNNee
# 2        https://www.facebook.com/CNNee
# 3  https://www.facebook.com/primerahora
# 4        https://www.facebook.com/CNNee
#
#                                         MessageDescr  \
# 0  La cantante estadounidense Billie Eilish, que ...
# 1  “La historia nos ha impuesto una tarea más urg...
# 2  Lo que dijo Sofía Vergara sobre los señalamien...
# 3  “Somos los grandes sueños de nuestros abuelos,...
# 4  5 cosas para seguir hoy: Rescatan a 39 niños d...
#
#                                          MessageOnly
# 0  La cantante estadounidense Billie Eilish, que ...
# 1  “La historia nos ha impuesto una tarea más urg...
# 2  Lo que dijo Sofía Vergara sobre los señalamien...
# 3  “Somos los grandes sueños de nuestros abuelos,...
# 4  5 cosas para seguir hoy: Rescatan a 39 niños d...
#
# [5 rows x 38 columns]

# %%
pol.rename(columns = {'Group Name': 'name'}, inplace=True)
news.rename(columns = {'Page Name': 'name'}, inplace=True)

# %%
print(pol.name.nunique())
print(pol.name.unique())
# Out:
# 67
# ['Latinos Contra Trump' 'Mexican Americans For Biden'
#  'Latinos for Joe Biden 2020' 'Latinos against Trump'
#  'Latinx Young Democrats' 'Mexicanos Contra Trump'
#  'Cuban Americans for Joe Biden' '305 Latinos for BIDEN'
#  'NC Latinos for Biden/Harris' 'NoCo Latinos for Biden'
#  'Latinos With Trump' 'Latinos For Trump-El Paso'
#  'Republican National Hispanic Assembly'
#  'Republican National Hispanic Assembly of Florida'
#  'Latinos For Trump en Espaol' 'Latinos for Trump in Lea County'
#  'Republican National Hispanic Assembly of Miami-Dade County'
#  'Mexican Chicas For Trump' 'Arizona Latino Republican Association'
#  'Latino National Republican Coalition' 'Mexicans for Donald Trump'
#  'Republican National Hispanic Assembly of Seminole County'
#  'Latinos For Trump 2020' 'Latinos For Trump - Michigan'
#  'Republican National Hispanic Assembly - New York Chapter'
#  'Latinos Saint Lucie County for Trump' 'Latinos For Trump -Texas'
#  'Republican National Hispanic Assembly of Charlotte'
#  'Latinos For Trump -Georgia' 'Real Latinos for Trump 2020'
#  'African Americans & Latinos for Biden & Harris'
#  'Pennsylvania Latinos for Joe Biden' 'Latinos Against Donald Trump'
#  'Mexicans/Chicanos/Natives HATE Trump' 'Latinos contra Trump'
#  'Latino Leaders Against Crooked Lying Trump Ruining America'
#  'LAATinos (Latinos & Americans Against Trump)'
#  'Latinos por Biden 2020 Nevada' 'Cuban Americans & friends for Biden'
#  'Latinos Against Trump' 'DONALD TRUMP PARA HISPANOS'
#  'Latinos For Trump -California Group'
#  'Puertorican Republican and Latin Conservative Movement'
#  'CARA - Cuban American Republican Alliance'
#  'Republican National Hispanic Assembly - Official Group'
#  'Colombianos Y Latinoamericanos que apoyamos a Donald Trump'
#  'Latinos For Trump.' 'Latinos for Trump'
#  'TRUMP--LATINOS EXIGEN UNA VICTORIA APLASTANTE 2020'
#  'Trump Para Los hispanos' 'Texas Latinos/as Republican Group'
#  'Latinos por Trump' 'Kentucky republican latinos'
#  'Latino Republican National Federation'
#  'American Latinos for freedom! Trump 2020'
#  'Latinos for Trump 2020- Georgia/Florida' 'Hispanos por trump'
#  'Latinos Blacks White Jewish - Trump Train & Trump Team'
#  'LATINOS FOR TRUMP OREGON' 'Chicanos For Trump'
#  'Latinos for Trump - Jacksonville' 'Mexicans for Donald J. Trump 2016'
#  'Latinos for Trump en Espaol'
#  'Latino National Republican Coalition of Maryland'
#  'Latinos For Trump Manatee area Group'
#  'LATINOS / HISPANICS WHO TRUST TRUMP!'
#  'Hispanic Republicans - Republican National Hispanic Assembly of Cook']

# %%
print(type(com))
print(type(com['name']))
print(type(com.name))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %%
com.name.fillna(com['Group Name'], inplace = True)
print(len(com))
com.tail()
# Out:
# 520
#      Unnamed: 0                                     name Page or Account URL  \
# 515     1064315                    Latino Giving Houston                 NaN
# 516     1064454                    Latino Giving Houston                 NaN
# 517     1064486                    Latino Giving Houston                 NaN
# 518     1064633        Chicago Hispanic Health Coalition                 NaN
# 519     1064762  Latinos / Hispanics Over 40 New York NY                 NaN
#
#     List State state       Facebook Id  \
# 515  NaN   NaN   NaN   461202987236203
# 516  NaN   NaN   NaN   461202987236203
# 517  NaN   NaN   NaN   461202987236203
# 518  NaN   NaN   NaN   392980794059817
# 519  NaN   NaN   NaN  1635374083385330
#
#                                   Group Name                       User Name  \
# 515                    Latino Giving Houston                    LatinoGiving
# 516                    Latino Giving Houston                    LatinoGiving
# 517                    Latino Giving Houston                    LatinoGiving
# 518        Chicago Hispanic Health Coalition  ChicagoHispanicHealthCoalition
# 519  Latinos / Hispanics Over 40 New York NY            latinosover40newyork
#
#      Likes at Posting  ...                                         Final Link  \
# 515               NaN  ...  https://www.facebook.com/login/?next=https%3A%...
# 516               NaN  ...                                                NaN
# 517               NaN  ...                                                NaN
# 518             455.0  ...                                                NaN
# 519               NaN  ...                                                NaN
#
#                                             Image Text  \
# 515  A JUSTICE TAHIRIH CENTER® Everyone deserves to...
# 516                                                NaN
# 517                                                NaN
# 518                                                NaN
# 519                                                NaN
#
#                                              Link Text  \
# 515                             Tahirih Justice Center
# 516  Let’s Dismantle Toxic Tax Policies That Feed B...
# 517  Philanthropy Won’t Make Headway on Racial Just...
# 518  Cities declare racism a health crisis, but som...
# 519  A Guide to NYC’s Budding, Fruit-Filled Instagr...
#
#                                            Description  Sponsor Id  \
# 515  Over the past few years, we have seen policy a...         NaN
# 516  Philanthropic fortunes, created at the expense...         NaN
# 517  Black Americans have long suffered under polic...         NaN
# 518  CHICAGO (AP) — Christy DeGallerie noticed a st...         NaN
# 519  Pan-Asian pastry boxes, crusty loaves of sourd...         NaN
#
#      Sponsor Name  Total Interactions  Overperforming Score  \
# 515           NaN                   0                 -32.0
# 516           NaN                   0                 -20.0
# 517           NaN                   0                 -20.0
# 518           NaN                   0                  -4.0
# 519           NaN                   0                  -2.0
#
#                                           MessageDescr  \
# 515  2017 Latino Giving Grantee Over the past few y...
# 516   Philanthropic fortunes, created at the expens...
# 517   Black Americans have long suffered under poli...
# 518  https://apnews.com/article/virus-outbreak-race...
# 519  A tray of Sans Rival doughnuts from Kora Filip...
#
#                                            MessageOnly
# 515  2017 Latino Giving Grantee Over the past few y...
# 516   Philanthropic fortunes, created at the expens...
# 517   Black Americans have long suffered under poli...
# 518  https://apnews.com/article/virus-outbreak-race...
# 519  A tray of Sans Rival doughnuts from Kora Filip...
#
# [5 rows x 39 columns]

# %%
print(type(com))
print(type(com.name))
temp = com.name.tolist()
print(type(temp))
print(type(temp[0]))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# <class 'list'>
# <class 'str'>

# %%
cond = []
for x in temp:
    if 'Trump' in x:
        cond.append(x)
    if 'Democr' in x:
        cond.append(x)
    if 'Repub' in x:
        cond.append(x)
    if 'repub' in x:
        cond.append(x)

# %%
print(len(cond))
#v is index
v = []
for x in range(len(com['name'])):
    if com['name'][x] in cond:
        v.append(x)
print 

print(len(v))
for i in v:
    pol = pol.append(com.iloc[i])

com.drop(
    labels = v,
    axis =0,
    inplace=True
)

pol.tail()
print(com.name.unique())
# Out:
# 101
# 101
# ['Hispanos unidos en New York (H.U.N.Y)' 'Hispanos en Columbus Ohio'
#  'Hispanos Unidos De Michigan' 'Hispanos en West Palm Beach FL'
#  'Hispanos en Massachusetts Online Compras & Ventas'
#  'Comunidad Latina de New Jersey - Latino Community of NJ'
#  'Mundo Latino Network Group Nebraska, Iowa y South Dakota'
#  'Pennsylvania News Latino'
#  'Boston, Massachusetts Fuerza Latina, Trabajos, Promotiones, Apartamentos'
#  'RED LATINA NEW YORK' 'America Latina en Orlando FL'
#  'Ticos en New Jersey' 'Ticos en Miami Dade' 'Ticos En Miami'
#  'Ticos en miami' 'Boricuas en San Antonio,TX'
#  'Boricuas en Dallas Y Fort Worth' 'BORICUAS 100 X 35 EN NORTH CAROLINA'
#  'BORICUAS EN KISSIMMEE Y ORLANDO' 'Boricuas en Orlando VIP'
#  'BORICUAS EN PALM BEACH' 'Boricuas en Miami'
#  'BORICUAS EN CHARLOTTE NORTH CAROLINA' 'Boricuas Fajones en Texas'
#  'Boricuas Alegres en West Palm Beach' 'BORICUAS EN CHICAGO'
#  'Boricuas en Texas' 'Boricuas en Dallas-Fort Worth, Texas'
#  'Boricuas en Miami Broward FortLauderdale Texas' 'JANGUEO BORICUA Miami'
#  'Soy Boricua en DFW' 'Nicas Autoconvocados en Miami'
#  'Nicas Unidos En Miami' 'Nicas en San Francisco'
#  'Argentinos En New Jersey 🇦🇷 Oficial' '"ARGENTINOS EN MIAMI"'
#  'San Diego LGBTQ Latinx Coalition' 'Venezolanos viviendo en Miami '
#  'Venezolanos en Miami' 'Venezolanos En Orlando'
#  'Venezolanos en Dallas - Fort Worth' 'Venezolanos en Kissimmee'
#  'Venezolanos en new jersey' 'venezolanos en Orlando and Kissimmee'
#  'Venezolanos en Minnesota' 'Venezolanos en north carolina (ventas)'
#  'Peruanos en DC, Maryland & Virginia (DMV)' 'PERUANOS EN NORTH DALLAS'
#  'SALVADOREÑOS EN HOUSTON®' 'Salvadoreños en Houston TX'
#  'Hondureños en Dallas Fort  Worth' 'HONDUREÑOS EN DALLAS, TX.'
#  'HONDUREÑOS EN HOUSTON, TX.'
#  'hondureños viviendo en miami: compra vende regala intercambia'
#  'hondureños en west palm beach y sus alrededores'
#  'Mexicanos unidos de utah' 'Mexicanos en st Louis Missouri'
#  'Mexicanos En North Carolina' 'Mexicanos en Houston'
#  'MEXICANOS EN TENNESSEE' 'Mexicanos en Chicago'
#  'Mexicanos Unidos en Tri Estatal\nNew York, New Jersey,Manhhatan Connecticut.'
#  'Mexicanos en San Francisco California' 'Cubanos en miami,fl'
#  'CUBANOS EN HOUSTON Y MÁS' 'CUBANOS EN HOUSTON'
#  'CUBANOS EN ORLANDO,FLORIDA' 'Cubanos en Chicago'
#  'Cubanos en Somos Miami' '+ Cubanos en Miami 🇨🇺'
#  'Cubanos en New Jersey, New York , Pennsylvania y Connecticut. Unete'
#  "Cubans and Hispanics who grew up in Miami during the 60's and 70's"
#  'Dominicanos en Houston' 'Ecuatorianos en Orlando'
#  'ECUATORIANOS en NEW YORK (NY)'
#  'Colombianos Venezolanos Mexicanos Latinos en Katy'
#  'Mexicanos en Florida Central' 'Mexicanos en California 🇲🇽🇺🇸'
#  'Mexicanos en Arizona 🇲🇽🇺🇸' 'Latinos en Florida, Broward & Miami Dade'
#  'LATINOS EN NEW YORK' 'latinos en maryland , washington dc y virginia '
#  'LATINOS FOR TRUMP OREGON' 'Latinos en New Jersey (NJ) y New York (NY)'
#  'latinos en New York' 'Latinos en Minnesota' 'Latinos en Texas'
#  'Latinos in Tech - Washington' 'Latinos Unidos En Massachusetts'
#  'Pennsylvania Latinos' 'Peruanos Unidos en DC, Maryland & Virginia'
#  'peruanos  en new  york y new jersey  de todas las sangres'
#  'Peruanos en New Jersey' 'Peruanos en Massachusetts'
#  'Peruanos En Massachusetts MP'
#  'Peruvian Americans of New Jersey USA  Peruanos Americanos de New Jersey USA'
#  'APU Asociación Peruanos Unidos de Massachusetts' 'Peruanos en Chicago'
#  'Peruanos de Corazon NY NJ' 'Grupo de Venezolanos Activos en Georgia'
#  'Venezolanos en La Florida' 'Venezolanos en Florida.'
#  'Venezolanos Solidarios En Kendall' 'Venezolanos en NY'
#  'Venezolanos en Boston' 'Pennsylvania Latinos for Joe Biden'
#  'Oakland Latinos United (Unidos)' 'Acción y Alertas Latinos Wisconsin'
#  'Latinos en todo Massachusetts USA' 'Latinos in Tennessee'
#  'Latinos en Missouri'
#  'LGBTQ LATINOS, BOSTON, RHODE ISLAND, CONNECTICUT, NEW YORK Y NEW JERSEY.'
#  'Latinos se unen en Orlando y Kissimmee Florida'
#  'Latinos de Boulder County'
#  'Buffalo, New York, West Side Latinos Stand Up !!!!!!'
#  'Latinos en Madison, Wisconsin' 'The Washington DC Latinos!'
#  'Negocios Latinos en Wisconsin' 'Latinos en Plainfields'
#  'Marketing  Latinos en Atlanta  ( USA )' 'Latinos en SALT LAKE CITY'
#  'Latinos por Biden 2020 Nevada' 'Latinos en utah'
#  'Latinos en Tampa Bay official' 'La Mesa Boricua de Florida'
#  'Afro-Latino Festival of New York'
#  'VACOLAO - Virginia Coalition of Latino Organizations'
#  "Hispanic Women's Network of Texas"
#  'Washington Office on Latin America - WOLA'
#  'Association of Hispanic School Administrators of Dallas ISD'
#  'Latin New York' 'Nebraska Latino American Commission'
#  'Ohio Commission on Hispanic/Latino Affairs (OCHLA)'
#  'Pennsylvania Commission on Latino Affairs'
#  'Chicago Latino Writers Initiative' 'El Sol Latino Newspaper Miami'
#  'Washington State Commission on Hispanic Affairs'
#  'San Francisco Latino Historical Society' 'Washington Hispanic Newspaper'
#  'Nebraska Hispanic Chamber of Commerce'
#  'University of Michigan Center for Latin American & Caribbean Studies'
#  'Latino Giving Houston' 'Chicago Hispanic Health Coalition'
#  'Latinos / Hispanics Over 40 New York NY']

# %%
print(len(com))
print(com.name.unique())
temp = []
temp = com.name.unique()
print(len(temp))
# Out:
# 419
# ['Hispanos unidos en New York (H.U.N.Y)' 'Hispanos en Columbus Ohio'
#  'Hispanos Unidos De Michigan' 'Hispanos en West Palm Beach FL'
#  'Hispanos en Massachusetts Online Compras & Ventas'
#  'Comunidad Latina de New Jersey - Latino Community of NJ'
#  'Mundo Latino Network Group Nebraska, Iowa y South Dakota'
#  'Pennsylvania News Latino'
#  'Boston, Massachusetts Fuerza Latina, Trabajos, Promotiones, Apartamentos'
#  'RED LATINA NEW YORK' 'America Latina en Orlando FL'
#  'Ticos en New Jersey' 'Ticos en Miami Dade' 'Ticos En Miami'
#  'Ticos en miami' 'Boricuas en San Antonio,TX'
#  'Boricuas en Dallas Y Fort Worth' 'BORICUAS 100 X 35 EN NORTH CAROLINA'
#  'BORICUAS EN KISSIMMEE Y ORLANDO' 'Boricuas en Orlando VIP'
#  'BORICUAS EN PALM BEACH' 'Boricuas en Miami'
#  'BORICUAS EN CHARLOTTE NORTH CAROLINA' 'Boricuas Fajones en Texas'
#  'Boricuas Alegres en West Palm Beach' 'BORICUAS EN CHICAGO'
#  'Boricuas en Texas' 'Boricuas en Dallas-Fort Worth, Texas'
#  'Boricuas en Miami Broward FortLauderdale Texas' 'JANGUEO BORICUA Miami'
#  'Soy Boricua en DFW' 'Nicas Autoconvocados en Miami'
#  'Nicas Unidos En Miami' 'Nicas en San Francisco'
#  'Argentinos En New Jersey 🇦🇷 Oficial' '"ARGENTINOS EN MIAMI"'
#  'San Diego LGBTQ Latinx Coalition' 'Venezolanos viviendo en Miami '
#  'Venezolanos en Miami' 'Venezolanos En Orlando'
#  'Venezolanos en Dallas - Fort Worth' 'Venezolanos en Kissimmee'
#  'Venezolanos en new jersey' 'venezolanos en Orlando and Kissimmee'
#  'Venezolanos en Minnesota' 'Venezolanos en north carolina (ventas)'
#  'Peruanos en DC, Maryland & Virginia (DMV)' 'PERUANOS EN NORTH DALLAS'
#  'SALVADOREÑOS EN HOUSTON®' 'Salvadoreños en Houston TX'
#  'Hondureños en Dallas Fort  Worth' 'HONDUREÑOS EN DALLAS, TX.'
#  'HONDUREÑOS EN HOUSTON, TX.'
#  'hondureños viviendo en miami: compra vende regala intercambia'
#  'hondureños en west palm beach y sus alrededores'
#  'Mexicanos unidos de utah' 'Mexicanos en st Louis Missouri'
#  'Mexicanos En North Carolina' 'Mexicanos en Houston'
#  'MEXICANOS EN TENNESSEE' 'Mexicanos en Chicago'
#  'Mexicanos Unidos en Tri Estatal\nNew York, New Jersey,Manhhatan Connecticut.'
#  'Mexicanos en San Francisco California' 'Cubanos en miami,fl'
#  'CUBANOS EN HOUSTON Y MÁS' 'CUBANOS EN HOUSTON'
#  'CUBANOS EN ORLANDO,FLORIDA' 'Cubanos en Chicago'
#  'Cubanos en Somos Miami' '+ Cubanos en Miami 🇨🇺'
#  'Cubanos en New Jersey, New York , Pennsylvania y Connecticut. Unete'
#  "Cubans and Hispanics who grew up in Miami during the 60's and 70's"
#  'Dominicanos en Houston' 'Ecuatorianos en Orlando'
#  'ECUATORIANOS en NEW YORK (NY)'
#  'Colombianos Venezolanos Mexicanos Latinos en Katy'
#  'Mexicanos en Florida Central' 'Mexicanos en California 🇲🇽🇺🇸'
#  'Mexicanos en Arizona 🇲🇽🇺🇸' 'Latinos en Florida, Broward & Miami Dade'
#  'LATINOS EN NEW YORK' 'latinos en maryland , washington dc y virginia '
#  'LATINOS FOR TRUMP OREGON' 'Latinos en New Jersey (NJ) y New York (NY)'
#  'latinos en New York' 'Latinos en Minnesota' 'Latinos en Texas'
#  'Latinos in Tech - Washington' 'Latinos Unidos En Massachusetts'
#  'Pennsylvania Latinos' 'Peruanos Unidos en DC, Maryland & Virginia'
#  'peruanos  en new  york y new jersey  de todas las sangres'
#  'Peruanos en New Jersey' 'Peruanos en Massachusetts'
#  'Peruanos En Massachusetts MP'
#  'Peruvian Americans of New Jersey USA  Peruanos Americanos de New Jersey USA'
#  'APU Asociación Peruanos Unidos de Massachusetts' 'Peruanos en Chicago'
#  'Peruanos de Corazon NY NJ' 'Grupo de Venezolanos Activos en Georgia'
#  'Venezolanos en La Florida' 'Venezolanos en Florida.'
#  'Venezolanos Solidarios En Kendall' 'Venezolanos en NY'
#  'Venezolanos en Boston' 'Pennsylvania Latinos for Joe Biden'
#  'Oakland Latinos United (Unidos)' 'Acción y Alertas Latinos Wisconsin'
#  'Latinos en todo Massachusetts USA' 'Latinos in Tennessee'
#  'Latinos en Missouri'
#  'LGBTQ LATINOS, BOSTON, RHODE ISLAND, CONNECTICUT, NEW YORK Y NEW JERSEY.'
#  'Latinos se unen en Orlando y Kissimmee Florida'
#  'Latinos de Boulder County'
#  'Buffalo, New York, West Side Latinos Stand Up !!!!!!'
#  'Latinos en Madison, Wisconsin' 'The Washington DC Latinos!'
#  'Negocios Latinos en Wisconsin' 'Latinos en Plainfields'
#  'Marketing  Latinos en Atlanta  ( USA )' 'Latinos en SALT LAKE CITY'
#  'Latinos por Biden 2020 Nevada' 'Latinos en utah'
#  'Latinos en Tampa Bay official' 'La Mesa Boricua de Florida'
#  'Afro-Latino Festival of New York'
#  'VACOLAO - Virginia Coalition of Latino Organizations'
#  "Hispanic Women's Network of Texas"
#  'Washington Office on Latin America - WOLA'
#  'Association of Hispanic School Administrators of Dallas ISD'
#  'Latin New York' 'Nebraska Latino American Commission'
#  'Ohio Commission on Hispanic/Latino Affairs (OCHLA)'
#  'Pennsylvania Commission on Latino Affairs'
#  'Chicago Latino Writers Initiative' 'El Sol Latino Newspaper Miami'
#  'Washington State Commission on Hispanic Affairs'
#  'San Francisco Latino Historical Society' 'Washington Hispanic Newspaper'
#  'Nebraska Hispanic Chamber of Commerce'
#  'University of Michigan Center for Latin American & Caribbean Studies'
#  'Latino Giving Houston' 'Chicago Hispanic Health Coalition'
#  'Latinos / Hispanics Over 40 New York NY']
# 144

# %%
#column 1 = group, column 2 = 'name' column 3 = 'frequency'

group = []
name = []
frequency = []
#community
for x in range(len(com)):
    
    # new row
    if com['name'].iloc[x] not in name:
        #append new name
        name.append(com['name'].iloc[x])
        #create new row
        group.append('Community')
        #give value of 1
        frequency.append(1)
    else:
        v = name.index(com['name'].iloc[x])
        frequency[v] +=1

#political
for x in range(len(pol)):
    if pol['name'].iloc[x] not in name:
        #append new name
        name.append(pol['name'].iloc[x])
        #create new row
        group.append('Political')
        #give value of 1
        frequency.append(1)
    else:
        v = name.index(pol['name'].iloc[x])
        frequency[v] +=1
        
#news
for x in range(len(news)):
    if news['name'].iloc[x] not in name:
        #append new name
        name.append(news['name'].iloc[x])
        #create new row
        group.append('News')
        #give value of 1
        frequency.append(1)
    else:
        v = name.index(news['name'].iloc[x])
        frequency[v] +=1

dict = {'name': name, 'group': group, 'frequency': frequency}
df = pd.DataFrame(dict)
df
# Out:
#                                                   name      group  frequency
# 0                Hispanos unidos en New York (H.U.N.Y)  Community          4
# 1                            Hispanos en Columbus Ohio  Community          1
# 2                          Hispanos Unidos De Michigan  Community          1
# 3                       Hispanos en West Palm Beach FL  Community          1
# 4    Hispanos en Massachusetts Online Compras & Ventas  Community          1
# ..                                                 ...        ...        ...
# 417               PERIODICO EL EXPRESSO DE PUERTO RICO       News          1
# 418                                Latino Public Radio       News          1
# 419                                   La Noticia de MS       News          2
# 420                                  Telemundo Lubbock       News          1
# 421                      La Voz Hispana De Connecticut       News          1
#
# [422 rows x 3 columns]

# %%
import seaborn as sns

sns.catplot(x='group', y = 'frequency', data =df, dodge=True, kind = 'violin', aspect =2)

# %%
sns.catplot(x='group', y ='frequency', data=df, kind='strip')

# %%
sns.catplot(x='frequency', y ='group', data=df, kind ='violin')

# %%
#Levene Test
import scipy.stats as stats
#establish three groups
group_col = []
group_pol = []
group_new = []
for x in range(len(df)):
    if df['group'][x] == "Community":
        group_col.append(df['frequency'][x])
    if df['group'][x] == "Political":
        group_pol.append(df['frequency'][x])
    if df['group'][x] == "News":
        group_new.append(df['frequency'][x])
        
stats.levene(group_col, group_pol, group_new, center='median')
# Out:
# LeveneResult(statistic=7.799333133180242, pvalue=0.0004724112995284485)

# %%
stats.levene(group_col, group_pol, group_new, center='mean')
# Out:
# LeveneResult(statistic=13.084521485620874, pvalue=3.0751021741359887e-06)

# %%
stats.f_oneway(group_col, group_pol, group_new)
# Out:
# F_onewayResult(statistic=9.730530722771944, pvalue=7.400939286183101e-05)
