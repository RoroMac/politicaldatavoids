# %%
import pandas as pd

com = pd.read_csv("community/FB_groups_States_economy.csv", sep= ",")
pol = pd.read_csv("political/Topics_FB_Political_Posts_per_partyeconomy.csv", sep = ",")
news = pd.read_csv("news/FB_groups_News_Media_Outlets_economy.csv", sep=",")

# %%
com.head()
# Out:
#    Unnamed: 0                                   name  \
# 0          72  Hispanos unidos en New York (H.U.N.Y)
# 1         179  Hispanos unidos en New York (H.U.N.Y)
# 2         349  Hispanos unidos en New York (H.U.N.Y)
# 3         385  Hispanos unidos en New York (H.U.N.Y)
# 4         621  Hispanos unidos en New York (H.U.N.Y)
#
#                                Page or Account URL                   List  \
# 0  https://www.facebook.com/groups/793416207356486  Latinos+EstadosGroups
# 1  https://www.facebook.com/groups/793416207356486  Latinos+EstadosGroups
# 2  https://www.facebook.com/groups/793416207356486  Latinos+EstadosGroups
# 3  https://www.facebook.com/groups/793416207356486  Latinos+EstadosGroups
# 4  https://www.facebook.com/groups/793416207356486  Latinos+EstadosGroups
#
#       State     state      Facebook Id                             Group Name  \
# 0  New York  New York  793416207356486  Hispanos unidos en New York (H.U.N.Y)
# 1  New York  New York  793416207356486  Hispanos unidos en New York (H.U.N.Y)
# 2  New York  New York  793416207356486  Hispanos unidos en New York (H.U.N.Y)
# 3  New York  New York  793416207356486  Hispanos unidos en New York (H.U.N.Y)
# 4  New York  New York  793416207356486  Hispanos unidos en New York (H.U.N.Y)
#
#   User Name  Likes at Posting  ... Final Link Image Text  \
# 0       NaN            6201.0  ...        NaN        NaN
# 1       NaN            6206.0  ...        NaN        NaN
# 2       NaN            6197.0  ...        NaN        NaN
# 3       NaN            6197.0  ...        NaN        NaN
# 4       NaN            6196.0  ...        NaN        NaN
#
#                                           Link Text  \
# 0                                       Nexotaxcorp
# 1                         DDM Home Improvement Corp
# 2  Peligros de las Herramientas de Corte Eléctricas
# 3                            Make the Road New York
# 4                                               NaN
#
#                                          Description  Sponsor Id  \
# 0                                                NaN         NaN
# 1  Contact us! #homeimprovement #carpenter #job #...         NaN
# 2  Estas herramientas producen algunas de las les...         NaN
# 3  📺WATCH: “Many of us here are Mixtecs. We pay o...         NaN
# 4                                                NaN         NaN
#
#    Sponsor Name  Total Interactions  Overperforming Score  \
# 0           NaN                   1                 -20.0
# 1           NaN                   0                 -66.0
# 2           NaN                   0                 -44.0
# 3           NaN                   0                 -40.0
# 4           NaN                   0                 -66.0
#
#                                         MessageDescr  \
# 0  Estamos en vivo! Conéctate a nuestro programa,...
# 1   Contact us! #homeimprovement #carpenter #job ...
# 2  "Este es un mercado laboral que se nutre de sa...
# 3   📺WATCH: “Many of us here are Mixtecs. We pay ...
# 4  Safety First! Always remember to follow the OS...
#
#                                          MessageOnly
# 0  Estamos en vivo! Conéctate a nuestro programa,...
# 1   Contact us! #homeimprovement #carpenter #job ...
# 2  "Este es un mercado laboral que se nutre de sa...
# 3   📺WATCH: “Many of us here are Mixtecs. We pay ...
# 4  Safety First! Always remember to follow the OS...
#
# [5 rows x 39 columns]

# %%
pol.head()
# Out:
#    Unnamed: 0                   Group Name                 User Name  \
# 0           6  Mexican Americans For Biden  MexicanAmericansForBiden
# 1          14         Latinos Contra Trump            latinosvstrump
# 2          20  Mexican Americans For Biden  MexicanAmericansForBiden
# 3          35  Mexican Americans For Biden  MexicanAmericansForBiden
# 4          87         Latinos Contra Trump            latinosvstrump
#
#         Facebook Id  Likes at Posting                  Created     Type  \
# 0   100921535039507            1039.0  2020-09-28 17:14:00 EDT    Photo
# 1  1161597243956409          229600.0  2020-09-27 20:12:01 EDT     Link
# 2   100921535039507            1139.0  2020-10-04 12:06:23 EDT  YouTube
# 3   100921535039507            1016.0  2020-09-24 16:23:26 EDT    Photo
# 4  1161597243956409          229612.0  2020-09-26 19:45:04 EDT     Link
#
#    Likes  Comments  Shares  ...  \
# 0    717        97     556  ...
# 1    336       242     430  ...
# 2    864        64     144  ...
# 3    425        48     250  ...
# 4    292        92     113  ...
#
#                                           Image Text  \
# 0  AVERAGE FEDERAL INCOME TAXES PAID: TEACHERS: $...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                            Link Text  \
# 0                                                NaN
# 1  Confirman lo Que Sabíamos: Trump Solo Pagó $ 7...
# 2                    Trump Was Wrong About the Rona!
# 3                                                NaN
# 4  Empleados de la Casa Blanca ya Discuten qué Ha...
#
#                                          Description  Sponsor Id  \
# 0                                                NaN         NaN
# 1  El venerable periódico logró hacerse con más d...         NaN
# 2  How President Trump mishandled the whole COVID...         NaN
# 3                                                NaN         NaN
# 4  Olivia Troye revela que ya se han celebrado re...         NaN
#
#    Sponsor Name  Total Interactions Overperforming Score  \
# 0           NaN               1,717                 8.38
# 1           NaN               1,391                 4.49
# 2           NaN               1,240                 2.46
# 3           NaN               1,027                 4.99
# 4           NaN                 560                 1.81
#
#                                         MessageDescr  \
# 0  It’s time for Trump to be held accountable on ...
# 1  Pues bien, si es mentira lo que el NY Times di...
# 2  Trump Was Wrong About the Rona! By Adalberto R...
# 3  Most Educated U.S. Presidents- (See article be...
# 4  Esto pasa cuando permites a un delincuente maf...
#
#                                          MessageOnly     party
# 0  It’s time for Trump to be held accountable on ...  Democrat
# 1  Pues bien, si es mentira lo que el NY Times di...  Democrat
# 2  Trump Was Wrong About the Rona! By Adalberto R...  Democrat
# 3  Most Educated U.S. Presidents- (See article be...  Democrat
# 4  Esto pasa cuando permites a un delincuente maf...  Democrat
#
# [5 rows x 35 columns]

# %%
news.head()
# Out:
#    Unnamed: 0            Page Name         User Name      Facebook Id  \
# 0          86       CNN en Español             CNNee      89613772643
# 1         253          NotiUno 630        NotiUno630  142122259214484
# 2         324              NotiCel         noticelpr  178010418883713
# 3         383  El Diario de Juárez  eldiariodejuarez  128606507194600
# 4         436  El Diario de Juárez  eldiariodejuarez  128606507194600
#
#    Likes at Posting                  Created  Type  Likes  Comments  Shares  \
# 0        13183193.0  2020-08-29 12:00:53 EDT  Link  10431      1032    3098
# 1          646665.0  2020-08-21 07:17:27 EDT  Link   3414       749    3018
# 2          500572.0  2020-08-25 12:35:05 EDT  Link   1683       443    4207
# 3          687884.0  2020-08-18 10:55:48 EDT  Link   3600       863     420
# 4          690086.0  2020-08-31 10:01:14 EDT  Link   2189       613     630
#
#    ...  Sponsor Id  Sponsor Name  Total Interactions  \
# 0  ...         NaN           NaN              17,794
# 1  ...         NaN           NaN               8,163
# 2  ...         NaN           NaN               6,610
# 3  ...         NaN           NaN               5,717
# 4  ...         NaN           NaN               4,995
#
#    Total Interactions (weighted  —  Likes 1x Shares 1x Comments 1x Love 1x Wow 1x Haha 1x Sad 1x Angry 1x Care 1x )  \
# 0                                             17,794
# 1                                              8,163
# 2                                              6,610
# 3                                              5,717
# 4                                              4,995
#
#    Overperforming Score         clean_url        State  \
# 0                 45.74             cnnee      Georgia
# 1                 36.77        notiuno630  Puerto Rico
# 2                 47.90         noticelpr  Puerto Rico
# 3                 14.36  eldiariodejuarez        Texas
# 4                 12.55  eldiariodejuarez        Texas
#
#                                     Facebook  \
# 0             https://www.facebook.com/CNNee
# 1       https://www.facebook.com/NotiUno630/
# 2        https://www.facebook.com/noticelpr/
# 3  https://www.facebook.com/eldiariodejuarez
# 4  https://www.facebook.com/eldiariodejuarez
#
#                                         MessageDescr  \
# 0  Rusia divulga material inédito de la explosión...
# 1  En momentos donde la pandemia golpea con fuerz...
# 2  Trump extendió el plazo sin pagos mediante una...
# 3  Ya se lleva a cabo contratación de personal #S...
# 4  Prepararon con antelación protocolos sanitario...
#
#                                          MessageOnly
# 0  Rusia divulga material inédito de la explosión...
# 1  En momentos donde la pandemia golpea con fuerz...
# 2  Trump extendió el plazo sin pagos mediante una...
# 3  Ya se lleva a cabo contratación de personal #S...
# 4  Prepararon con antelación protocolos sanitario...
#
# [5 rows x 38 columns]

# %%
pol.rename(columns = {'Group Name': 'name'}, inplace=True)
news.rename(columns = {'Page Name': 'name'}, inplace=True)

# %%
print(pol.name.nunique())
print(pol.name.unique())
# Out:
# 139
# ['Mexican Americans For Biden' 'Latinos Contra Trump'
#  'Latinos for Joe Biden 2020' 'Latinos for Biden' 'Latinos Con Biden'
#  'NC Latinos for Biden/Harris' '305 Latinos for BIDEN'
#  'Cuban Americans for Joe Biden' 'Mexicanos Contra Trump'
#  'Latinx Voter Committee of the Coconino County Democratic Party'
#  'Dominicanos con Biden' 'Latinx Young Democrats of Orange County'
#  'Latinx Young Democrats' 'NoCo Latinos for Biden'
#  'Latino Veterans con Biden'
#  'Latinx Caucus of the Democratic Party of Georgia'
#  'Latinos Republicanos for Biden' 'Revere 02151 Latinos for Biden'
#  'Somos Latinos Con Biden Broward County' 'Latinos for Trump'
#  'Republican National Hispanic Assembly'
#  'Republican National Hispanic Assembly - TEXAS'
#  'Republican National Hispanic Assembly of Florida'
#  'Mexicans for Donald Trump' 'Latinos For Trump-El Paso'
#  'Latinos For Trump en Espaol'
#  'Republican National Hispanic Assembly - New York Chapter'
#  'Latinos for Trump -South Texas' 'Latinas Por Trump'
#  'Arizona Latino Republican Association' 'Latinos With Trump'
#  'New York State Latino Republican Coalition'
#  'Latino National Republican Coalition' 'Latinos con Donald J. Trump'
#  'Latinos Saint Lucie County for Trump' 'Latinos for Trump in Lea County'
#  'This Latino Is For Trump' 'Los Angeles Hispanic Republican Club'
#  'Latinos For Trump -California' 'Latinos For Trump 2020'
#  'Latinos For Trump - New Mexico'
#  'Republican National Hispanic Assembly - Lubbock Chapter'
#  'Latinos For Trump -Georgia'
#  'Republican National Hispanic Assembly of Miami-Dade County'
#  'Republican National Hispanic Assembly of Seminole County'
#  'Latinos 4 Trump 2020. No Al Socialismo'
#  "New Mexico's Hispanic For Trump" 'Latinos For Trump Network'
#  'Mexican Chicas For Trump' 'Latinos For Trump -Texas'
#  'Latinos For Trump -New Jersey' 'Latinos For Trump Virginia'
#  'Latinos For Trump - Michigan' 'Latinos For Trump -Delaware'
#  'Republican National Hispanic Assembly of Broward County'
#  'Republican National Hispanic Assembly - San Angelo TX Chapter'
#  'Latinos For Donald Trump' 'Latinos for TRUMP CLUB'
#  'Republican Hispanic Citizens in Action'
#  'Republican National Hispanic Assembly of Charlotte'
#  'Latinos For Trump Wisconsin' 'The Latinos For Trump Flag'
#  'Republican National Hispanic Assembly of Orange County'
#  'Republican National Hispanic Assembly of Collier County'
#  'Republicans Latinos of Palm Beach County'
#  'Republican National Hispanic Assembly of Osceola County'
#  'Latinos For Trump -Missouri' 'Latinos For Trump Colorado'
#  'This is why Trump is good for Mexico and Mexicans'
#  'Real Latinos for Trump 2020' 'Latinas For Trump'
#  'Latinos for Trump 2020 -California' 'Latinos For Trump - Illinois'
#  'Republican National Hispanic Assembly New Jersey Chapter'
#  'Republican National Hispanic Assembly of Missouri'
#  'Republican National Hispanic Assembly of Polk County'
#  'Republican National Hispanic Assembly of Palm Beach County'
#  'Latinos For Trump -Pennsylvania' 'Latinos For Trump Washington D. C.'
#  'Latinos Against Donald Trump'
#  'African Americans & Latinos for Biden & Harris'
#  'Pennsylvania Latinos for Joe Biden' 'Latinos contra Trump'
#  'Cuban Americans & friends for Biden'
#  'Mexicans/Chicanos/Natives HATE Trump'
#  'Latinos and Allies of Nebraska Against Trump'
#  'Latinos por Biden 2020 Nevada' 'LATINX for BIDEN/ HARRIS'
#  'Salvadoreos Con Biden' 'Dominicanos/Florida con Joe Biden'
#  'Latinos for Joe Biden and Kamala Harris'
#  'Latino Leaders Against Crooked Lying Trump Ruining America'
#  'LATINOS POR BIDEN Y KAMALA' 'Ohio Latino Veterans for Biden'
#  'Latinos Unidos contra Trump' 'Latinos Against Trump'
#  'Latinos United Against  Donald Trump'
#  'LAATinos (Latinos & Americans Against Trump)'
#  'DONALD TRUMP PARA HISPANOS' 'Latinos For Trump -California Group'
#  'Puertorican Republican and Latin Conservative Movement'
#  'Republican National Hispanic Assembly - Official Group'
#  'CARA - Cuban American Republican Alliance'
#  'Latino Republican National Federation' 'DOMINICANOS CON DONALD TRUMP'
#  'Latinos For Trump.'
#  'Colombianos Y Latinoamericanos que apoyamos a Donald Trump'
#  'Chicanos For Trump' 'Latinos por la Familia Trump'
#  'Republican National Hispanic Assembly of Virginia'
#  'Latinos who support Donald Trump'
#  'TRUMP--LATINOS EXIGEN UNA VICTORIA APLASTANTE 2020'
#  'Latinos for Trump - Jacksonville' 'Latinos For Trump of Georgia'
#  'Kentucky republican latinos' 'LATINOS FOR TRUMP OREGON'
#  'American Latinos for freedom! Trump 2020' 'Trump Para Los hispanos'
#  'Latinos for Trump 2020- Georgia/Florida'
#  'Latinos Blacks White Jewish - Trump Train & Trump Team'
#  'Latinos For Trump' 'Mexican Americans for Trump'
#  'Hispanos con Donald Trump'
#  'Republican National Hispanic Assembly- Illinois Chapter'
#  'Latinos / Latinas for TRUMP' 'Latinos por Trump'
#  'Texas Latinos/as Republican Group' 'Latinos for Trump en Espaol'
#  'Tarrant County Republican National Hispanic Assembly'
#  'Latinos For Trump - Texas Group' 'Hispanos por trump'
#  'Friends Who Like Latino National Republican Coalition of Rockland County'
#  'LATINOS / HISPANICS WHO TRUST TRUMP!'
#  'Latinos de la Florida con Donald Trump'
#  'Latino National Republican Coalition - Houston Area'
#  'Latino National Republican Coalition of Maryland'
#  'Latinos For Trump Manatee area Group' 'Latinos 4 Trump'
#  'Hispanic Republicans - Republican National Hispanic Assembly of Cook']

# %%
print(type(com))
print(type(com['name']))
print(type(com.name))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %%
com.name.fillna(com['Group Name'], inplace = True)
print(len(com))
com.tail()
# Out:
# 14507
#        Unnamed: 0                                               name  \
# 14502     1064919                           Latino New York Magazine
# 14503     1064936  Republican National Hispanic Assembly New Jers...
# 14504     1064947  Republican National Hispanic Assembly New Jers...
# 14505     1064950  Republican National Hispanic Assembly New Jers...
# 14506     1064960  Republican National Hispanic Assembly New Jers...
#
#       Page or Account URL List State state      Facebook Id  \
# 14502                 NaN  NaN   NaN   NaN  321113924580682
# 14503                 NaN  NaN   NaN   NaN  108074727679268
# 14504                 NaN  NaN   NaN   NaN  108074727679268
# 14505                 NaN  NaN   NaN   NaN  108074727679268
# 14506                 NaN  NaN   NaN   NaN  108074727679268
#
#                                               Group Name  \
# 14502                           Latino New York Magazine
# 14503  Republican National Hispanic Assembly New Jers...
# 14504  Republican National Hispanic Assembly New Jers...
# 14505  Republican National Hispanic Assembly New Jers...
# 14506  Republican National Hispanic Assembly New Jers...
#
#                    User Name  Likes at Posting  ...  \
# 14502  latinonewyorkmagazine               NaN  ...
# 14503         RNHANewJersey1               NaN  ...
# 14504         RNHANewJersey1               NaN  ...
# 14505         RNHANewJersey1               NaN  ...
# 14506         RNHANewJersey1               NaN  ...
#
#                                               Final Link  \
# 14502  https://www.facebook.com/login/?next=https%3A%...
# 14503                                                NaN
# 14504                                                NaN
# 14505  https://www.facebook.com/login/?next=https%3A%...
# 14506  https://www.facebook.com/login/?next=https%3A%...
#
#                                               Image Text  \
# 14502  U.S.HOME SERVICES SANTI JULCAMANYAN Business C...
# 14503  ABRAHAM LINCOLN; THE FIRST REPUBLICAN PRESIDEN...
# 14504                                                NaN
# 14505                                                NaN
# 14506  22% OF LATINOS SUPPORT TRUMP FOR RE- ELECTION ...
#
#                      Link Text  Description  Sponsor Id  Sponsor Name  \
# 14502                      NaN          NaN         NaN           NaN
# 14503          Timeline Photos          NaN         NaN           NaN
# 14504          Timeline Photos          NaN         NaN           NaN
# 14505  Vote for Frank Pallotta          NaN         NaN           NaN
# 14506          Timeline Photos          NaN         NaN           NaN
#
#        Total Interactions  Overperforming Score  \
# 14502                   0                 -10.0
# 14503                   0                   0.0
# 14504                   0                   0.0
# 14505                   0                   0.0
# 14506                   0                   0.0
#
#                                             MessageDescr  \
# 14502  Financial business opportunity to make a loan ...
# 14503  Abraham Lincoln was the first Republican presi...
# 14504  The New Jersey Chapter of the Republican Natio...
# 14505  A message from the Chairman of the New Jersey ...
# 14506  The Hispanic community's support for President...
#
#                                              MessageOnly
# 14502  Financial business opportunity to make a loan ...
# 14503  Abraham Lincoln was the first Republican presi...
# 14504  The New Jersey Chapter of the Republican Natio...
# 14505  A message from the Chairman of the New Jersey ...
# 14506  The Hispanic community's support for President...
#
# [5 rows x 39 columns]

# %%
print(type(com))
print(type(com.name))
temp = com.name.tolist()
print(type(temp))
print(type(temp[0]))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# <class 'list'>
# <class 'str'>

# %%
cond = []
for x in temp:
    if 'Trump' in x:
        cond.append(x)
    if 'Democr' in x:
        cond.append(x)
    if 'Repub' in x:
        cond.append(x)
    if 'repub' in x:
        cond.append(x)

# %%
print(len(cond))
#v is index
v = []
for x in range(len(com['name'])):
    if com['name'][x] in cond:
        v.append(x)
print 

print(len(v))
for i in v:
    pol = pol.append(com.iloc[i])

com.drop(
    labels = v,
    axis =0,
    inplace=True
)

pol.tail()
print(com.name.unique())
# Out:
# 568
# 568
# ['Hispanos unidos en New York (H.U.N.Y)' 'Hispanos en Columbus Ohio'
#  'Cristianos Hispanos en Dallas, Texas ( Metroplex)'
#  'Hispanos en Oklahoma' 'Hispanos unidos en el gabacho (Tennessee)'
#  'Hispanos en Virginia' 'HISPANOS EN ST LOUIS MISSOURI'
#  'Hispanos Unidos De Michigan' 'Hispanos V.I.P. de Virginia'
#  'Hispanos en West Palm Beach FL' '"HISPANOS EN PENNSYLVANIA"'
#  'Hispanos en Massachusetts Online Compras & Ventas'
#  'hispanos en annapolis Maryland' 'Hispanos en Utah'
#  'HISPANOS DE NEW YORK,5 BOROS Y ALREDEDORES'
#  'Eventos Hispanos En Tennessee'
#  'COMPRE Y VENDE HISPANOS EN ST LOUIS MISSOURI Y SUS ALREDEDORES EN  ILLINOIS'
#  'Ayuda para Hispanos en Orlando' 'Hispanos en New York'
#  'Ventas y compras en Houston Texas entre Hispanos'
#  'Comunidad Latina de New Jersey - Latino Community of NJ'
#  'SAN BERNARDINO SWAPMEET LATINO' 'COMUNIDAD LATINO AMERICANA EN MICHIGAN'
#  'Latino Outdoors San Antonio/Austin' 'Latino Outdoors Washington'
#  'Mundo Latino Network Group Nebraska, Iowa y South Dakota'
#  'Craigslist  Latino  Minnesota'
#  'NEBRASKA LATINO SMALL BUSINESS AND ENTREPRENEURS'
#  'Utah Latino Empowerment OutReach Network'
#  'Ohio Latino Veterans for Biden' 'Latino San Diego'
#  'Latino Filmmakers of Oklahoma' 'MIAMI LATIN FESTIVAL'
#  'Orlando Latin Nights' 'MIAMI LATIN NEWS'
#  'Latin Dancers of South Carolina' 'LATIN EVENTS SOUTH CAROLINA'
#  'DFW Latin Professionals' 'BACHATA LATIN DANCE SAN DIEGO'
#  'Latin Jazz events in San Francisco' 'Miami Latin Music movement'
#  'Latin Food Lovers of DFW'
#  'Columbus Ohio - Comunidad Latina y Trabajo Disponible'
#  'Boston, Massachusetts Fuerza Latina, Trabajos, Promotiones, Apartamentos'
#  'Comunidad Latina en San Antonio tx' 'CONEXION LATINA EN UTAH'
#  'LA CHACHARA LATINA TEXAS' 'Mujer Latina Emprendedora Utah'
#  'Chicago .fuerza Latina , Negocios, anuncios y ayuda a los latinos.'
#  'la yarda latina de carlsbad nm' 'NOCHE LATINA UTAH'
#  'RED LATINA NEW YORK' 'America Latina en Orlando FL'
#  'Hispanic Heritage Matters in Texas' 'Elgin Hispanic Network'
#  'Hispanic Real Estate Industry of Washington D.C, Maryland and Virginia'
#  'Mercadito Hispano Salem Oregon' 'ebay-hispano  compra y vende minnesota'
#  'Pulga De Arlington Para La Raza Hispana'
#  'CASAS DE CONSTRUCCIÓN NUEVA EN OKLAHOMA- ALEJANDRO LAURENS REALTOR'
#  'Pastoral Juvenil Hispana en Houston'
#  'La original yarda hispana de phoenix' 'Comunidad Hispana De Elgin, IL'
#  'la pulguita de san Antonio hispana' 'Ticos en New Jersey'
#  'Ticos en Orlando' 'Ticos in Miami' 'Ticos en Miami Dade'
#  'Ticos en Houston, Texas' 'Ticos Unidos En Dallas' 'Ticos En Miami'
#  'Ticos en miami' 'TICOS EN NEW JERSEY & NEW YORK'
#  'Boricuas en San Antonio,TX' 'Boricuas en Dallas Y Fort Worth'
#  'BORICUAS 100 X 35 EN NORTH CAROLINA' 'BORICUAS EN KISSIMMEE Y ORLANDO'
#  'Boricuas en Orlando VIP' 'Boricuas levantandose  en Cleveland, Ohio'
#  'Boricuas Profesionales en Dallas y Ft. Worth -  Texas'
#  'BORICUAS EN PALM BEACH' 'Boricuas en Miami' 'Utah Boricuas'
#  'BORICUAS EN CHARLOTTE NORTH CAROLINA' 'Boricuas en Killeen Texas'
#  'Boricuas in Utah' 'BORICUAS EN WISCONSIN' 'BORICUAS en TEXAS'
#  'Boricuas en Texas' 'Boricuas en Ohio' 'Boricuas Fajones en Texas'
#  'Boricuas Alegres en West Palm Beach' 'Negocios Boricuas en Houston'
#  'Southside Boricuas - Virginia'
#  'BORICUAS ENTRE ORLANDO Y LAKELAND: LAKE, ORANGE, OSCEOLA, POLK'
#  'BORICUAS EN CHICAGO' 'Boricuas en Dallas-Fort Worth, Texas'
#  'Boricuas en Chicago' 'PR NORTH CAROLINA'
#  'Boricuas en Miami Broward FortLauderdale Texas'
#  'Boricuas y Dominicanos En Massachusetts🇩🇴🇵🇷'
#  'Servicios Boricuas en Maryland' 'BORICUAS EN POINCIANA & KISSIMMEE'
#  'JANGUEO BORICUA Miami' 'Soy Boricua en DFW'
#  'El Pulguero Boricua de Dallas y Fort Worth'
#  'Casa Boricua en Houston, TX' 'La Fonda Boricua in New York City'
#  'BORICUA MC OF YOUNGSTOWN,OHIO' 'Nicas Autoconvocados en Miami'
#  'Nicas Unidos En Miami' 'Nicas en San Francisco' 'Nicas en Miami'
#  'Nicas en Virginia, Md,Dc' 'Future Of Peru / Miami County Indiana'
#  'free pets  in Peru Indiana Miami County' 'Peru and Miami County Events'
#  'Argentinos En New Jersey 🇦🇷 Oficial' 'Argentinos en Miami'
#  '"ARGENTINOS EN MIAMI"' 'Argentinos en Houston, TX' 'Argentinos en Utah'
#  'Argentinos en San Diego CA' 'Argentinos en Dallas Texas'
#  'Argentinos en Minnesota'
#  'Argentinos en San Diego profesionales y comercio'
#  'Argentinos en New York' 'argentinos en new jersey'
#  'Argentinos en Rhode Island' 'Argentinos Emigrando A Miami'
#  'Miami Cuban Street Slang & Culture' 'Cuban Salsa New York'
#  'Old Spanish and Mexican Land Grants in New Mexico and Southern Colorado'
#  'Mexican parranda party en New York' 'Mexican Filmmakers in San Diego'
#  'San Diego LGBTQ Latinx Coalition' 'Venezolanos en Miami'
#  'Venezolanos viviendo en Miami ' 'Venezolanos en Orlando'
#  'Venezolanos En Orlando' 'Venezolanos en Chicago'
#  'Venezolanos en Dallas - Fort Worth' 'Venezolanos en Kissimmee'
#  'Venezolanos en Houston Tx' 'Venezolanos en new jersey'
#  'venezolanos en Orlando and Kissimmee'
#  'Venezolanos Unidos en D.C. Maryland & Virginia'
#  'Venezolanos en Washington D.C, Virginia and Maryland'
#  'Cuantos venezolanos hay en New York?' 'Venezolanos En Chicago 🇺🇸🇻🇪'
#  'Venezolanos en Wisconsin' 'Venezolanos y Latinos en Fort Lauderdale'
#  'Venezolanos unidos de Utah' 'Venezolanos en San Francisco'
#  'Venezolanos en San Antonio, Texas'
#  'Profesionales y Comerciantes Venezolanos en San Diego y alrededores.'
#  'Venezolanos en Las Vegas Nevada'
#  'Comunidad de Venezolanos en Minnesota - Venezuelan Community in MN'
#  'Los Venezolanos en The Woodlands, Spring y Conroe'
#  'VENEZOLANOS EN TULSA-OKLAHOMA' 'Venezolanos en  Tijuana y San Diego, CA'
#  'Venezolanos en Columbus Ohio'
#  'Venezolanos del Area de la Bahia de San Francisco'
#  'Venezolanos en Minnesota' 'Venezolanos en Texas'
#  'Venezolanos en San Diego y Tijuana Baja California'
#  'Venezolanos en DALLAS  y FORTWORTH' 'VENEZOLANOS UNIDOS EN OKLAHOMA'
#  'Venezolanos en Miami ' 'Venezolanos en Utah'
#  'VENEZOLANOS EN MIAMI,FLORIDA'
#  'Venezolanos en Indiana, Illinois, Ohio, Michigan'
#  'VENEZOLANOS EN PENNSYLVANIA'
#  'Venezolanos viviendo en Frederick, Maryland, USA'
#  'Venezolanos en North Dallas - Addison - Carrolton - Famers Branch Etc'
#  'Venezolanos y Colombianos unidos en Miami.'
#  'Venezolanos en Paterson New Jersey y sus alrededores'
#  'VENEZOLANOS EN FORT LAUDERDALE' 'Venezolanos en north carolina (ventas)'
#  'Venezolanos En Miami' 'Venezolanos viviendo en Miami  Grupo de Mundo24'
#  'Venezolanos en Virginia, Maryland y Washington 🇻🇪🇺🇸'
#  'Venezolanos en Washington DC'
#  'Venezolanos en Orlando Avalon Park - Waterford Lakes'
#  'Venezolanos en Rhode Island' 'Peruanos en DC, Maryland & Virginia (DMV)'
#  'Peruanos en San Francisco Bay Area' 'PERUANOS EN NORTH DALLAS'
#  'SALVADOREÑOS EN HOUSTON®' 'Salvadoreños en Houston TX'
#  'Salvadoreños en Houston, Texas' 'Guatemaltecos en Miami'
#  'Guatemaltecos en Rhode Island' 'Hondureños en Dallas'
#  '🇭🇳Hondureños en Houston🇭🇳' 'Hondureños En Houston Texas'
#  'Hondureños Unidos En New Jersey' 'Hondureños en Dallas Fort  Worth'
#  'HONDUREÑOS EN DALLAS, TX.' 'HONDUREÑOS EN HOUSTON, TX.'
#  'hondureños viviendo en miami: compra vende regala intercambia'
#  'hondureños en west palm beach y sus alrededores'
#  'SALVADOREñOS EN LONG ISLAND Y NEW YORK'
#  'Salvadoreños en Houston Texas, Anuncia, Compra Vende'
#  'Mexicanos en Texas 🇲🇽🇺🇸' 'Mexicanos unidos de utah'
#  'Mexicanos en st Louis Missouri' 'Mexicanos en washington virginia !!'
#  'Mexicanos en portland oregon' 'Mexicanos En North Carolina'
#  'Mexicanos en Houston' 'Mexicanos en Washington DC'
#  'MEXICANOS EN TENNESSEE' 'Mexicanos en Chicago'
#  'MEXICANOS EN ACCION ORLANDO Y KISSIMME'
#  'MEXICANOS EMPRESARIOS Y EXITOSOS EN NEW YORK & NEW JERSEY'
#  'MEXICANOS EN OHIO'
#  'Mexicanos Unidos en Tri Estatal\nNew York, New Jersey,Manhhatan Connecticut.'
#  'Mexicanos en Dallas' 'Mexicanos en Rhode Island 🇲🇽🇺🇸'
#  'Mexicanos en San Antonio'
#  'Mexicanos en Houston. Trabajo amistad y lo que se de..'
#  'Mexicanos en San Francisco California' 'mexicanos en passaic New Jersey'
#  'MEXICANOS UNIDOS DE HAVERSTRAW NEW YORK'
#  'Mexicanos en el Estado de Virginia' 'Mexicanos en The Woodlands'
#  'Mexicanos y Latinos en Montana' 'Cubanos en miami,fl'
#  'CUBANOS EN HOUSTON Y MÁS' 'CUBANOS EN HOUSTON'
#  'CUBANOS EN ORLANDO,FLORIDA' 'Cubanos en Chicago'
#  'Cubanos en Somos Miami' 'Cubanos en Dallas' 'CUBANOS EN HOUSTON tx'
#  '+ Cubanos en Miami 🇨🇺'
#  'Cubanos en New Jersey, New York , Pennsylvania y Connecticut. Unete'
#  'Cubanos En Dallas' 'CUBANOS EN ORLANDO' 'CUBANOS EN PALM BEACH'
#  'Cubanos en North Carolina' 'cubanos en Houston Texas'
#  'Cubanos en DFW Texas'
#  'CUBANOS Y LATINOS RESIDENTES EN MIAMI BEACH. FLORIDA. UNETE.'
#  'Cubans in Ohio - Cubanos en Ohio' 'Cubanos en Houston y alrededores'
#  "Cubans and Hispanics who grew up in Miami during the 60's and 70's"
#  'Dominicanos en Houston' 'Dominicanos en Houston Texas'
#  'Dominicanos en Centro Texas' 'Dominicanos en Miami Y USA'
#  'Dominicanos en Orlando.' 'Dominicanos en orlando kissimmee'
#  'Dominicanos en Rhode Island' 'Dominicanos en las vegas nv'
#  'Asociación de Ecuatorianos DFW' 'Ecuatorianos en Orlando'
#  'ECUATORIANOS en NEW YORK (NY)' 'Ecuatorianos en Chicago y alrededores'
#  'ECUATORIANOS EN NEW YORK &  NEW JERSEY'
#  'ECUATORIANOS EN LA CIUDAD DE NEW YORK'
#  'Ecuatorianos en Virginia-DC-Maryland' 'ECUATORIANOS EN NEW YORK'
#  'Ecuatorianos  En Chicago' 'Ecuatorianos en La Florida'
#  'Colombianos Venezolanos Mexicanos Latinos en Katy'
#  'Mexicanos en Florida Central' 'Mexicanos en California 🇲🇽🇺🇸'
#  'Mexicanos en Arizona 🇲🇽🇺🇸' 'Mexicanos en California USA u otros estados'
#  'Mexicanos En Connecticut' 'MEXICANOS Y CENTRO AMERICANOS EN LAS VEGAS'
#  'Numeros ke repiten de las loterias dominicanas y new york'
#  'Latinos en Florida, Broward & Miami Dade'
#  'Latinos en Compro y Vendo en St Louis Missouri' 'LATINOS EN NEW YORK'
#  'TRABAJOS PARA LATINOS - HOUSTON'
#  'latinos en maryland , washington dc y virginia '
#  'LATINOS FOR TRUMP OREGON' 'Latinos en New Jersey (NJ) y New York (NY)'
#  'Latinos en New Jersey y areas cercanas' '☀️ Latinos en Miami 🌴'
#  'Latinos en Oregon' 'latinos en New York' 'Latinos en Minnesota'
#  'Latinos en Texas' 'Latinos in Tech - Washington'
#  'Latinos Unidos En Massachusetts'
#  'TRABAJO PARA LATINOS  EN ST LOUIS MISSOURI' 'Pennsylvania Latinos'
#  'Negocios Y Eventos Latinos en Minnesota'
#  'Peruanos Unidos en DC, Maryland & Virginia'
#  'peruanos  en new  york y new jersey  de todas las sangres'
#  'Peruanos en New Jersey' 'Peruanos en Massachusetts'
#  'Peruanos en Minnesota' 'Peruanos en Orlando, Fl'
#  'Peruvian Americans of New Jersey USA  Peruanos Americanos de New Jersey USA'
#  'Peruanos en Texas' 'Eventos peruanos en washington maryland y virginia'
#  'APU Asociación Peruanos Unidos de Massachusetts' 'Peruanos en Chicago'
#  'Peruanos en Washington DC área (DC, Maryland y Virginia -DMV)'
#  'Peruanos Unidos En utah🇵🇪👋' 'Peruanos en Utah'
#  'Peruanos de Corazon NY NJ' 'Peruanos en Rhode Island'
#  'PERUANOS EN FLORIDA' 'VENEZOLANOS EN  KATY,TX' 'venezolanos En Austin'
#  'Venezolanos en Colorado' 'Venezolanos en Charlotte NC'
#  'Grupo de Venezolanos Activos en Georgia' 'Venezolanos en Nashville'
#  'Venezolanos en La Florida' 'Ciudadanos Venezolanos en Atlanta.'
#  'Venezolanos en Florida.' 'Venezolanos Solidarios En Kendall'
#  'Venezolanos En Tampa Bay Oficial' 'Venezolanos en NY'
#  'Venezolanos en Boston' 'Pennsylvania Latinos for Joe Biden'
#  'Oakland Latinos United (Unidos)' 'Acción y Alertas Latinos Wisconsin'
#  'LATINOS EN OREGON' 'Latinos en Houston Texas'
#  'Latinos en Charlotte North Carolina'
#  'Chilenos Latinos unidos en NY NJ PA OH by Orlando Abarzua ...'
#  'Latinos en San Antonio, TX' 'latinos Unidos❤en houston tx'
#  'Latinos en todo Massachusetts USA' 'Latinos in Tennessee'
#  'Latinos en Orlando Florida'
#  'Entre Latinos...Venta,Compra,Ofrece trabajo y Servicios En Todo Houston!'
#  'Latinos en Clarksville Tennessee' 'Latinos sur de Oregon'
#  'Latinos en Missouri' 'Latinos Emprendedores en New York'
#  'LGBTQ LATINOS, BOSTON, RHODE ISLAND, CONNECTICUT, NEW YORK Y NEW JERSEY.'
#  'Latinos se unen en Orlando y Kissimmee Florida'
#  'Latinos en forked river, lakewood y todo New jersey'
#  'Latinos San Diego/Tijuana' 'Latinos de Boulder County'
#  'Latinos en Houston'
#  'Buffalo, New York, West Side Latinos Stand Up !!!!!!'
#  'Latinos en Madison, Wisconsin' 'Craigslista Latinos en Minnesota'
#  'Latinos Unidos en murfreesboro tennessee' 'The Washington DC Latinos!'
#  'Latinos Unidos En South Carolina'
#  'Latinos En Philadelpia New Jersey & New York'
#  'Latinos En South Carolina' 'Negocios Latinos en Wisconsin'
#  'Latinos Over 40 Houston, TX Group' 'Latinos en Oklahoma City - Oklahoma'
#  'Profesionales latinos en Kissimmee y Orlando anunciate'
#  'Richmond,Oakland,San Francisco, San Jose y los alrededores.,Latinos'
#  'Latinos Cristianos de Kissimmee y Orlando'
#  'Latinos Over 40 McAllen, TX Group'
#  'LATINOS EN FORT LAUDERDALE - MIAMI & ALREDEDORES'
#  'LATINOS MIAMI FLORIDA USA' 'Latinos en Las Vegas'
#  'Latinos en Dallas - Fort Worth' 'Latinos en South Dakota'
#  'Latinos en Youngstown, Ohio' 'Colombo-Venezolano latinos en Utah'
#  'Latinos en Miami' 'Las Vegas Hispanos y Latinos'
#  'Latinos En Atlanta Official' 'Latinos en Plainfields'
#  'Datos de Trabajos y Ventas Latinos en Broward - Weston - Miami'
#  'Latinos Columbus' 'Marketing  Latinos en Atlanta  ( USA )'
#  'Latinos en SALT LAKE CITY' 'LATINOS EN CINCINNATI!!😉'
#  'Latinos por Biden 2020 Nevada' 'latinos unidos de cincinnati'
#  'TRABAJO EN SAVANNAH PARA LATINOS' 'Latinos en utah'
#  'EVENTOS LATINOS EN UTAH' 'Latinos en SWFL' 'Latinos en Fayetteville NC'
#  'LATINOS EN UTAH' 'Latinos en los Angeles California compra y venta'
#  'Latinos en Tampa Bay official'
#  'Blue Cross and Blue Shield of Texas Latino'
#  'Institute of  Hispanic Culture of Houston' 'Latinos en New York'
#  'Texas Latino Conservatives' 'Latino Mix Houston' 'Latino Mix Chicago'
#  'Texas Louisiana Hispanic District'
#  'Latino Awards Chicago by Zonika TV Radio Fm'
#  'Miami-Dade Cuban-American Dems' 'San Diego Latino Health Coalition'
#  'La Mesa Boricua de Florida' 'Consulado de El Salvador en Virginia'
#  'Latino Mix Dallas' 'Dallas Unidos por El Salvador'
#  'Latinos En Michigan TV' 'Blue Cross and Blue Shield of Oklahoma Latino'
#  'Afro-Latino Festival of New York'
#  'Blue Cross and Blue Shield of New Mexico Latino' 'Zelda Latino New York'
#  'Oakland Latinos United'
#  'VACOLAO - Virginia Coalition of Latino Organizations'
#  'Mexicanos en Miami' 'San Diego Latino Film Festival'
#  'Consulado General de El Salvador en Las Vegas Nevada'
#  'Consulado General de El Salvador  Boston Massachusetts' 'Latino Dallas'
#  'Hispanic Heritage Council of Western New York Inc.'
#  'Hispanic/Latino Commission of Michigan'
#  'Palm Beach County Hispanic Bar Association'
#  'San Antonio Hispanic Chamber of Commerce'
#  "Hispanic Women's Network of Texas" 'Venezolanos En Houston'
#  'Oregon Latino Health Coalition' 'Hispanic Center of Western Michigan'
#  'Maryland Hispanic Business Conference' 'Latino Union of Chicago'
#  'Chicago Boricua Resistance' 'Washington Office on Latin America - WOLA'
#  'Latino Chamber of Commerce of SE Wisconsin Inc'
#  'Chicago Latino Film Festival'
#  'Ohio Hispanic Coalition - Coalicin Hispana de Ohio'
#  'Massachusetts Latino Police Officers Association'
#  'El Paso Hispanic Chamber' 'West Michigan Hispanic Chamber of Commerce'
#  'New Braunfels Hispanic Business Alliance'
#  'Virginia Hispanic Chamber of Commerce' 'Latino News of Tennessee'
#  'Consulado Peru En Dallas' 'Latino Mix Phoenix' 'Latin New York'
#  'Latino Community Fund of Washington State'
#  'Hispanic Chamber of Commerce Metro Orlando'
#  'Houston Hispanic Chamber of Commerce' 'Rhode Island Latino Arts'
#  'NHPO Houston - National Hispanic Professional Organization'
#  'South Carolina Latina Project' 'New York Latino Film Festival'
#  'Nebraska Latino American Commission' 'Chicago Latin Fitness'
#  'National Hispanic Institute at San Antonio'
#  'Minnesota Council on Latino Affairs'
#  'Ohio Commission on Hispanic/Latino Affairs (OCHLA)'
#  'The Latin School of Chicago - Official Alumni Page'
#  'Consulado de El Salvador en Seattle Washington'
#  'San Diego County Hispanic Chamber of Commerce'
#  'Latino Muslims of New York' 'The Maryland Hispanic Chamber of Commerce'
#  'Latin Chamber of Commerce Nevada'
#  'North Carolina Hispanic Chamber of Commerce'
#  'New Jersey Center for Hispanic Policy Research and Development'
#  'Pennsylvania Commission on Latino Affairs' 'Houston Latina Bloggers'
#  'Ayudas y Recursos para la Comunidad Hispana de Orlando FL'
#  'Latin Ballet of Virginia' 'Oakland Latino Firefighters Association'
#  'El Sol Latino Newspaper Miami'
#  'Washington State Commission on Hispanic Affairs'
#  'Amaryllis aka The Latin Phoenix' 'Miami Latin Festival'
#  'Nevada Hispanic Business Group' 'Texas Latin Conference'
#  'Greater Oklahoma City Hispanic Chamber of Commerce'
#  'San Francisco Latino Historical Society'
#  'Palm Beach County Latin Entrepreneurs' 'Venezolanos En Nebraska'
#  'Chicago Latino Caucus Foundation'
#  'Washington State Latino Leadership Network'
#  'El Fogon Mexican Grill Riverside'
#  'Northern Virginia Hispanic Chamber of Commerce'
#  'Oregon Hispanic Bar Association'
#  'Consulado El Salvador en McAllen Texas' 'Latino Muslims of Chicago'
#  'Chicago Teachers Union Latinx Caucus' 'New Jersey Hispano'
#  'GWHCC - Greater Washington Hispanic Chamber of Commerce'
#  'Latin American Student Association - South Dakota State University'
#  'Greater Riverside Hispanic Chamber of Commerce'
#  'Washington Hispanic Newspaper'
#  'National Latina Business Women Association-San Diego [NLBWA-SD]'
#  'Nebraska Hispanic Chamber of Commerce'
#  'Peridico El Latino / Largest Hispanic Newspaper in San Diego'
#  'The Latin Phoenix Creperie'
#  'New York State  Black Puerto Rican Hispanic and Asian Legislative Caucus'
#  'San Diego Latino News' 'Mi San Diego Latinx North County'
#  'Cubanos en Houston' 'Chicago New Latino Movement'
#  'Chicago Latinos in Philanthropy' 'New York Soccer Latin Academy NYSLA'
#  'New Jersey Latinos for Bernie'
#  'Washington State Latinos Con Bernie Sanders' 'LGBT Latinos of Orlando'
#  'Latino Giving Houston' 'Dallas latino WSB' 'Tu Orlando Latino'
#  'Latinos En La Ciudad de New York by the Fox'
#  'Latinos / Hispanics Over 40 New York NY'
#  'New York Latino Publishing   NYLP ' 'Latino New York Magazine']

# %%
print(len(com))
print(com.name.unique())
temp = []
temp = com.name.unique()
print(len(temp))
# Out:
# 13939
# ['Hispanos unidos en New York (H.U.N.Y)' 'Hispanos en Columbus Ohio'
#  'Cristianos Hispanos en Dallas, Texas ( Metroplex)'
#  'Hispanos en Oklahoma' 'Hispanos unidos en el gabacho (Tennessee)'
#  'Hispanos en Virginia' 'HISPANOS EN ST LOUIS MISSOURI'
#  'Hispanos Unidos De Michigan' 'Hispanos V.I.P. de Virginia'
#  'Hispanos en West Palm Beach FL' '"HISPANOS EN PENNSYLVANIA"'
#  'Hispanos en Massachusetts Online Compras & Ventas'
#  'hispanos en annapolis Maryland' 'Hispanos en Utah'
#  'HISPANOS DE NEW YORK,5 BOROS Y ALREDEDORES'
#  'Eventos Hispanos En Tennessee'
#  'COMPRE Y VENDE HISPANOS EN ST LOUIS MISSOURI Y SUS ALREDEDORES EN  ILLINOIS'
#  'Ayuda para Hispanos en Orlando' 'Hispanos en New York'
#  'Ventas y compras en Houston Texas entre Hispanos'
#  'Comunidad Latina de New Jersey - Latino Community of NJ'
#  'SAN BERNARDINO SWAPMEET LATINO' 'COMUNIDAD LATINO AMERICANA EN MICHIGAN'
#  'Latino Outdoors San Antonio/Austin' 'Latino Outdoors Washington'
#  'Mundo Latino Network Group Nebraska, Iowa y South Dakota'
#  'Craigslist  Latino  Minnesota'
#  'NEBRASKA LATINO SMALL BUSINESS AND ENTREPRENEURS'
#  'Utah Latino Empowerment OutReach Network'
#  'Ohio Latino Veterans for Biden' 'Latino San Diego'
#  'Latino Filmmakers of Oklahoma' 'MIAMI LATIN FESTIVAL'
#  'Orlando Latin Nights' 'MIAMI LATIN NEWS'
#  'Latin Dancers of South Carolina' 'LATIN EVENTS SOUTH CAROLINA'
#  'DFW Latin Professionals' 'BACHATA LATIN DANCE SAN DIEGO'
#  'Latin Jazz events in San Francisco' 'Miami Latin Music movement'
#  'Latin Food Lovers of DFW'
#  'Columbus Ohio - Comunidad Latina y Trabajo Disponible'
#  'Boston, Massachusetts Fuerza Latina, Trabajos, Promotiones, Apartamentos'
#  'Comunidad Latina en San Antonio tx' 'CONEXION LATINA EN UTAH'
#  'LA CHACHARA LATINA TEXAS' 'Mujer Latina Emprendedora Utah'
#  'Chicago .fuerza Latina , Negocios, anuncios y ayuda a los latinos.'
#  'la yarda latina de carlsbad nm' 'NOCHE LATINA UTAH'
#  'RED LATINA NEW YORK' 'America Latina en Orlando FL'
#  'Hispanic Heritage Matters in Texas' 'Elgin Hispanic Network'
#  'Hispanic Real Estate Industry of Washington D.C, Maryland and Virginia'
#  'Mercadito Hispano Salem Oregon' 'ebay-hispano  compra y vende minnesota'
#  'Pulga De Arlington Para La Raza Hispana'
#  'CASAS DE CONSTRUCCIÓN NUEVA EN OKLAHOMA- ALEJANDRO LAURENS REALTOR'
#  'Pastoral Juvenil Hispana en Houston'
#  'La original yarda hispana de phoenix' 'Comunidad Hispana De Elgin, IL'
#  'la pulguita de san Antonio hispana' 'Ticos en New Jersey'
#  'Ticos en Orlando' 'Ticos in Miami' 'Ticos en Miami Dade'
#  'Ticos en Houston, Texas' 'Ticos Unidos En Dallas' 'Ticos En Miami'
#  'Ticos en miami' 'TICOS EN NEW JERSEY & NEW YORK'
#  'Boricuas en San Antonio,TX' 'Boricuas en Dallas Y Fort Worth'
#  'BORICUAS 100 X 35 EN NORTH CAROLINA' 'BORICUAS EN KISSIMMEE Y ORLANDO'
#  'Boricuas en Orlando VIP' 'Boricuas levantandose  en Cleveland, Ohio'
#  'Boricuas Profesionales en Dallas y Ft. Worth -  Texas'
#  'BORICUAS EN PALM BEACH' 'Boricuas en Miami' 'Utah Boricuas'
#  'BORICUAS EN CHARLOTTE NORTH CAROLINA' 'Boricuas en Killeen Texas'
#  'Boricuas in Utah' 'BORICUAS EN WISCONSIN' 'BORICUAS en TEXAS'
#  'Boricuas en Texas' 'Boricuas en Ohio' 'Boricuas Fajones en Texas'
#  'Boricuas Alegres en West Palm Beach' 'Negocios Boricuas en Houston'
#  'Southside Boricuas - Virginia'
#  'BORICUAS ENTRE ORLANDO Y LAKELAND: LAKE, ORANGE, OSCEOLA, POLK'
#  'BORICUAS EN CHICAGO' 'Boricuas en Dallas-Fort Worth, Texas'
#  'Boricuas en Chicago' 'PR NORTH CAROLINA'
#  'Boricuas en Miami Broward FortLauderdale Texas'
#  'Boricuas y Dominicanos En Massachusetts🇩🇴🇵🇷'
#  'Servicios Boricuas en Maryland' 'BORICUAS EN POINCIANA & KISSIMMEE'
#  'JANGUEO BORICUA Miami' 'Soy Boricua en DFW'
#  'El Pulguero Boricua de Dallas y Fort Worth'
#  'Casa Boricua en Houston, TX' 'La Fonda Boricua in New York City'
#  'BORICUA MC OF YOUNGSTOWN,OHIO' 'Nicas Autoconvocados en Miami'
#  'Nicas Unidos En Miami' 'Nicas en San Francisco' 'Nicas en Miami'
#  'Nicas en Virginia, Md,Dc' 'Future Of Peru / Miami County Indiana'
#  'free pets  in Peru Indiana Miami County' 'Peru and Miami County Events'
#  'Argentinos En New Jersey 🇦🇷 Oficial' 'Argentinos en Miami'
#  '"ARGENTINOS EN MIAMI"' 'Argentinos en Houston, TX' 'Argentinos en Utah'
#  'Argentinos en San Diego CA' 'Argentinos en Dallas Texas'
#  'Argentinos en Minnesota'
#  'Argentinos en San Diego profesionales y comercio'
#  'Argentinos en New York' 'argentinos en new jersey'
#  'Argentinos en Rhode Island' 'Argentinos Emigrando A Miami'
#  'Miami Cuban Street Slang & Culture' 'Cuban Salsa New York'
#  'Old Spanish and Mexican Land Grants in New Mexico and Southern Colorado'
#  'Mexican parranda party en New York' 'Mexican Filmmakers in San Diego'
#  'San Diego LGBTQ Latinx Coalition' 'Venezolanos en Miami'
#  'Venezolanos viviendo en Miami ' 'Venezolanos en Orlando'
#  'Venezolanos En Orlando' 'Venezolanos en Chicago'
#  'Venezolanos en Dallas - Fort Worth' 'Venezolanos en Kissimmee'
#  'Venezolanos en Houston Tx' 'Venezolanos en new jersey'
#  'venezolanos en Orlando and Kissimmee'
#  'Venezolanos Unidos en D.C. Maryland & Virginia'
#  'Venezolanos en Washington D.C, Virginia and Maryland'
#  'Cuantos venezolanos hay en New York?' 'Venezolanos En Chicago 🇺🇸🇻🇪'
#  'Venezolanos en Wisconsin' 'Venezolanos y Latinos en Fort Lauderdale'
#  'Venezolanos unidos de Utah' 'Venezolanos en San Francisco'
#  'Venezolanos en San Antonio, Texas'
#  'Profesionales y Comerciantes Venezolanos en San Diego y alrededores.'
#  'Venezolanos en Las Vegas Nevada'
#  'Comunidad de Venezolanos en Minnesota - Venezuelan Community in MN'
#  'Los Venezolanos en The Woodlands, Spring y Conroe'
#  'VENEZOLANOS EN TULSA-OKLAHOMA' 'Venezolanos en  Tijuana y San Diego, CA'
#  'Venezolanos en Columbus Ohio'
#  'Venezolanos del Area de la Bahia de San Francisco'
#  'Venezolanos en Minnesota' 'Venezolanos en Texas'
#  'Venezolanos en San Diego y Tijuana Baja California'
#  'Venezolanos en DALLAS  y FORTWORTH' 'VENEZOLANOS UNIDOS EN OKLAHOMA'
#  'Venezolanos en Miami ' 'Venezolanos en Utah'
#  'VENEZOLANOS EN MIAMI,FLORIDA'
#  'Venezolanos en Indiana, Illinois, Ohio, Michigan'
#  'VENEZOLANOS EN PENNSYLVANIA'
#  'Venezolanos viviendo en Frederick, Maryland, USA'
#  'Venezolanos en North Dallas - Addison - Carrolton - Famers Branch Etc'
#  'Venezolanos y Colombianos unidos en Miami.'
#  'Venezolanos en Paterson New Jersey y sus alrededores'
#  'VENEZOLANOS EN FORT LAUDERDALE' 'Venezolanos en north carolina (ventas)'
#  'Venezolanos En Miami' 'Venezolanos viviendo en Miami  Grupo de Mundo24'
#  'Venezolanos en Virginia, Maryland y Washington 🇻🇪🇺🇸'
#  'Venezolanos en Washington DC'
#  'Venezolanos en Orlando Avalon Park - Waterford Lakes'
#  'Venezolanos en Rhode Island' 'Peruanos en DC, Maryland & Virginia (DMV)'
#  'Peruanos en San Francisco Bay Area' 'PERUANOS EN NORTH DALLAS'
#  'SALVADOREÑOS EN HOUSTON®' 'Salvadoreños en Houston TX'
#  'Salvadoreños en Houston, Texas' 'Guatemaltecos en Miami'
#  'Guatemaltecos en Rhode Island' 'Hondureños en Dallas'
#  '🇭🇳Hondureños en Houston🇭🇳' 'Hondureños En Houston Texas'
#  'Hondureños Unidos En New Jersey' 'Hondureños en Dallas Fort  Worth'
#  'HONDUREÑOS EN DALLAS, TX.' 'HONDUREÑOS EN HOUSTON, TX.'
#  'hondureños viviendo en miami: compra vende regala intercambia'
#  'hondureños en west palm beach y sus alrededores'
#  'SALVADOREñOS EN LONG ISLAND Y NEW YORK'
#  'Salvadoreños en Houston Texas, Anuncia, Compra Vende'
#  'Mexicanos en Texas 🇲🇽🇺🇸' 'Mexicanos unidos de utah'
#  'Mexicanos en st Louis Missouri' 'Mexicanos en washington virginia !!'
#  'Mexicanos en portland oregon' 'Mexicanos En North Carolina'
#  'Mexicanos en Houston' 'Mexicanos en Washington DC'
#  'MEXICANOS EN TENNESSEE' 'Mexicanos en Chicago'
#  'MEXICANOS EN ACCION ORLANDO Y KISSIMME'
#  'MEXICANOS EMPRESARIOS Y EXITOSOS EN NEW YORK & NEW JERSEY'
#  'MEXICANOS EN OHIO'
#  'Mexicanos Unidos en Tri Estatal\nNew York, New Jersey,Manhhatan Connecticut.'
#  'Mexicanos en Dallas' 'Mexicanos en Rhode Island 🇲🇽🇺🇸'
#  'Mexicanos en San Antonio'
#  'Mexicanos en Houston. Trabajo amistad y lo que se de..'
#  'Mexicanos en San Francisco California' 'mexicanos en passaic New Jersey'
#  'MEXICANOS UNIDOS DE HAVERSTRAW NEW YORK'
#  'Mexicanos en el Estado de Virginia' 'Mexicanos en The Woodlands'
#  'Mexicanos y Latinos en Montana' 'Cubanos en miami,fl'
#  'CUBANOS EN HOUSTON Y MÁS' 'CUBANOS EN HOUSTON'
#  'CUBANOS EN ORLANDO,FLORIDA' 'Cubanos en Chicago'
#  'Cubanos en Somos Miami' 'Cubanos en Dallas' 'CUBANOS EN HOUSTON tx'
#  '+ Cubanos en Miami 🇨🇺'
#  'Cubanos en New Jersey, New York , Pennsylvania y Connecticut. Unete'
#  'Cubanos En Dallas' 'CUBANOS EN ORLANDO' 'CUBANOS EN PALM BEACH'
#  'Cubanos en North Carolina' 'cubanos en Houston Texas'
#  'Cubanos en DFW Texas'
#  'CUBANOS Y LATINOS RESIDENTES EN MIAMI BEACH. FLORIDA. UNETE.'
#  'Cubans in Ohio - Cubanos en Ohio' 'Cubanos en Houston y alrededores'
#  "Cubans and Hispanics who grew up in Miami during the 60's and 70's"
#  'Dominicanos en Houston' 'Dominicanos en Houston Texas'
#  'Dominicanos en Centro Texas' 'Dominicanos en Miami Y USA'
#  'Dominicanos en Orlando.' 'Dominicanos en orlando kissimmee'
#  'Dominicanos en Rhode Island' 'Dominicanos en las vegas nv'
#  'Asociación de Ecuatorianos DFW' 'Ecuatorianos en Orlando'
#  'ECUATORIANOS en NEW YORK (NY)' 'Ecuatorianos en Chicago y alrededores'
#  'ECUATORIANOS EN NEW YORK &  NEW JERSEY'
#  'ECUATORIANOS EN LA CIUDAD DE NEW YORK'
#  'Ecuatorianos en Virginia-DC-Maryland' 'ECUATORIANOS EN NEW YORK'
#  'Ecuatorianos  En Chicago' 'Ecuatorianos en La Florida'
#  'Colombianos Venezolanos Mexicanos Latinos en Katy'
#  'Mexicanos en Florida Central' 'Mexicanos en California 🇲🇽🇺🇸'
#  'Mexicanos en Arizona 🇲🇽🇺🇸' 'Mexicanos en California USA u otros estados'
#  'Mexicanos En Connecticut' 'MEXICANOS Y CENTRO AMERICANOS EN LAS VEGAS'
#  'Numeros ke repiten de las loterias dominicanas y new york'
#  'Latinos en Florida, Broward & Miami Dade'
#  'Latinos en Compro y Vendo en St Louis Missouri' 'LATINOS EN NEW YORK'
#  'TRABAJOS PARA LATINOS - HOUSTON'
#  'latinos en maryland , washington dc y virginia '
#  'LATINOS FOR TRUMP OREGON' 'Latinos en New Jersey (NJ) y New York (NY)'
#  'Latinos en New Jersey y areas cercanas' '☀️ Latinos en Miami 🌴'
#  'Latinos en Oregon' 'latinos en New York' 'Latinos en Minnesota'
#  'Latinos en Texas' 'Latinos in Tech - Washington'
#  'Latinos Unidos En Massachusetts'
#  'TRABAJO PARA LATINOS  EN ST LOUIS MISSOURI' 'Pennsylvania Latinos'
#  'Negocios Y Eventos Latinos en Minnesota'
#  'Peruanos Unidos en DC, Maryland & Virginia'
#  'peruanos  en new  york y new jersey  de todas las sangres'
#  'Peruanos en New Jersey' 'Peruanos en Massachusetts'
#  'Peruanos en Minnesota' 'Peruanos en Orlando, Fl'
#  'Peruvian Americans of New Jersey USA  Peruanos Americanos de New Jersey USA'
#  'Peruanos en Texas' 'Eventos peruanos en washington maryland y virginia'
#  'APU Asociación Peruanos Unidos de Massachusetts' 'Peruanos en Chicago'
#  'Peruanos en Washington DC área (DC, Maryland y Virginia -DMV)'
#  'Peruanos Unidos En utah🇵🇪👋' 'Peruanos en Utah'
#  'Peruanos de Corazon NY NJ' 'Peruanos en Rhode Island'
#  'PERUANOS EN FLORIDA' 'VENEZOLANOS EN  KATY,TX' 'venezolanos En Austin'
#  'Venezolanos en Colorado' 'Venezolanos en Charlotte NC'
#  'Grupo de Venezolanos Activos en Georgia' 'Venezolanos en Nashville'
#  'Venezolanos en La Florida' 'Ciudadanos Venezolanos en Atlanta.'
#  'Venezolanos en Florida.' 'Venezolanos Solidarios En Kendall'
#  'Venezolanos En Tampa Bay Oficial' 'Venezolanos en NY'
#  'Venezolanos en Boston' 'Pennsylvania Latinos for Joe Biden'
#  'Oakland Latinos United (Unidos)' 'Acción y Alertas Latinos Wisconsin'
#  'LATINOS EN OREGON' 'Latinos en Houston Texas'
#  'Latinos en Charlotte North Carolina'
#  'Chilenos Latinos unidos en NY NJ PA OH by Orlando Abarzua ...'
#  'Latinos en San Antonio, TX' 'latinos Unidos❤en houston tx'
#  'Latinos en todo Massachusetts USA' 'Latinos in Tennessee'
#  'Latinos en Orlando Florida'
#  'Entre Latinos...Venta,Compra,Ofrece trabajo y Servicios En Todo Houston!'
#  'Latinos en Clarksville Tennessee' 'Latinos sur de Oregon'
#  'Latinos en Missouri' 'Latinos Emprendedores en New York'
#  'LGBTQ LATINOS, BOSTON, RHODE ISLAND, CONNECTICUT, NEW YORK Y NEW JERSEY.'
#  'Latinos se unen en Orlando y Kissimmee Florida'
#  'Latinos en forked river, lakewood y todo New jersey'
#  'Latinos San Diego/Tijuana' 'Latinos de Boulder County'
#  'Latinos en Houston'
#  'Buffalo, New York, West Side Latinos Stand Up !!!!!!'
#  'Latinos en Madison, Wisconsin' 'Craigslista Latinos en Minnesota'
#  'Latinos Unidos en murfreesboro tennessee' 'The Washington DC Latinos!'
#  'Latinos Unidos En South Carolina'
#  'Latinos En Philadelpia New Jersey & New York'
#  'Latinos En South Carolina' 'Negocios Latinos en Wisconsin'
#  'Latinos Over 40 Houston, TX Group' 'Latinos en Oklahoma City - Oklahoma'
#  'Profesionales latinos en Kissimmee y Orlando anunciate'
#  'Richmond,Oakland,San Francisco, San Jose y los alrededores.,Latinos'
#  'Latinos Cristianos de Kissimmee y Orlando'
#  'Latinos Over 40 McAllen, TX Group'
#  'LATINOS EN FORT LAUDERDALE - MIAMI & ALREDEDORES'
#  'LATINOS MIAMI FLORIDA USA' 'Latinos en Las Vegas'
#  'Latinos en Dallas - Fort Worth' 'Latinos en South Dakota'
#  'Latinos en Youngstown, Ohio' 'Colombo-Venezolano latinos en Utah'
#  'Latinos en Miami' 'Las Vegas Hispanos y Latinos'
#  'Latinos En Atlanta Official' 'Latinos en Plainfields'
#  'Datos de Trabajos y Ventas Latinos en Broward - Weston - Miami'
#  'Latinos Columbus' 'Marketing  Latinos en Atlanta  ( USA )'
#  'Latinos en SALT LAKE CITY' 'LATINOS EN CINCINNATI!!😉'
#  'Latinos por Biden 2020 Nevada' 'latinos unidos de cincinnati'
#  'TRABAJO EN SAVANNAH PARA LATINOS' 'Latinos en utah'
#  'EVENTOS LATINOS EN UTAH' 'Latinos en SWFL' 'Latinos en Fayetteville NC'
#  'LATINOS EN UTAH' 'Latinos en los Angeles California compra y venta'
#  'Latinos en Tampa Bay official'
#  'Blue Cross and Blue Shield of Texas Latino'
#  'Institute of  Hispanic Culture of Houston' 'Latinos en New York'
#  'Texas Latino Conservatives' 'Latino Mix Houston' 'Latino Mix Chicago'
#  'Texas Louisiana Hispanic District'
#  'Latino Awards Chicago by Zonika TV Radio Fm'
#  'Miami-Dade Cuban-American Dems' 'San Diego Latino Health Coalition'
#  'La Mesa Boricua de Florida' 'Consulado de El Salvador en Virginia'
#  'Latino Mix Dallas' 'Dallas Unidos por El Salvador'
#  'Latinos En Michigan TV' 'Blue Cross and Blue Shield of Oklahoma Latino'
#  'Afro-Latino Festival of New York'
#  'Blue Cross and Blue Shield of New Mexico Latino' 'Zelda Latino New York'
#  'Oakland Latinos United'
#  'VACOLAO - Virginia Coalition of Latino Organizations'
#  'Mexicanos en Miami' 'San Diego Latino Film Festival'
#  'Consulado General de El Salvador en Las Vegas Nevada'
#  'Consulado General de El Salvador  Boston Massachusetts' 'Latino Dallas'
#  'Hispanic Heritage Council of Western New York Inc.'
#  'Hispanic/Latino Commission of Michigan'
#  'Palm Beach County Hispanic Bar Association'
#  'San Antonio Hispanic Chamber of Commerce'
#  "Hispanic Women's Network of Texas" 'Venezolanos En Houston'
#  'Oregon Latino Health Coalition' 'Hispanic Center of Western Michigan'
#  'Maryland Hispanic Business Conference' 'Latino Union of Chicago'
#  'Chicago Boricua Resistance' 'Washington Office on Latin America - WOLA'
#  'Latino Chamber of Commerce of SE Wisconsin Inc'
#  'Chicago Latino Film Festival'
#  'Ohio Hispanic Coalition - Coalicin Hispana de Ohio'
#  'Massachusetts Latino Police Officers Association'
#  'El Paso Hispanic Chamber' 'West Michigan Hispanic Chamber of Commerce'
#  'New Braunfels Hispanic Business Alliance'
#  'Virginia Hispanic Chamber of Commerce' 'Latino News of Tennessee'
#  'Consulado Peru En Dallas' 'Latino Mix Phoenix' 'Latin New York'
#  'Latino Community Fund of Washington State'
#  'Hispanic Chamber of Commerce Metro Orlando'
#  'Houston Hispanic Chamber of Commerce' 'Rhode Island Latino Arts'
#  'NHPO Houston - National Hispanic Professional Organization'
#  'South Carolina Latina Project' 'New York Latino Film Festival'
#  'Nebraska Latino American Commission' 'Chicago Latin Fitness'
#  'National Hispanic Institute at San Antonio'
#  'Minnesota Council on Latino Affairs'
#  'Ohio Commission on Hispanic/Latino Affairs (OCHLA)'
#  'The Latin School of Chicago - Official Alumni Page'
#  'Consulado de El Salvador en Seattle Washington'
#  'San Diego County Hispanic Chamber of Commerce'
#  'Latino Muslims of New York' 'The Maryland Hispanic Chamber of Commerce'
#  'Latin Chamber of Commerce Nevada'
#  'North Carolina Hispanic Chamber of Commerce'
#  'New Jersey Center for Hispanic Policy Research and Development'
#  'Pennsylvania Commission on Latino Affairs' 'Houston Latina Bloggers'
#  'Ayudas y Recursos para la Comunidad Hispana de Orlando FL'
#  'Latin Ballet of Virginia' 'Oakland Latino Firefighters Association'
#  'El Sol Latino Newspaper Miami'
#  'Washington State Commission on Hispanic Affairs'
#  'Amaryllis aka The Latin Phoenix' 'Miami Latin Festival'
#  'Nevada Hispanic Business Group' 'Texas Latin Conference'
#  'Greater Oklahoma City Hispanic Chamber of Commerce'
#  'San Francisco Latino Historical Society'
#  'Palm Beach County Latin Entrepreneurs' 'Venezolanos En Nebraska'
#  'Chicago Latino Caucus Foundation'
#  'Washington State Latino Leadership Network'
#  'El Fogon Mexican Grill Riverside'
#  'Northern Virginia Hispanic Chamber of Commerce'
#  'Oregon Hispanic Bar Association'
#  'Consulado El Salvador en McAllen Texas' 'Latino Muslims of Chicago'
#  'Chicago Teachers Union Latinx Caucus' 'New Jersey Hispano'
#  'GWHCC - Greater Washington Hispanic Chamber of Commerce'
#  'Latin American Student Association - South Dakota State University'
#  'Greater Riverside Hispanic Chamber of Commerce'
#  'Washington Hispanic Newspaper'
#  'National Latina Business Women Association-San Diego [NLBWA-SD]'
#  'Nebraska Hispanic Chamber of Commerce'
#  'Peridico El Latino / Largest Hispanic Newspaper in San Diego'
#  'The Latin Phoenix Creperie'
#  'New York State  Black Puerto Rican Hispanic and Asian Legislative Caucus'
#  'San Diego Latino News' 'Mi San Diego Latinx North County'
#  'Cubanos en Houston' 'Chicago New Latino Movement'
#  'Chicago Latinos in Philanthropy' 'New York Soccer Latin Academy NYSLA'
#  'New Jersey Latinos for Bernie'
#  'Washington State Latinos Con Bernie Sanders' 'LGBT Latinos of Orlando'
#  'Latino Giving Houston' 'Dallas latino WSB' 'Tu Orlando Latino'
#  'Latinos En La Ciudad de New York by the Fox'
#  'Latinos / Hispanics Over 40 New York NY'
#  'New York Latino Publishing   NYLP ' 'Latino New York Magazine']
# 505

# %%
print(len(com))
print(len(pol))
print(len(news))
# Out:
# 13939
# 2921
# 9674

# %%
#column 1 = group, column 2 = 'name' column 3 = 'frequency'

group = []
name = []
frequency = []
#community
for x in range(len(com)):
    
    # new row
    if com['name'].iloc[x] not in name:
        #append new name
        name.append(com['name'].iloc[x])
        #create new row
        group.append('Community')
        #give value of 1
        frequency.append(1)
    else:
        v = name.index(com['name'].iloc[x])
        frequency[v] +=1

#political
for x in range(len(pol)):
    if pol['name'].iloc[x] not in name:
        #append new name
        name.append(pol['name'].iloc[x])
        #create new row
        group.append('Political')
        #give value of 1
        frequency.append(1)
    else:
        v = name.index(pol['name'].iloc[x])
        frequency[v] +=1
        
#news
for x in range(len(news)):
    if news['name'].iloc[x] not in name:
        #append new name
        name.append(news['name'].iloc[x])
        #create new row
        group.append('News')
        #give value of 1
        frequency.append(1)
    else:
        v = name.index(news['name'].iloc[x])
        frequency[v] +=1

dict = {'name': name, 'group': group, 'frequency': frequency}
df = pd.DataFrame(dict)
df
# Out:
#                                                   name      group  frequency
# 0                Hispanos unidos en New York (H.U.N.Y)  Community         48
# 1                            Hispanos en Columbus Ohio  Community         97
# 2    Cristianos Hispanos en Dallas, Texas ( Metroplex)  Community          7
# 3                                 Hispanos en Oklahoma  Community         46
# 4            Hispanos unidos en el gabacho (Tennessee)  Community          1
# ..                                                 ...        ...        ...
# 987                                      La Isla Oeste       News          1
# 988                                El Semanal Magazine       News          1
# 989                                         Ohio Habla       News          1
# 990                            Impacto Latin Newspaper       News          1
# 991                                     El Extra Texas       News          1
#
# [992 rows x 3 columns]

# %%
import seaborn as sns

sns.catplot(x='group', y = 'frequency', data =df, dodge=True, kind = 'violin', aspect =2)

# %%
sns.catplot(x='group', y ='frequency', data=df, kind ='strip')

# %%
sns.catplot(x='frequency', y ='group', data=df, kind ='violin')

# %%
#Levene Test
import scipy.stats as stats
#establish three groups
group_col = []
group_pol = []
group_new = []
for x in range(len(df)):
    if df['group'][x] == "Community":
        group_col.append(df['frequency'][x])
    if df['group'][x] == "Political":
        group_pol.append(df['frequency'][x])
    if df['group'][x] == "News":
        group_new.append(df['frequency'][x])
        
stats.levene(group_col, group_pol, group_new, center='median')
# Out:
# LeveneResult(statistic=0.6513366242359356, pvalue=0.5215719521153519)

# %%
stats.levene(group_col, group_pol, group_new, center='mean')
# Out:
# LeveneResult(statistic=0.6863725122169367, pvalue=0.5036384620614518)

# %%
from pingouin import welch_anova
aov = welch_anova(dv='frequency', between='group', data=df)
aov
# Out:
#   Source  ddof1       ddof2         F     p-unc      np2
# 0  group      2  380.077924  0.978666  0.376757  0.00176

# %%
stats.f_oneway(group_col, group_pol, group_new)
# Out:
# F_onewayResult(statistic=0.8719124014568054, pvalue=0.4184722845010649)

# %%
stats.mannwhitneyu(group_col, group_pol)
# Out:
# MannwhitneyuResult(statistic=30445.5, pvalue=0.001410098618039398)

# %%
stats.mannwhitneyu(group_new, group_pol)
# Out:
# MannwhitneyuResult(statistic=19416.5, pvalue=9.475146680604235e-05)

# %%
stats.ttest_ind(group_col, group_pol, equal_var = False)
# Out:
# Ttest_indResult(statistic=1.3402124172988696, pvalue=0.1815555037092798)

# %%
stats.ttest_ind(group_new, group_pol, equal_var = False)
# Out:
# Ttest_indResult(statistic=1.2181769441423962, pvalue=0.22400744458894245)

# %%
import numpy

numpy.mean(group_col)
# Out:
# 27.746534653465346

# %%
numpy.sum(group_col)
# Out:
# 14012

# %%
numpy.mean(group_pol)
# Out:
# 19.90277777777778

# %%
numpy.sum(group_pol)
# Out:
# 2866

# %%
numpy.sum(group_new)
# Out:
# 9656

# %%
numpy.mean(group_new)
# Out:
# 28.151603498542276
