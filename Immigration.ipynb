# %%
import pandas as pd

#readcsv file date
com = pd.read_csv("community/FB_groups_States_immigration.csv", sep= ",")
pol = pd.read_csv("political/Topics_FB_Political_Posts_per_partyimmigration.csv", sep = ",")
news = pd.read_csv("news/FB_groups_News_Media_Outlets_immigration.csv", sep=",")

# %%
com.head()
# Out:
#    Unnamed: 0                                   name  \
# 0        1221  Hispanos unidos en New York (H.U.N.Y)
# 1        2627  Hispanos unidos en New York (H.U.N.Y)
# 2        3588  Hispanos unidos en New York (H.U.N.Y)
# 3        4013  Hispanos unidos en New York (H.U.N.Y)
# 4        6314              Hispanos en Columbus Ohio
#
#                                 Page or Account URL                   List  \
# 0   https://www.facebook.com/groups/793416207356486  Latinos+EstadosGroups
# 1   https://www.facebook.com/groups/793416207356486  Latinos+EstadosGroups
# 2   https://www.facebook.com/groups/793416207356486  Latinos+EstadosGroups
# 3   https://www.facebook.com/groups/793416207356486  Latinos+EstadosGroups
# 4  https://www.facebook.com/groups/1450333408570918  Latinos+EstadosGroups
#
#       State     state       Facebook Id  \
# 0  New York  New York   793416207356486
# 1  New York  New York   793416207356486
# 2  New York  New York   793416207356486
# 3  New York  New York   793416207356486
# 4      Ohio      Ohio  1450333408570918
#
#                               Group Name User Name  Likes at Posting  ...  \
# 0  Hispanos unidos en New York (H.U.N.Y)       NaN            6242.0  ...
# 1  Hispanos unidos en New York (H.U.N.Y)       NaN            6368.0  ...
# 2  Hispanos unidos en New York (H.U.N.Y)       NaN            6508.0  ...
# 3  Hispanos unidos en New York (H.U.N.Y)       NaN            6512.0  ...
# 4              Hispanos en Columbus Ohio       NaN            8973.0  ...
#
#   Final Link                                         Image Text  \
# 0        NaN                                                NaN
# 1        NaN  Juez Federal de California, Jeffrey White, can...
# 2        NaN  Queens Defenders Presents: QUEENS DEFENDERS KN...
# 3        NaN  DE VISAS VISAS AMERICANAS USA ECUADOR NFERENCI...
# 4        NaN                                                NaN
#
#                          Link Text  \
# 0          NYC Council District 38
# 1                    NoVa Law Firm
# 2                 Queens Defenders
# 3                 Loteria de Visas
# 4  Legal Immigration Services, LLC
#
#                                          Description  Sponsor Id  \
# 0  New Immigration Fees Starting October 2! \n\nN...         NaN
# 1  ¡Buenas noticias!\nEl Juez Jeffrey White, de C...         NaN
# 2  Join us this Thursday for a Know Your Rights p...         NaN
# 3  👉 Quedan cordialmente invitados a la Conferenc...         NaN
# 4  🇺🇸 ✈️🇺🇸✈️🇺🇸✈️🇺🇸✈️🇺🇸✈️🇺🇸✈️🇺🇸✈️🇺🇸✈️🇺🇸\n Durante ...         NaN
#
#    Sponsor Name  Total Interactions  Overperforming Score  \
# 0           NaN                   1                 -33.0
# 1           NaN                   0                 -30.0
# 2           NaN                   2                 -16.5
# 3           NaN                   0                 -66.0
# 4           NaN                   1                 -34.0
#
#                                         MessageDescr  \
# 0   New Immigration Fees Starting October 2! \n\n...
# 1  El Juez Jeffrey White, de California, cancela ...
# 2   Join us this Thursday for a Know Your Rights ...
# 3   👉 Quedan cordialmente invitados a la Conferen...
# 4   🇺🇸 ✈️🇺🇸✈️🇺🇸✈️🇺🇸✈️🇺🇸✈️🇺🇸✈️🇺🇸✈️🇺🇸✈️🇺🇸\n Durante...
#
#                                          MessageOnly
# 0   New Immigration Fees Starting October 2! \n\n...
# 1  El Juez Jeffrey White, de California, cancela ...
# 2   Join us this Thursday for a Know Your Rights ...
# 3   👉 Quedan cordialmente invitados a la Conferen...
# 4   🇺🇸 ✈️🇺🇸✈️🇺🇸✈️🇺🇸✈️🇺🇸✈️🇺🇸✈️🇺🇸✈️🇺🇸✈️🇺🇸\n Durante...
#
# [5 rows x 39 columns]

# %%
pol.head()
# Out:
#    Unnamed: 0                     Group Name      User Name      Facebook Id  \
# 0         415              Latinos for Biden  Latinos4Biden  112443027004765
# 1         764     Latinos for Joe Biden 2020  LatinosforJoe  121155365229796
# 2        1600     Latinos for Joe Biden 2020  LatinosforJoe  121155365229796
# 3        1680     Latinos for Joe Biden 2020  LatinosforJoe  121155365229796
# 4        1823  Cuban Americans for Joe Biden            NaN  104474857952542
#
#    Likes at Posting                  Created          Type  Likes  Comments  \
# 0            2421.0  2020-10-23 11:27:26 EDT          Link     37        76
# 1            1927.0  2020-09-18 19:16:01 EDT          Link     56         2
# 2            1927.0  2020-09-17 23:03:21 EDT  Native Video     12         1
# 3            2231.0  2020-10-09 01:45:20 EDT          Link     16         0
# 4               NaN  2020-09-14 15:30:52 EDT          Link      5         5
#
#    Shares  ...  Image Text                                          Link Text  \
# 0       9  ...         NaN  Trump says most asylum seekers don’t show up f...
# 1      11  ...         NaN  Computing Pioneers Endorse Biden, Citing Trump...
# 2       4  ...         NaN                                   NowThis Politics
# 3       0  ...         NaN  Traditionally Republican Arizona now a Trump-B...
# 4       1  ...         NaN  68% Of Americans Do Not Trust What Trump Says ...
#
#                                          Description  Sponsor Id  \
# 0  This study contradicts Trump’s rationale for e...         NaN
# 1  They said the administration’s policies were d...         NaN
# 2  MEET THE LATINX LEADER GETTING OUT THE VOTE FO...         NaN
# 3  The economy and the coronavirus are top issues...         NaN
# 4  According to a new Fox News poll, likely voter...         NaN
#
#    Sponsor Name  Total Interactions Overperforming Score  \
# 0           NaN                 149                 1.33
# 1           NaN                  79                -1.33
# 2           NaN                  20                -2.70
# 3           NaN                  17                -4.41
# 4           NaN                  12                -1.92
#
#                                         MessageDescr  \
# 0  There you go! That man lies, lies, lies. https...
# 1  Tech leaders supporting Biden. https://www.nyt...
# 2  Check out Laura reppin' the Biden campaign! ME...
# 3  The old lines of the battle field have changed...
# 4  Even Fox News says a majority of Americans tru...
#
#                                          MessageOnly     party
# 0  There you go! That man lies, lies, lies. https...  Democrat
# 1  Tech leaders supporting Biden. https://www.nyt...  Democrat
# 2  Check out Laura reppin' the Biden campaign! ME...  Democrat
# 3  The old lines of the battle field have changed...  Democrat
# 4  Even Fox News says a majority of Americans tru...  Democrat
#
# [5 rows x 35 columns]

# %%
news.head()
# Out:
#    Unnamed: 0    Page Name  User Name       Facebook Id  Likes at Posting  \
# 0        1422   NBC Latino  NBCLatino   164878620263509          184649.0
# 1        1997   NBC Latino  NBCLatino   164878620263509          184664.0
# 2        2338   NBC Latino  NBCLatino   164878620263509          184643.0
# 3        3335     Remezcla   Remezcla      119685104266          700535.0
# 4        6311  We are mitú  wearemitu  1405630409737397         4042040.0
#
#                    Created  Type  Likes  Comments  Shares  ...  Sponsor Id  \
# 0  2020-08-22 11:55:10 EDT  Link    128       316     447  ...         NaN
# 1  2020-08-20 15:37:51 EDT  Link     50       246     284  ...         NaN
# 2  2020-08-29 14:18:42 EDT  Link    465        10     244  ...         NaN
# 3  2020-08-20 17:52:35 EDT  Link    371        31      91  ...         NaN
# 4  2020-08-18 21:45:46 EDT  Link    214         1      53  ...         NaN
#
#    Sponsor Name  Total Interactions  \
# 0           NaN               1,716
# 1           NaN               1,244
# 2           NaN               1,049
# 3           NaN                 726
# 4           NaN                 344
#
#    Total Interactions (weighted  —  Likes 1x Shares 1x Comments 1x Love 1x Wow 1x Haha 1x Sad 1x Angry 1x Care 1x )  \
# 0                                              1,716
# 1                                              1,244
# 2                                              1,049
# 3                                                726
# 4                                                344
#
#    Overperforming Score  clean_url       State  \
# 0                  4.97  nbclatino    New York
# 1                  3.61  nbclatino    New York
# 2                  3.10  nbclatino    New York
# 3                  8.54   remezcla    New York
# 4                  2.16  wearemitu  California
#
#                               Facebook  \
# 0  https://www.facebook.com/NBCLatino/
# 1  https://www.facebook.com/NBCLatino/
# 2  https://www.facebook.com/NBCLatino/
# 3   https://www.facebook.com/Remezcla/
# 4  https://www.facebook.com/wearemitu/
#
#                                         MessageDescr  \
# 0  'White supremacy' was behind child separations...
# 1  Trump cabinet officials voted in 2018 White Ho...
# 2  Remembering a journalism giant who "spoke trut...
# 3  The 11-year-old's video at the #DNC was an imp...
# 4  Even if you can't donate, there are many ways ...
#
#                                          MessageOnly
# 0  'White supremacy' was behind child separations...
# 1  Trump cabinet officials voted in 2018 White Ho...
# 2  Remembering a journalism giant who "spoke trut...
# 3  The 11-year-old's video at the #DNC was an imp...
# 4  Even if you can't donate, there are many ways ...
#
# [5 rows x 38 columns]

# %%
pol.rename(columns = {'Group Name': 'name'}, inplace=True)
news.rename(columns = {'Page Name': 'name'}, inplace=True)

# %%
print(pol.name.nunique())
print(pol.name.unique())
# Out:
# 80
# ['Latinos for Biden' 'Latinos for Joe Biden 2020'
#  'Cuban Americans for Joe Biden' 'Latinos Con Biden'
#  'Iowa Latinos for Joe Biden' 'Latinx Young Democrats'
#  'Latino Veterans con Biden' 'NC Latinos for Biden/Harris'
#  'Latinx Caucus of the Democratic Party of Georgia' 'Latinos Contra Trump'
#  'Latinos for Trump' 'Latinos For Trump 2020' 'Latinos For Trump-El Paso'
#  'Republican National Hispanic Assembly'
#  'Republican National Hispanic Assembly - New York Chapter'
#  'Latinos With Trump' 'Latinos For Trump -California'
#  'Latinos for Trump in Lea County' 'Latinos For Trump -Delaware'
#  'Latino National Republican Coalition' 'Latinos For Trump Network'
#  'Latinos For Trump -New Jersey' 'Latinos Saint Lucie County for Trump'
#  'Republican National Hispanic Assembly of Seminole County'
#  'Republican National Hispanic Assembly of Polk County'
#  'Latinos For Trump Colorado' 'Latinos For Trump en Espaol'
#  'Latinos for Trump 2020 -California' 'Latinos For Trump - Michigan'
#  'The Latinos For Trump Flag'
#  'Republican National Hispanic Assembly of Osceola County'
#  'Mexican Chicas For Trump' 'Latinos For Trump - New Mexico'
#  'Latinos For Trump - Illinois'
#  'Republican National Hispanic Assembly New Jersey Chapter'
#  'Republican National Hispanic Assembly of Charlotte'
#  'Republican National Hispanic Assembly of Palm Beach County'
#  'Latinos For Trump -Pennsylvania' 'Latinos For Trump -Missouri'
#  'Latinos For Trump -Georgia' 'Latinos For Trump Wisconsin'
#  'Latinos For Trump Virginia' 'Latinos For Trump Washington D. C.'
#  'Latinos Against Donald Trump' 'Pennsylvania Latinos for Joe Biden'
#  'African Americans & Latinos for Biden & Harris'
#  'Latinos and Allies of Nebraska Against Trump' 'Latinos contra Trump'
#  'Mexicans/Chicanos/Natives HATE Trump' 'Salvadoreos Con Biden'
#  'LATINX for BIDEN/ HARRIS' 'Cuban Americans & friends for Biden'
#  'Latinos Against Trump' 'Dominicanos/Florida con Joe Biden'
#  'Latino Leaders Against Crooked Lying Trump Ruining America'
#  'Latinos United Against  Donald Trump'
#  'LAATinos (Latinos & Americans Against Trump)'
#  'CARA - Cuban American Republican Alliance'
#  'Latinos For Trump -California Group' 'DONALD TRUMP PARA HISPANOS'
#  'Puertorican Republican and Latin Conservative Movement'
#  'Latinos For Trump.'
#  'Tarrant County Republican National Hispanic Assembly'
#  'Latino Republican National Federation'
#  'TRUMP--LATINOS EXIGEN UNA VICTORIA APLASTANTE 2020'
#  'Republican National Hispanic Assembly - Official Group'
#  'Mexicans for Donald Trump' 'American Latinos for freedom! Trump 2020'
#  'Latinos For Trump' 'Republican National Hispanic Assembly of Virginia'
#  'Latinos for Trump - Jacksonville' 'Los Angeles Hispanic Republican Club'
#  'Latinos Blacks White Jewish - Trump Train & Trump Team'
#  'Trump Para Los hispanos'
#  'Latino National Republican Coalition - Houston Area'
#  'Latino National Republican Coalition of Maryland'
#  'Kentucky republican latinos' 'Hispanos con Donald Trump'
#  'Latinos 4 Trump' 'Latinos For Trump - Texas Group']

# %%
print(type(com))
print(type(com['name']))
print(type(com.name))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %%
com.name.fillna(com['Group Name'], inplace = True)
print(len(com))
com.tail()
# Out:
# 2714
#       Unnamed: 0                                               name  \
# 2709     1064381                              Latino Giving Houston
# 2710     1064485                              Latino Giving Houston
# 2711     1064812                                Latinos en New York
# 2712     1064945  Republican National Hispanic Assembly New Jers...
# 2713     1064968  Republican National Hispanic Assembly New Jers...
#
#      Page or Account URL List State state       Facebook Id  \
# 2709                 NaN  NaN   NaN   NaN   461202987236203
# 2710                 NaN  NaN   NaN   NaN   461202987236203
# 2711                 NaN  NaN   NaN   NaN  1444226155789217
# 2712                 NaN  NaN   NaN   NaN   108074727679268
# 2713                 NaN  NaN   NaN   NaN   108074727679268
#
#                                              Group Name         User Name  \
# 2709                              Latino Giving Houston      LatinoGiving
# 2710                              Latino Giving Houston      LatinoGiving
# 2711                                Latinos en New York  latinosennewyork
# 2712  Republican National Hispanic Assembly New Jers...    RNHANewJersey1
# 2713  Republican National Hispanic Assembly New Jers...    RNHANewJersey1
#
#       Likes at Posting  ...  \
# 2709               NaN  ...
# 2710               NaN  ...
# 2711               NaN  ...
# 2712               NaN  ...
# 2713               NaN  ...
#
#                                              Final Link  \
# 2709  https://www.facebook.com/login/?next=https%3A%...
# 2710  https://www.facebook.com/login/?next=https%3A%...
# 2711                                                NaN
# 2712                                                NaN
# 2713  https://www.facebook.com/login/?next=https%3A%...
#
#                                              Image Text  \
# 2709                                                NaN
# 2710  2021 IMMIGRATION ACTION PLAN Let's restore hum...
# 2711                                                NaN
# 2712  RAUL DANNY VARGAS Former Chairman of the Repub...
# 2713  Latinos FOR TRUMP 2020 AGAIN 30% OF LATINOS SU...
#
#                                               Link Text  \
# 2709                        Fe y Justicia Worker Center
# 2710                             Tahirih Justice Center
# 2711  El gobierno ya no otorgará al azar las visas H...
# 2712                                    Timeline Photos
# 2713                                                NaN
#
#                                             Description  Sponsor Id  \
# 2709  Attorney Omar O. Vargas has vast legal experie...         NaN
# 2710  Transforming the nation’s immigration system i...         NaN
# 2711  La propuesta de reglamentación señala que ahor...         NaN
# 2712                                                NaN         NaN
# 2713                                                NaN         NaN
#
#       Sponsor Name  Total Interactions  Overperforming Score  \
# 2709           NaN                   0                 -32.0
# 2710           NaN                   0                 -32.0
# 2711           NaN                   0                 -42.0
# 2712           NaN                   0                   0.0
# 2713           NaN                   0                   0.0
#
#                                            MessageDescr  \
# 2709  2013 Latino Giving Grantee Attorney Omar O. Va...
# 2710  2017 Latino Giving Grantee Transforming the na...
# 2711  Para rematar lo del covid, las leyes de immigr...
# 2712  Raul Danny Vargas served as Chairman of the Re...
# 2713  Many questions why Hispanics vote for trump or...
#
#                                             MessageOnly
# 2709  2013 Latino Giving Grantee Attorney Omar O. Va...
# 2710  2017 Latino Giving Grantee Transforming the na...
# 2711  Para rematar lo del covid, las leyes de immigr...
# 2712  Raul Danny Vargas served as Chairman of the Re...
# 2713  Many questions why Hispanics vote for trump or...
#
# [5 rows x 39 columns]

# %%
print(type(com))
print(type(com.name))
temp = com.name.tolist()
print(type(temp))
print(type(temp[0]))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# <class 'list'>
# <class 'str'>

# %%
cond = []
for x in temp:
    if 'Trump' in x:
        cond.append(x)
    if 'Democr' in x:
        cond.append(x)
    if 'Repub' in x:
        cond.append(x)
    if 'repub' in x:
        cond.append(x)

# %%
print(len(cond))
#v is index
v = []
for x in range(len(com['name'])):
    if com['name'][x] in cond:
        v.append(x)
print 

print(len(v))
for i in v:
    pol = pol.append(com.iloc[i])

com.drop(
    labels = v,
    axis =0,
    inplace=True
)

pol.tail()
print(com.name.unique())
# Out:
# 76
# 76
# ['Hispanos unidos en New York (H.U.N.Y)' 'Hispanos en Columbus Ohio'
#  'Hispanos en Oklahoma' 'Hispanos Unidos De Michigan'
#  'Hispanos en West Palm Beach FL'
#  'Hispanos en Massachusetts Online Compras & Ventas' 'Hispanos en Utah'
#  'Eventos Hispanos En Tennessee'
#  'COMPRE Y VENDE HISPANOS EN ST LOUIS MISSOURI Y SUS ALREDEDORES EN  ILLINOIS'
#  'Ayuda para Hispanos en Orlando'
#  'Comunidad Latina de New Jersey - Latino Community of NJ'
#  'SAN BERNARDINO SWAPMEET LATINO'
#  'Mundo Latino Network Group Nebraska, Iowa y South Dakota'
#  'Craigslist  Latino  Minnesota' 'MIAMI LATIN FESTIVAL'
#  'LATIN EVENTS SOUTH CAROLINA' 'DFW Latin Professionals'
#  'Columbus Ohio - Comunidad Latina y Trabajo Disponible'
#  'Boston, Massachusetts Fuerza Latina, Trabajos, Promotiones, Apartamentos'
#  'LA CHACHARA LATINA TEXAS' 'Hispanic Heritage Matters in Texas'
#  'Mercadito Hispano Salem Oregon'
#  'CASAS DE CONSTRUCCIÓN NUEVA EN OKLAHOMA- ALEJANDRO LAURENS REALTOR'
#  'La original yarda hispana de phoenix' 'Ticos en New Jersey'
#  'Ticos en Miami Dade' 'Boricuas en Dallas Y Fort Worth'
#  'BORICUAS 100 X 35 EN NORTH CAROLINA' 'BORICUAS EN KISSIMMEE Y ORLANDO'
#  'Boricuas en Orlando VIP'
#  'Boricuas Profesionales en Dallas y Ft. Worth -  Texas'
#  'Boricuas en Miami' 'BORICUAS EN CHARLOTTE NORTH CAROLINA'
#  'Boricuas en Killeen Texas' 'BORICUAS EN WISCONSIN' 'Boricuas en Ohio'
#  'PR NORTH CAROLINA' 'Boricuas en Miami Broward FortLauderdale Texas'
#  'Boricuas y Dominicanos En Massachusetts🇩🇴🇵🇷'
#  'BORICUAS EN POINCIANA & KISSIMMEE' 'JANGUEO BORICUA Miami'
#  'Soy Boricua en DFW' 'El Pulguero Boricua de Dallas y Fort Worth'
#  'Nicas Autoconvocados en Miami' 'Nicas Unidos En Miami'
#  'Nicas en San Francisco' 'Nicas en Miami'
#  'Argentinos En New Jersey 🇦🇷 Oficial' 'Argentinos en Miami'
#  'Argentinos en Houston, TX' 'Argentinos en Dallas Texas'
#  'Venezolanos en Miami' 'Venezolanos viviendo en Miami '
#  'Venezolanos en Orlando' 'Venezolanos En Orlando'
#  'Venezolanos en Chicago' 'Venezolanos en Dallas - Fort Worth'
#  'Venezolanos en Kissimmee' 'Venezolanos en Houston Tx'
#  'Venezolanos en new jersey' 'venezolanos en Orlando and Kissimmee'
#  'Venezolanos Unidos en D.C. Maryland & Virginia'
#  'Venezolanos en Washington D.C, Virginia and Maryland'
#  'Cuantos venezolanos hay en New York?' 'Venezolanos En Chicago 🇺🇸🇻🇪'
#  'Venezolanos en Wisconsin' 'Venezolanos y Latinos en Fort Lauderdale'
#  'Venezolanos unidos de Utah' 'Venezolanos en San Francisco'
#  'Profesionales y Comerciantes Venezolanos en San Diego y alrededores.'
#  'Venezolanos en Las Vegas Nevada'
#  'VENEZOLANOS EN EL TRI-STATE (OHIO, INDIANA, KENTUCKY)'
#  'Comunidad de Venezolanos en Minnesota - Venezuelan Community in MN'
#  'VENEZOLANOS EN TULSA-OKLAHOMA' 'Venezolanos en Minnesota'
#  'Venezolanos en Miami ' 'Venezolanos en Utah'
#  'VENEZOLANOS EN MIAMI,FLORIDA' 'VENEZOLANOS EN PENNSYLVANIA'
#  'Venezolanos viviendo en Frederick, Maryland, USA'
#  'Venezolanos en North Dallas - Addison - Carrolton - Famers Branch Etc'
#  'Venezolanos y Colombianos unidos en Miami.'
#  'Venezolanos en Missouri,Kansas, Arkansas, Iowa,Nebraska y Texas'
#  'Venezolanos en Paterson New Jersey y sus alrededores'
#  'Venezolanos en north carolina (ventas)' 'Venezolanos En Miami'
#  'Venezolanos viviendo en Miami  Grupo de Mundo24'
#  'Venezolanos en Wyoming' 'Peruanos en DC, Maryland & Virginia (DMV)'
#  'Peruanos en San Francisco Bay Area' 'PERUANOS EN NORTH DALLAS'
#  'Salvadoreños en San Francisco' 'SALVADOREÑOS EN HOUSTON®'
#  'Salvadoreños en Houston TX' 'Salvadoreños en Houston, Texas'
#  'Guatemaltecos en Miami' 'Hondureños en Dallas'
#  '🇭🇳Hondureños en Houston🇭🇳' 'Hondureños En Houston Texas'
#  'Hondureños en Dallas Fort  Worth' 'HONDUREÑOS EN HOUSTON, TX.'
#  'hondureños viviendo en miami: compra vende regala intercambia'
#  'Mexicanos en Texas 🇲🇽🇺🇸' 'Mexicanos unidos de utah'
#  'Mexicanos en st Louis Missouri' 'Mexicanos en washington virginia !!'
#  'Mexicanos En North Carolina' 'Mexicanos en Houston'
#  'MEXICANOS EN TENNESSEE' 'Mexicanos en Chicago'
#  'MEXICANOS EN ACCION ORLANDO Y KISSIMME' 'MEXICANOS EN OHIO'
#  'Mexicanos Unidos en Tri Estatal\nNew York, New Jersey,Manhhatan Connecticut.'
#  'Mexicanos en Dallas' 'Mexicanos en San Francisco California'
#  'Cubanos en miami,fl' 'CUBANOS EN HOUSTON' 'CUBANOS EN ORLANDO,FLORIDA'
#  'Cubanos en Chicago' 'Cubanos en Dallas' 'CUBANOS EN HOUSTON tx'
#  '+ Cubanos en Miami 🇨🇺' 'Cubanos En Dallas' 'Cubanos en North Carolina'
#  'cubanos en Houston Texas'
#  'CUBANOS Y LATINOS RESIDENTES EN MIAMI BEACH. FLORIDA. UNETE.'
#  'Cubans in Ohio - Cubanos en Ohio' 'Dominicanos en Houston Texas'
#  'Dominicanos en Miami Y USA' 'Dominicanos en Orlando.'
#  'Dominicanos en orlando kissimmee' 'Asociación de Ecuatorianos DFW'
#  'Ecuatorianos en Orlando' 'ECUATORIANOS en NEW YORK (NY)'
#  'ECUATORIANOS EN NEW YORK &  NEW JERSEY'
#  'ECUATORIANOS EN LA CIUDAD DE NEW YORK' 'Ecuatorianos en La Florida'
#  'Colombianos Venezolanos Mexicanos Latinos en Katy'
#  'Mexicanos en Florida Central' 'Mexicanos en California 🇲🇽🇺🇸'
#  'Mexicanos en California USA u otros estados' 'Mexicanos En Connecticut'
#  'Latinos en Florida, Broward & Miami Dade' 'LATINOS EN NEW YORK'
#  'TRABAJOS PARA LATINOS - HOUSTON'
#  'latinos en maryland , washington dc y virginia '
#  'Latinos en New Jersey (NJ) y New York (NY)'
#  'Latinos en New Jersey y areas cercanas' '☀️ Latinos en Miami 🌴'
#  'Latinos en Oregon' 'latinos en New York' 'Latinos en Texas'
#  'Latinos in Tech - Washington' 'Latinos Unidos En Massachusetts'
#  'Pennsylvania Latinos' 'Peruanos Unidos en DC, Maryland & Virginia'
#  'peruanos  en new  york y new jersey  de todas las sangres'
#  'Peruanos en New Jersey' 'Peruanos en Massachusetts'
#  'Peruanos en Orlando, Fl'
#  'Peruvian Americans of New Jersey USA  Peruanos Americanos de New Jersey USA'
#  'Peruanos de Corazon NY NJ' 'PERUANOS EN FLORIDA'
#  'VENEZOLANOS EN  KATY,TX' 'venezolanos En Austin'
#  'Venezolanos en Colorado' 'Venezolanos en Charlotte NC'
#  'Grupo de Venezolanos Activos en Georgia' 'Venezolanos en Nashville'
#  'Venezolanos en La Florida' 'Ciudadanos Venezolanos en Atlanta.'
#  'Venezolanos en Florida.' 'Venezolanos Solidarios En Kendall'
#  'Venezolanos En Tampa Bay Oficial' 'Venezolanos en NY'
#  'Venezolanos en Boston' 'Pennsylvania Latinos for Joe Biden'
#  'Oakland Latinos United (Unidos)' 'Acción y Alertas Latinos Wisconsin'
#  'Latinos en Houston Texas' 'Latinos en Charlotte North Carolina'
#  'Latinos en San Antonio, TX' 'Latinos en todo Massachusetts USA'
#  'Latinos in Tennessee' 'Latinos en Orlando Florida'
#  'Latinos en Clarksville Tennessee' 'Latinos sur de Oregon'
#  'Latinos en Missouri' 'Latinos Emprendedores en New York'
#  'LGBTQ LATINOS, BOSTON, RHODE ISLAND, CONNECTICUT, NEW YORK Y NEW JERSEY.'
#  'Latinos se unen en Orlando y Kissimmee Florida'
#  'Latinos San Diego/Tijuana' 'Latinos de Boulder County'
#  'Latinos Unidos en murfreesboro tennessee' 'North Dakota Latinos'
#  'The Washington DC Latinos!' 'Negocios Latinos en Wisconsin'
#  'Latinos Cristianos de Kissimmee y Orlando'
#  'LATINOS EN FORT LAUDERDALE - MIAMI & ALREDEDORES' 'Latinos en Las Vegas'
#  'Latinos en Dallas - Fort Worth' 'Latinos en South Dakota'
#  'Latinos en Youngstown, Ohio' 'Colombo-Venezolano latinos en Utah'
#  'Latinos en Miami' 'Latinos En Atlanta Official' 'Latinos en Plainfields'
#  'Latinos Columbus' 'Marketing  Latinos en Atlanta  ( USA )'
#  'Latinos en SALT LAKE CITY' 'latinos unidos de cincinnati'
#  'Latinos en utah' 'Latinos en SWFL' 'Latinos en Fayetteville NC'
#  'LATINOS EN UTAH' 'Latinos en los Angeles California compra y venta'
#  'Latinos en Tampa Bay official' 'Miami-Dade Cuban-American Dems'
#  'VACOLAO - Virginia Coalition of Latino Organizations'
#  'San Diego Latino Film Festival' 'Latino Dallas'
#  'Hispanic Heritage Council of Western New York Inc.'
#  'Palm Beach County Hispanic Bar Association'
#  'Oregon Latino Health Coalition' 'Latino Union of Chicago'
#  'Washington Office on Latin America - WOLA'
#  'Chicago Latino Film Festival'
#  'West Michigan Hispanic Chamber of Commerce'
#  'Latino Community Fund of Washington State' 'Chicago Latino Network'
#  'South Carolina Latina Project' 'Nebraska Latino American Commission'
#  'Latinos for Washington Inc.' 'Minnesota Council on Latino Affairs'
#  'New Jersey Center for Hispanic Policy Research and Development'
#  'Houston Latina Bloggers' 'New Mexico Hispanic Bar Association'
#  'Texas Senate Hispanic Caucus' 'Oakland Latino Firefighters Association'
#  'Washington State Commission on Hispanic Affairs'
#  'Society of Hispanic Professional Engineers - Michigan Tech'
#  'Hispanic Business Network - Chicago' 'Chicago Latino Caucus Foundation'
#  'Oregon Hispanic Bar Association' 'Chicago Teachers Union Latinx Caucus'
#  'Latin American Student Association - South Dakota State University'
#  'Nebraska Hispanic Chamber of Commerce' 'Latino Giving Houston'
#  'Latinos en New York']

# %%
print(len(com))
print(com.name.unique())
temp = []
temp = com.name.unique()
print(len(temp))
# Out:
# 2638
# ['Hispanos unidos en New York (H.U.N.Y)' 'Hispanos en Columbus Ohio'
#  'Hispanos en Oklahoma' 'Hispanos Unidos De Michigan'
#  'Hispanos en West Palm Beach FL'
#  'Hispanos en Massachusetts Online Compras & Ventas' 'Hispanos en Utah'
#  'Eventos Hispanos En Tennessee'
#  'COMPRE Y VENDE HISPANOS EN ST LOUIS MISSOURI Y SUS ALREDEDORES EN  ILLINOIS'
#  'Ayuda para Hispanos en Orlando'
#  'Comunidad Latina de New Jersey - Latino Community of NJ'
#  'SAN BERNARDINO SWAPMEET LATINO'
#  'Mundo Latino Network Group Nebraska, Iowa y South Dakota'
#  'Craigslist  Latino  Minnesota' 'MIAMI LATIN FESTIVAL'
#  'LATIN EVENTS SOUTH CAROLINA' 'DFW Latin Professionals'
#  'Columbus Ohio - Comunidad Latina y Trabajo Disponible'
#  'Boston, Massachusetts Fuerza Latina, Trabajos, Promotiones, Apartamentos'
#  'LA CHACHARA LATINA TEXAS' 'Hispanic Heritage Matters in Texas'
#  'Mercadito Hispano Salem Oregon'
#  'CASAS DE CONSTRUCCIÓN NUEVA EN OKLAHOMA- ALEJANDRO LAURENS REALTOR'
#  'La original yarda hispana de phoenix' 'Ticos en New Jersey'
#  'Ticos en Miami Dade' 'Boricuas en Dallas Y Fort Worth'
#  'BORICUAS 100 X 35 EN NORTH CAROLINA' 'BORICUAS EN KISSIMMEE Y ORLANDO'
#  'Boricuas en Orlando VIP'
#  'Boricuas Profesionales en Dallas y Ft. Worth -  Texas'
#  'Boricuas en Miami' 'BORICUAS EN CHARLOTTE NORTH CAROLINA'
#  'Boricuas en Killeen Texas' 'BORICUAS EN WISCONSIN' 'Boricuas en Ohio'
#  'PR NORTH CAROLINA' 'Boricuas en Miami Broward FortLauderdale Texas'
#  'Boricuas y Dominicanos En Massachusetts🇩🇴🇵🇷'
#  'BORICUAS EN POINCIANA & KISSIMMEE' 'JANGUEO BORICUA Miami'
#  'Soy Boricua en DFW' 'El Pulguero Boricua de Dallas y Fort Worth'
#  'Nicas Autoconvocados en Miami' 'Nicas Unidos En Miami'
#  'Nicas en San Francisco' 'Nicas en Miami'
#  'Argentinos En New Jersey 🇦🇷 Oficial' 'Argentinos en Miami'
#  'Argentinos en Houston, TX' 'Argentinos en Dallas Texas'
#  'Venezolanos en Miami' 'Venezolanos viviendo en Miami '
#  'Venezolanos en Orlando' 'Venezolanos En Orlando'
#  'Venezolanos en Chicago' 'Venezolanos en Dallas - Fort Worth'
#  'Venezolanos en Kissimmee' 'Venezolanos en Houston Tx'
#  'Venezolanos en new jersey' 'venezolanos en Orlando and Kissimmee'
#  'Venezolanos Unidos en D.C. Maryland & Virginia'
#  'Venezolanos en Washington D.C, Virginia and Maryland'
#  'Cuantos venezolanos hay en New York?' 'Venezolanos En Chicago 🇺🇸🇻🇪'
#  'Venezolanos en Wisconsin' 'Venezolanos y Latinos en Fort Lauderdale'
#  'Venezolanos unidos de Utah' 'Venezolanos en San Francisco'
#  'Profesionales y Comerciantes Venezolanos en San Diego y alrededores.'
#  'Venezolanos en Las Vegas Nevada'
#  'VENEZOLANOS EN EL TRI-STATE (OHIO, INDIANA, KENTUCKY)'
#  'Comunidad de Venezolanos en Minnesota - Venezuelan Community in MN'
#  'VENEZOLANOS EN TULSA-OKLAHOMA' 'Venezolanos en Minnesota'
#  'Venezolanos en Miami ' 'Venezolanos en Utah'
#  'VENEZOLANOS EN MIAMI,FLORIDA' 'VENEZOLANOS EN PENNSYLVANIA'
#  'Venezolanos viviendo en Frederick, Maryland, USA'
#  'Venezolanos en North Dallas - Addison - Carrolton - Famers Branch Etc'
#  'Venezolanos y Colombianos unidos en Miami.'
#  'Venezolanos en Missouri,Kansas, Arkansas, Iowa,Nebraska y Texas'
#  'Venezolanos en Paterson New Jersey y sus alrededores'
#  'Venezolanos en north carolina (ventas)' 'Venezolanos En Miami'
#  'Venezolanos viviendo en Miami  Grupo de Mundo24'
#  'Venezolanos en Wyoming' 'Peruanos en DC, Maryland & Virginia (DMV)'
#  'Peruanos en San Francisco Bay Area' 'PERUANOS EN NORTH DALLAS'
#  'Salvadoreños en San Francisco' 'SALVADOREÑOS EN HOUSTON®'
#  'Salvadoreños en Houston TX' 'Salvadoreños en Houston, Texas'
#  'Guatemaltecos en Miami' 'Hondureños en Dallas'
#  '🇭🇳Hondureños en Houston🇭🇳' 'Hondureños En Houston Texas'
#  'Hondureños en Dallas Fort  Worth' 'HONDUREÑOS EN HOUSTON, TX.'
#  'hondureños viviendo en miami: compra vende regala intercambia'
#  'Mexicanos en Texas 🇲🇽🇺🇸' 'Mexicanos unidos de utah'
#  'Mexicanos en st Louis Missouri' 'Mexicanos en washington virginia !!'
#  'Mexicanos En North Carolina' 'Mexicanos en Houston'
#  'MEXICANOS EN TENNESSEE' 'Mexicanos en Chicago'
#  'MEXICANOS EN ACCION ORLANDO Y KISSIMME' 'MEXICANOS EN OHIO'
#  'Mexicanos Unidos en Tri Estatal\nNew York, New Jersey,Manhhatan Connecticut.'
#  'Mexicanos en Dallas' 'Mexicanos en San Francisco California'
#  'Cubanos en miami,fl' 'CUBANOS EN HOUSTON' 'CUBANOS EN ORLANDO,FLORIDA'
#  'Cubanos en Chicago' 'Cubanos en Dallas' 'CUBANOS EN HOUSTON tx'
#  '+ Cubanos en Miami 🇨🇺' 'Cubanos En Dallas' 'Cubanos en North Carolina'
#  'cubanos en Houston Texas'
#  'CUBANOS Y LATINOS RESIDENTES EN MIAMI BEACH. FLORIDA. UNETE.'
#  'Cubans in Ohio - Cubanos en Ohio' 'Dominicanos en Houston Texas'
#  'Dominicanos en Miami Y USA' 'Dominicanos en Orlando.'
#  'Dominicanos en orlando kissimmee' 'Asociación de Ecuatorianos DFW'
#  'Ecuatorianos en Orlando' 'ECUATORIANOS en NEW YORK (NY)'
#  'ECUATORIANOS EN NEW YORK &  NEW JERSEY'
#  'ECUATORIANOS EN LA CIUDAD DE NEW YORK' 'Ecuatorianos en La Florida'
#  'Colombianos Venezolanos Mexicanos Latinos en Katy'
#  'Mexicanos en Florida Central' 'Mexicanos en California 🇲🇽🇺🇸'
#  'Mexicanos en California USA u otros estados' 'Mexicanos En Connecticut'
#  'Latinos en Florida, Broward & Miami Dade' 'LATINOS EN NEW YORK'
#  'TRABAJOS PARA LATINOS - HOUSTON'
#  'latinos en maryland , washington dc y virginia '
#  'Latinos en New Jersey (NJ) y New York (NY)'
#  'Latinos en New Jersey y areas cercanas' '☀️ Latinos en Miami 🌴'
#  'Latinos en Oregon' 'latinos en New York' 'Latinos en Texas'
#  'Latinos in Tech - Washington' 'Latinos Unidos En Massachusetts'
#  'Pennsylvania Latinos' 'Peruanos Unidos en DC, Maryland & Virginia'
#  'peruanos  en new  york y new jersey  de todas las sangres'
#  'Peruanos en New Jersey' 'Peruanos en Massachusetts'
#  'Peruanos en Orlando, Fl'
#  'Peruvian Americans of New Jersey USA  Peruanos Americanos de New Jersey USA'
#  'Peruanos de Corazon NY NJ' 'PERUANOS EN FLORIDA'
#  'VENEZOLANOS EN  KATY,TX' 'venezolanos En Austin'
#  'Venezolanos en Colorado' 'Venezolanos en Charlotte NC'
#  'Grupo de Venezolanos Activos en Georgia' 'Venezolanos en Nashville'
#  'Venezolanos en La Florida' 'Ciudadanos Venezolanos en Atlanta.'
#  'Venezolanos en Florida.' 'Venezolanos Solidarios En Kendall'
#  'Venezolanos En Tampa Bay Oficial' 'Venezolanos en NY'
#  'Venezolanos en Boston' 'Pennsylvania Latinos for Joe Biden'
#  'Oakland Latinos United (Unidos)' 'Acción y Alertas Latinos Wisconsin'
#  'Latinos en Houston Texas' 'Latinos en Charlotte North Carolina'
#  'Latinos en San Antonio, TX' 'Latinos en todo Massachusetts USA'
#  'Latinos in Tennessee' 'Latinos en Orlando Florida'
#  'Latinos en Clarksville Tennessee' 'Latinos sur de Oregon'
#  'Latinos en Missouri' 'Latinos Emprendedores en New York'
#  'LGBTQ LATINOS, BOSTON, RHODE ISLAND, CONNECTICUT, NEW YORK Y NEW JERSEY.'
#  'Latinos se unen en Orlando y Kissimmee Florida'
#  'Latinos San Diego/Tijuana' 'Latinos de Boulder County'
#  'Latinos Unidos en murfreesboro tennessee' 'North Dakota Latinos'
#  'The Washington DC Latinos!' 'Negocios Latinos en Wisconsin'
#  'Latinos Cristianos de Kissimmee y Orlando'
#  'LATINOS EN FORT LAUDERDALE - MIAMI & ALREDEDORES' 'Latinos en Las Vegas'
#  'Latinos en Dallas - Fort Worth' 'Latinos en South Dakota'
#  'Latinos en Youngstown, Ohio' 'Colombo-Venezolano latinos en Utah'
#  'Latinos en Miami' 'Latinos En Atlanta Official' 'Latinos en Plainfields'
#  'Latinos Columbus' 'Marketing  Latinos en Atlanta  ( USA )'
#  'Latinos en SALT LAKE CITY' 'latinos unidos de cincinnati'
#  'Latinos en utah' 'Latinos en SWFL' 'Latinos en Fayetteville NC'
#  'LATINOS EN UTAH' 'Latinos en los Angeles California compra y venta'
#  'Latinos en Tampa Bay official' 'Miami-Dade Cuban-American Dems'
#  'VACOLAO - Virginia Coalition of Latino Organizations'
#  'San Diego Latino Film Festival' 'Latino Dallas'
#  'Hispanic Heritage Council of Western New York Inc.'
#  'Palm Beach County Hispanic Bar Association'
#  'Oregon Latino Health Coalition' 'Latino Union of Chicago'
#  'Washington Office on Latin America - WOLA'
#  'Chicago Latino Film Festival'
#  'West Michigan Hispanic Chamber of Commerce'
#  'Latino Community Fund of Washington State' 'Chicago Latino Network'
#  'South Carolina Latina Project' 'Nebraska Latino American Commission'
#  'Latinos for Washington Inc.' 'Minnesota Council on Latino Affairs'
#  'New Jersey Center for Hispanic Policy Research and Development'
#  'Houston Latina Bloggers' 'New Mexico Hispanic Bar Association'
#  'Texas Senate Hispanic Caucus' 'Oakland Latino Firefighters Association'
#  'Washington State Commission on Hispanic Affairs'
#  'Society of Hispanic Professional Engineers - Michigan Tech'
#  'Hispanic Business Network - Chicago' 'Chicago Latino Caucus Foundation'
#  'Oregon Hispanic Bar Association' 'Chicago Teachers Union Latinx Caucus'
#  'Latin American Student Association - South Dakota State University'
#  'Nebraska Hispanic Chamber of Commerce' 'Latino Giving Houston'
#  'Latinos en New York']
# 249

# %%
#column 1 = group, column 2 = 'name' column 3 = 'frequency'

group = []
name = []
frequency = []
#community
for x in range(len(com)):
    
    # new row
    if com['name'].iloc[x] not in name:
        #append new name
        name.append(com['name'].iloc[x])
        #create new row
        group.append('Community')
        #give value of 1
        frequency.append(1)
    else:
        v = name.index(com['name'].iloc[x])
        frequency[v] +=1

#political
for x in range(len(pol)):
    if pol['name'].iloc[x] not in name:
        #append new name
        name.append(pol['name'].iloc[x])
        #create new row
        group.append('Political')
        #give value of 1
        frequency.append(1)
    else:
        v = name.index(pol['name'].iloc[x])
        frequency[v] +=1
        
#news
for x in range(len(news)):
    if news['name'].iloc[x] not in name:
        #append new name
        name.append(news['name'].iloc[x])
        #create new row
        group.append('News')
        #give value of 1
        frequency.append(1)
    else:
        v = name.index(news['name'].iloc[x])
        frequency[v] +=1

dict = {'name': name, 'group': group, 'frequency': frequency}
df = pd.DataFrame(dict)
df
# Out:
#                                       name      group  frequency
# 0    Hispanos unidos en New York (H.U.N.Y)  Community          4
# 1                Hispanos en Columbus Ohio  Community         15
# 2                     Hispanos en Oklahoma  Community         12
# 3              Hispanos Unidos De Michigan  Community          6
# 4           Hispanos en West Palm Beach FL  Community         24
# ..                                     ...        ...        ...
# 420                      El Nacional de OK       News          1
# 421                    Miniondas Newspaper       News          1
# 422           Reflejos Bilingual Newspaper       News          1
# 423                   Buenos Dias Nebraska       News          1
# 424                            LatinTRENDS       News          1
#
# [425 rows x 3 columns]

# %%
print(len(com))
print(len(pol))
print(len(news))
# Out:
# 2638
# 327
# 451

# %%
import seaborn as sns

sns.catplot(x='group', y = 'frequency', data =df, dodge=True, kind = 'violin', aspect =2)

# %%
sns.catplot(x='group', y ='frequency', data=df, kind ='strip')

# %%
sns.catplot(x='frequency', y ='group', data=df, kind ='violin')

# %%
#Levene Test
import scipy.stats as stats
#establish three groups
group_col = []
group_pol = []
group_new = []
for x in range(len(df)):
    if df['group'][x] == "Community":
        group_col.append(df['frequency'][x])
    if df['group'][x] == "Political":
        group_pol.append(df['frequency'][x])
    if df['group'][x] == "News":
        group_new.append(df['frequency'][x])
        
stats.levene(group_col, group_pol, group_new, center='median')
# Out:
# LeveneResult(statistic=8.295346910349977, pvalue=0.0002926787102751525)

# %%
stats.levene(group_col, group_pol, group_new, center='mean')
# Out:
# LeveneResult(statistic=18.1487451975585, pvalue=2.746686329133515e-08)

# %%
from pingouin import welch_anova
aov = welch_anova(dv='frequency', between='group', data=df)
aov
# Out:
#   Source  ddof1       ddof2          F     p-unc       np2
# 0  group      2  246.751689  12.487247  0.000007  0.039977

# %%
stats.f_oneway(group_col, group_pol, group_new)
# Out:
# F_onewayResult(statistic=8.786371670567403, pvalue=0.00018257352556131544)

# %%
stats.mannwhitneyu(group_col, group_pol)
# Out:
# MannwhitneyuResult(statistic=7527.5, pvalue=4.690159132473463e-05)

# %%
stats.f_oneway(group_col, group_pol)
# Out:
# F_onewayResult(statistic=10.606897506164097, pvalue=0.0012433591713391049)

# %%
stats.mannwhitneyu(group_new, group_pol)
# Out:
# MannwhitneyuResult(statistic=3863.0, pvalue=0.49938401751012484)

# %%
stats.mannwhitneyu(group_new, group_col)
# Out:
# MannwhitneyuResult(statistic=8449.5, pvalue=7.663155986159693e-05)

# %%
stats.mannwhitneyu(group_new, group_col)
